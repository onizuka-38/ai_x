# %%
from openai import OpenAI
client = OpenAI()

response = client.responses.create(
    model="gpt-5",
    tools=[{"type": "web_search"}],
    input="동원맛참 고소참기름은 얼마야?"
)

print(response.output_text)
# Out:
# 혹시 “동원맛참 고소참기름” 참치캔 말씀 맞으세요? 병에 담긴 참기름이 아니라, 참기름맛 참치 제품입니다.
#
# 오늘(2025-09-01) 기준 대략 가격
# - 한국: 90g 4캔 묶음 약 10,800원, 135g 4캔 묶음 약 11,480원. ([ssg.com](https://www.ssg.com/search.ssg?query=%EB%8F%99%EC%9B%90%EC%B0%B8%EA%B8%B0%EB%A6%84&utm_source=openai), [store.baemin.com](https://store.baemin.com/product/302309?utm_source=openai))
# - 미국: 135g 4캔 묶음 약 $17.99(한양마트 온라인). ([hanyangmart.com](https://www.hanyangmart.com/collections/vendors?q=dongwon&srsltid=AfmBOorKKQtt8UDWS1_T_6GyvNQZT2ERlBMXnvdzA0ez38c2OA5cUpht&utm_source=openai))
#
# 원하시는 용량(90g/135g)과 구매지역(한국/미국)을 알려주시면, 현재 최저가로 더 정확히 찾아드릴게요. 만약 병 참기름(동원 참기름) 가격을 찾으시는 거라면 용량도 함께 알려주세요.

# %%
# Agent build
from agents import Agent, Runner
import asyncio

spanish_agent = Agent(
    name="Spanish agent",
    instructions="You only speak Spanish.",
)

english_agent = Agent(
    name="English agent",
    instructions="You only speak English",
)

triage_agent = Agent(
    name="Triage agent",
    instructions="Handoff to the appropriate agent based on the language of the request.",
    handoffs=[spanish_agent, english_agent],
)


async def main():
    result = await Runner.run(triage_agent, input="Hola, ¿cómo estás?")
    print(result.final_output)


if __name__ == "__main__":
    asyncio.run(main())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Agent build
# ----> 2 from agents import Agent, Runner
#       3 import asyncio
#       5 spanish_agent = Agent(
#       6     name="Spanish agent",
#       7     instructions="You only speak Spanish.",
#       8 )
#
# ModuleNotFoundError: No module named 'agents'
