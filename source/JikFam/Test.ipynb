# %%
import requests 
import pandas as pd

# %%
url = "https://kosis.kr/openapi/Param/statisticsParameterData.do?method=getList&apiKey=YzdiYTgwYTA4MmYzOWQzNjJkYjU5MjhjYjQ1MTcyMGI=&itmId=T001+&objL1=0+1+2+3+4+&objL2=&objL3=&objL4=&objL5=&objL6=&objL7=&objL8=&format=json&jsonVD=Y&prdSe=Q&startPrdDe=201501&endPrdDe=202204&orgId=101&tblId=DT_1J56"

# %%
r = requests.get(url)
j = r.json()

j
# Out:
# [{'C1_OBJ_NM': '분류별',
#   'DT': '102.2',
#   'C1': '0',
#   'PRD_SE': 'Q',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1J56',
#   'ITM_NM': '농가판매가격지수',
#   'TBL_NM': '농가판매가격지수(2015＝100 분기)',
#   'PRD_DE': '201501',
#   'LST_CHN_DE': '2018-04-27',
#   'C1_NM_ENG': 'All commodities',
#   'C1_NM': '총지수',
#   'ITM_NM_ENG': 'P.I. of farm products received by farmer',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'All commodities'},
#  {'C1_OBJ_NM': '분류별',
#   'DT': '99',
#   'C1': '0',
#   'PRD_SE': 'Q',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1J56',
#   'ITM_NM': '농가판매가격지수',
#   'TBL_NM': '농가판매가격지수(2015＝100 분기)',
#   'PRD_DE': '201502',
#   'LST_CHN_DE': '2018-04-27',
#   'C1_NM_ENG': 'All commodities',
#   'C1_NM': '총지수',
#   'ITM_NM_ENG': 'P.I. of farm products received by farmer',
#   'ORG_ID': '101',
#   'C1_OBJ_NM_ENG': 'All commodities'},
#  {'C1_OBJ_NM': '분류별',
#   'DT': '99',
#   'C1': '0',
#   'PRD_SE': 'Q',
#   'ITM_ID': 'T001',
#   'TBL_ID': 'DT_1J56',
#   'ITM_NM': '농가판매가격지수',
# ...

# %%
df = pd.DataFrame(j)
df
# Out:
#     C1_OBJ_NM          DT C1 PRD_SE ITM_ID   TBL_ID    ITM_NM  \
# 0         분류별       102.2  0      Q   T001  DT_1J56  농가판매가격지수
# 1         분류별          99  0      Q   T001  DT_1J56  농가판매가격지수
# 2         분류별          99  0      Q   T001  DT_1J56  농가판매가격지수
# 3         분류별        98.5  0      Q   T001  DT_1J56  농가판매가격지수
# 4         분류별       106.7  0      Q   T001  DT_1J56  농가판매가격지수
# ..        ...         ... ..    ...    ...      ...       ...
# 155       분류별  120.797478  4      Q   T001  DT_1J56  농가판매가격지수
# 156       분류별  133.570295  4      Q   T001  DT_1J56  농가판매가격지수
# 157       분류별   123.15689  4      Q   T001  DT_1J56  농가판매가격지수
# 158       분류별       120.3  4      Q   T001  DT_1J56  농가판매가격지수
# 159       분류별       118.6  4      Q   T001  DT_1J56  농가판매가격지수
#
#                     TBL_NM  PRD_DE  LST_CHN_DE            C1_NM_ENG  C1_NM  \
# 0    농가판매가격지수(2015＝100 분기)  201501  2018-04-27      All commodities    총지수
# ...
