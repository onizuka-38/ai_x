# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:86% !important;}
div.cell.code_cell.rendered{width:100%;}
div.CodeMirror {font-family:Consolas; font-size:12pt;}
div.output {font-size:15pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:12pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:12px;}
</style>
"""))
# Out:
# <style>
# div.container{width:86% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.CodeMirror {font-family:Consolas; font-size:12pt;}
# div.output {font-size:15pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:12pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:12px;}
# </style>

# %% [markdown]
# <b><font size="5" color="red" >ch14. 웹데이터 수집</font></b>
# # 1절. BeautifulSoup 과 parser
# ``` pip install bs4``` 아나콘다를 설치하면 7500여개의 패키지 설치
# - 공식 사이트 : https://www.crummy.com/software/BeautifulSoup/
# - Docs : https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %%
import requests # HTTP 요청 처리 lib
from requests_file import FileAdapter

# %%
s = requests.Session() # HTTP 요청관리를 위한 세션 객체
s.mount("file://", FileAdapter())
response = s.get("file:///ai_x/source/01_python/data/ch14_sample.html")
response
# Out:
# <Response [200]>

# %%
response.status_code 
# 200
# 404 : 없는 페이지
# 406 : get, post 오류
# Out:
# 200

# %%
ex = response.content # 바이너리 형식의 내용
ex
# Out:
# b'<!DOCTYPE html>\r\n<html lang="en">\r\n  <head>\r\n    <meta charset="UTF-8" />\r\n  </head>\r\n  <body>\r\n    <h1 class="greeting css" id="text" title="greeting">Hello, CSS</h1>\r\n    <h1 class="css">Hi, CSS</h1>\r\n    <div id="subject">subject \xec\x84\xa0\xed\x83\x9d\xec\x9e\x90 \xec\x95\x88\xec\x9d\x98 \xeb\x82\xb4\xec\x9a\xa9</div>\r\n    <p>CSS \xec\x84\xa0\xed\x83\x9d\xec\x9e\x90\xeb\x8a\x94 \xeb\x8b\xa4\xec\x96\x91\xed\x95\x9c \xea\xb3\xb3\xec\x97\x90\xec\x84\x9c \xed\x99\x9c\xec\x9a\xa9\xeb\x90\xa9\xeb\x8b\x88\xeb\x8b\xa4</p>\r\n    <div class="contents">\r\n      \xec\x84\xa0\xed\x83\x9d\xec\x9e\x90\xeb\xa5\xbc \xec\x96\xb4\xeb\x96\xbb\xea\xb2\x8c \xec\x9e\x91\xec\x84\xb1\xed\x95\x98\xeb\x8a\x90\xeb\x83\x90\xec\x97\x90 \xeb\x94\xb0\xeb\x9d\xbc\r\n      <span>\xeb\x8b\xa4\xeb\xa5\xb8<b>\xec\x9a\x94\xec\x86\x8c\xea\xb0\x80 \xeb\xb0\x98\xed\x99\x98</b></span\r\n      >\xeb\x90\xa9\xeb\x8b\x88\xeb\x8b\xa4\r\n    </div>\r\n    <div>CSS \xec\x84\xa0\xed\x83\x9d\xec\x9e\x90\xeb\x8a\x94 \xeb\x8b\xa4\xec\x96\x91\xed\x95\x9c \xea\xb3\xb3\xec\x97\x90 <b>\xed\x99\x9c\xec\x9a\xa9</b>\xeb\x90\xa9\xeb\x8b\x88\xeb\x8b\xa4</div>\r\n  </body>\r\n</html>\r\n'

# %%
ex.decode('utf-8')
# Out:
# '<!DOCTYPE html>\r\n<html lang="en">\r\n  <head>\r\n    <meta charset="UTF-8" />\r\n  </head>\r\n  <body>\r\n    <h1 class="greeting css" id="text" title="greeting">Hello, CSS</h1>\r\n    <h1 class="css">Hi, CSS</h1>\r\n    <div id="subject">subject 선택자 안의 내용</div>\r\n    <p>CSS 선택자는 다양한 곳에서 활용됩니다</p>\r\n    <div class="contents">\r\n      선택자를 어떻게 작성하느냐에 따라\r\n      <span>다른<b>요소가 반환</b></span\r\n      >됩니다\r\n    </div>\r\n    <div>CSS 선택자는 다양한 곳에 <b>활용</b>됩니다</div>\r\n  </body>\r\n</html>\r\n'

# %%
response.text
# Out:
# '<!DOCTYPE html>\r\n<html lang="en">\r\n  <head>\r\n    <meta charset="UTF-8" />\r\n  </head>\r\n  <body>\r\n    <h1 class="greeting css" id="text" title="greeting">Hello, CSS</h1>\r\n    <h1 class="css">Hi, CSS</h1>\r\n    <div id="subject">subject 선택자 안의 내용</div>\r\n    <p>CSS 선택자는 다양한 곳에서 활용됩니다</p>\r\n    <div class="contents">\r\n      선택자를 어떻게 작성하느냐에 따라\r\n      <span>다른<b>요소가 반환</b></span\r\n      >됩니다\r\n    </div>\r\n    <div>CSS 선택자는 다양한 곳에 <b>활용</b>됩니다</div>\r\n  </body>\r\n</html>\r\n'

# %%
# html 파싱
from bs4 import BeautifulSoup
soup = BeautifulSoup(response.content, # response.text
                     "html.parser")
#soup

# %%
# soup.select_one('선택자') : 해당 선택자 처음 하나만
el = soup.select_one('h1') # 처음 나오는 h1태그 하나만
print('el :', el)
print('el.text :', el.text)
print('el.string :', el.string)
print('el의 속성들 :', el.attrs)
print('el의 title 속성 :', el.attrs['title'])
print('el의 title 속성 :', el.attrs.get('title'))
print('el의 이름 :', el.name)
# Out:
# el : <h1 class="greeting css" id="text" title="greeting">Hello, CSS</h1>
# el.text : Hello, CSS
# el.string : Hello, CSS
# el의 속성들 : {'class': ['greeting', 'css'], 'id': 'text', 'title': 'greeting'}
# el의 title 속성 : greeting
# el의 title 속성 : greeting
# el의 이름 : h1

# %%
# soup.select('선택자') : 해당 선택자 모든 엘리먼트를 리스트로
el = soup.select('h1')
print('리스트 el :', el)
print('el의 text들 :', [e.text for e in el])
# for e in el:
#     print(e.text, end=',')
print('el의 속성들 :', [e.attrs for e in el])
print('el의 class속성들 :', [e.attrs.get('class') for e in el])
# Out:
# 리스트 el : [<h1 class="greeting css" id="text" title="greeting">Hello, CSS</h1>, <h1 class="css">Hi, CSS</h1>]
# el의 text들 : ['Hello, CSS', 'Hi, CSS']
# el의 속성들 : [{'class': ['greeting', 'css'], 'id': 'text', 'title': 'greeting'}, {'class': ['css']}]
# el의 class속성들 : [['greeting', 'css'], ['css']]

# %%
# select_one(선택자)와 find(태그,속성)
print('select_one :', soup.select_one('h1.css'))
print('find :', soup.find('h1', {'class':'css'}))
print('find :', soup.find('h1', class_='css'))
print()
print('select_one :', soup.select_one('h1#text'))
print('find :', soup.find('h1', {'id':'text'}))
print()
print('select')
# Out:
# select_one : <h1 class="greeting css" id="text" title="greeting">Hello, CSS</h1>
# find : <h1 class="greeting css" id="text" title="greeting">Hello, CSS</h1>
# find : <h1 class="greeting css" id="text" title="greeting">Hello, CSS</h1>
#
# select_one : <h1 class="greeting css" id="text" title="greeting">Hello, CSS</h1>
# find : <h1 class="greeting css" id="text" title="greeting">Hello, CSS</h1>

# %%
# select(선택자)와 find_all(태그, 속성)
print('모든 h1.css , span 태그(select) :',
      soup.select('h1.css, span'))
print('모든 h1.css, span태그(find_all) :',
      soup.find_all(['h1','span'], class_='css'))
# Out:
# 모든 h1.css , span 태그(select) : [<h1 class="greeting css" id="text" title="greeting">Hello, CSS</h1>, <h1 class="css">Hi, CSS</h1>, <span>다른<b>요소가 반환</b></span>]
# 모든 h1.css, span태그(find_all) : [<h1 class="greeting css" id="text" title="greeting">Hello, CSS</h1>, <h1 class="css">Hi, CSS</h1>]

# %%
# 없는 엘리먼트 찾기
print('find_all(빈 list) :', soup.find_all('a', class_ = 'css'))
print('find(None) :', soup.find('a', class_='css'))
print('select :', soup.select('a.css'))
print('select_one(None) :', soup.select_one('a.css'))
# Out:
# find_all(빈 list) : []
# find(None) : None
# select : []
# select_one(None) : None

# %% [markdown]
# # 2절. 정적 웹 데이터 수집(정적 웹 크롤링)
# - json, html, xml
# ## 2.1 JSON파일
# - request모듈(get)
# - urllib.request모듈(urlopen)

# %%
# 크롤링 허용 범위는 사이트마다 ~/robots.txt에서 확인할 수 있습니다

# %%
# 방법1
import requests
response = requests.get('http://api.github.com')
response, response.status_code
# Out:
# (<Response [200]>, 200)

# %%
# 방법2
from urllib.request import urlopen
response = urlopen('http://api.github.com')
response
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[104], line 3
#       1 # 방법2
#       2 from urllib.request import urlopen
# ----> 3 response = urlopen('http://api.github.com')
#       4 response
#
# File c:\Users\Admin\anaconda3\lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File c:\Users\Admin\anaconda3\lib\urllib\request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File c:\Users\Admin\anaconda3\lib\urllib\request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     631 # According to RFC 2616, "2xx" code indicates that the client's
#     632 # request was successfully received, understood, and accepted.
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File c:\Users\Admin\anaconda3\lib\urllib\request.py:557, in OpenerDirector.error(self, proto, *args)
#     555     http_err = 0
#     556 args = (dict, proto, meth_name) + args
# --> 557 result = self._call_chain(*args)
#     558 if result:
#     559     return result
#
# File c:\Users\Admin\anaconda3\lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File c:\Users\Admin\anaconda3\lib\urllib\request.py:749, in HTTPRedirectHandler.http_error_302(self, req, fp, code, msg, headers)
#     746 fp.read()
#     747 fp.close()
# --> 749 return self.parent.open(new, timeout=req.timeout)
#
# File c:\Users\Admin\anaconda3\lib\urllib\request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File c:\Users\Admin\anaconda3\lib\urllib\request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     631 # According to RFC 2616, "2xx" code indicates that the client's
#     632 # request was successfully received, understood, and accepted.
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File c:\Users\Admin\anaconda3\lib\urllib\request.py:563, in OpenerDirector.error(self, proto, *args)
#     561 if http_err:
#     562     args = (dict, 'default', 'http_error_default') + orig_args
# --> 563     return self._call_chain(*args)
#
# File c:\Users\Admin\anaconda3\lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File c:\Users\Admin\anaconda3\lib\urllib\request.py:643, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     642 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 403: rate limit exceeded

# %%
text = '{"속성1":"값1","속성2":"값2"}'
type(text)
# Out:
# str

# %%
# 문자(딕셔너리 타입)를 딕져너리
# '{"속성1":"값1","속성2":"값2"}' => {"속성1":"값1","속성2":"값2"}
import json
json.loads(text)
# Out:
# {'속성1': '값1', '속성2': '값2'}

# %% [markdown]
# ## 2.2 html 파일
# ### 1) 환율정보 가져오기(네이버->증권->시장지표)

# %%
# 방법1
import requests
from bs4 import BeautifulSoup
url = 'https://finance.naver.com/marketindex'
# https://finance.naver.com/robots.txt : robots.txt로 크롤링 허용범위 확인
response = requests.get(url)
# response, response.status_code
# response.content
# response.content.decode('cp949') == response.text
soup = BeautifulSoup(response.text,
                     'html.parser')

# %%
# 방법2
from urllib.request import urlopen
response = urlopen(url)
# response.status 상태코드
# response.read()
# response.read().decode('cp949')
soup = BeautifulSoup(response, 'html.parser')

# %%
title = soup.select('h3.h_lst > span.blind')
for t in title:
    print(t.text, end='\t')
# Out:
# 미국 USD	일본 JPY(100엔)	유럽연합 EUR	중국 CNY	달러/일본 엔	유로/달러	영국 파운드/달러	달러인덱스	WTI	휘발유	국제 금	국내 금

# %%
price = soup.select('div.head_info > span.value')
# for p in price:
#     print(p.text, end='\t')
[round(float(p.text.replace(',',''))) for p in price]
[round(float(''.join(p.text.split(',')))) for p in price]
# Out:
# [1375, 953, 1556, 191, 144, 1, 1, 99, 61, 1633, 3300, 146218]

# %%
out = '1,375.20'
round(float(''.join(out.split(','))))
# Out:
# 1375

# %%
round(float(out.replace(',','')))
# Out:
# 1375

# %%
unit = soup.select('div.head_info > span > span.blind')
unit = [u.text for u in unit]
unit.insert(7, '') # 7번째 인덱스에 ''추가
unit
# Out:
# ['원', '원', '원', '원', '엔', '달러', '달러', '', '달러', '원', '달러', '원']

# %%
status = soup.select('div.head_info > span.blind')
[t.text for t in title]
[p.text for p in price]
unit
[s.string for s in status]
# Out:
# ['하락', '하락', '하락', '하락', '상승', '하락', '하락', '상승', '하락', '하락', '하락', '상승']

# %%
len(title), len(price), len(unit), len(status)
# Out:
# (12, 12, 12, 12)

# %%
for idx in range(len(title)):
    print("{} : {}{} - {}".format(idx+1,
                                  title[idx].text,
                                  price[idx].text,
                                  unit[idx],
                                  status[idx].text))
# Out:
# 1 : 미국 USD1,375.20 - 원
# 2 : 일본 JPY(100엔)953.05 - 원
# 3 : 유럽연합 EUR1,556.38 - 원
# 4 : 중국 CNY191.04 - 원
# 5 : 달러/일본 엔144.3800 - 엔
# 6 : 유로/달러1.1342 - 달러
# 7 : 영국 파운드/달러1.3520 - 달러
# 8 : 달러인덱스99.4200 -
# 9 : WTI60.89 - 달러
# 10 : 휘발유1633.17 - 원
# 11 : 국제 금3300.4 - 달러
# 12 : 국내 금146218.18 - 원

# %%
for idx, (t,p,u,s) in enumerate (zip(title, price, unit, status)):
    print("{} : {}{} - {}".format(idx+1,
                                  t.text,
                                  p.text,
                                  u,
                                  s.text))
# Out:
# 1 : 미국 USD1,375.20 - 원
# 2 : 일본 JPY(100엔)953.05 - 원
# 3 : 유럽연합 EUR1,556.38 - 원
# 4 : 중국 CNY191.04 - 원
# 5 : 달러/일본 엔144.3800 - 엔
# 6 : 유로/달러1.1342 - 달러
# 7 : 영국 파운드/달러1.3520 - 달러
# 8 : 달러인덱스99.4200 -
# 9 : WTI60.89 - 달러
# 10 : 휘발유1633.17 - 원
# 11 : 국제 금3300.4 - 달러
# 12 : 국내 금146218.18 - 원

# %% [markdown]
# ### 2) 이번주 로또번호 출력
# - https://dhlottery.co.kr/gameResult.do?method=byWin (로또번호 당첨결과)
# ```
#     1173회 (2025년 05월 24일 추첨)
#     당첨번호 [1 5 18 20 30 35]
#     보너스 3
# ```

# %%
# 방법1
import requests
from bs4 import BeautifulSoup
url = 'https://dhlottery.co.kr/gameResult.do?method=byWin'
response = requests.get(url)
soup = BeautifulSoup(response.content,
                     'html.parser')

# %%
from urllib.request import urlopen
response = urlopen(url)
soup = BeautifulSoup(response, "html.parser")

# %%
title = soup.select('h4 > strong')
for t in title:
    print(t.text, end='\t')
# Out:
# 1173회

# %%
number = soup.select('div.num.win span')
[n.text for n in number]
# Out:
# ['1', '5', '18', '20', '30', '35']

# %%
bonus = soup.select('div.num.bonus span')
[b.text for b in bonus]
# Out:
# ['3']

# %%
times = soup.select_one('h4 > strong').text # 1173회
date = soup.select_one('div.win_result >p.desc').text # 2025년 05월 24일 추첨
print(times, date)
title1 = soup.select_one('div.num.win > strong').text
lotto_number = soup.select('div.num.win > p > span')
print(title1, [int(lotto.text) for lotto in lotto_number])
title2 = soup.select_one('div.num.bonus > strong').string
bonus_number = soup.select_one('div.num.bonus > p > span').text
print(title2, bonus_number)
# Out:
# 1173회 (2025년 05월 24일 추첨)
# 당첨번호 [1, 5, 18, 20, 30, 35]
# 보너스 3

# %%
# 위의 select 함수를 find 함수로
# times = soup.select_one('h4 > strong').text # 1173회
win_result = soup.find('div', class_="win_result")
times = win_result.find('strong').text
# date = soup.select_one('div.win_result >p.desc').text # 2025년 05월 24일 추첨
soup.find('p', class_='desc').text
print(times,date)
# title1 = soup.select_one('div.num.win > strong').text
num_win = soup.find('div', class_=['num', 'win'])
title1 = num_win.find('strong').text
# lotto_number = soup.select('div.num.win > p > span')
lotto_number = num_win.find_all('span') #배열
print(title1, [int(lotto.text) for lotto in lotto_number])
# title2 = soup.select_one('div.num.bonus > strong').string
num_bonus = soup.find('div', class_=['bonus'])
title2 = num_bonus.find('strong').text

# bonus_number = soup.select_one('div.num.bonus > p > span').text
bonus_number = num_bonus.find('span').text
print(title2, bonus_number)
# Out:
# 1173회 (2025년 05월 24일 추첨)
# 당첨번호 [1, 5, 18, 20, 30, 35]
# 보너스 3

# %% [markdown]
# ### 3) 다음 검색 리스트
# ```
# no title link
# [비트코인 2025] https://v.daum.net/v/20250528103907230
# [비즈 나우] https://v.daum.net/v/20250528075215864
# ```

# %%
# 방법1
import requests
from bs4 import BeautifulSoup
keyword = '의학공학'
url = 'https://search.daum.net/search?w=news&nil_search=btn&DA=NTB&enc=utf8&cluster=y&cluster_page=1&q=' + keyword
response = requests.get(url)
soup = BeautifulSoup(response.text, # response.content
                     "html.parser")
items_find_list = [] # 검색한 결과를 담을 dict list
items_el = soup.select('div.item-title > strong.tit-g.clamp-g > a')
len(items_el)
for idx,item in enumerate(items_el):
    items_find_list.append({'no':idx,
                            'title':item.text,
                            'link':item.attrs['href']})
import pandas as pd
pd.DataFrame(items_find_list)
# Out:
#    no                                             title  \
# 0   0       [의학바이오게시판] 삼성바이오로직스, 5개월만에 누적 수주액 3조원 돌파 外
# 1   1   연세의대 성학준·유승은 교수팀, '면역세포가 약물을 표적 세포로 전달' 플랫폼 개발
# 2   2                “암·심혈관질환 치료에 획기적”…새로운 약물 전달 방법 개발
# 3   3                 면역세포가 약물을 표적 세포로 전달하는 새로운 플랫폼 개발
# 4   4                  유학생 사상 검증하나…美 국무부 SNS 심사 의무화 추진
# 5   5            “AI의료융합 혁신” 순천향대, ‘2025 글로컬대학30’ 예비지정
# 6   6                     고대의료원 "중증·난치성 질환 연구 병원으로 도약"
# 7   7             “간호법 이대로 두면 심장수술 멈춘다” 흉부외과 교수의 작심 발언
# 8   8            미국 유학·취업비자 ‘빨간불’…국민이주㈜ 24일 미국투자이민 설명회
# 9   9               계명대 의과대학-DGIST, 글로벌 의과학자 양성 요람 만든다
#
#                                     link
# 0  http://v.daum.net/v/20250526175012172
# 1  http://v.daum.net/v/20250526093721609
# 2  http://v.daum.net/v/20250526162539118
# 3  http://v.daum.net/v/20250526093608557
# 4  http://v.daum.net/v/20250528133501355
# 5  http://v.daum.net/v/20250527143105983
# 6  http://v.daum.net/v/20250526181355077
# 7  http://v.daum.net/v/20250521053048252
# 8  http://v.daum.net/v/20250522100601267
# 9  http://v.daum.net/v/20250527184316561

# %% [markdown]
# ### 4) User-agent를 추가하여 크롤링
# - urlopen()함수를 사용하면 크롤링이 안 되는 사이트
# - User-agent를 추가하여 크롤링

# %%
# 방법2
from urllib.request import urlopen
import urllib.parse
keyword = '비트코인'
keyword = urllib.parse.quote(keyword)
print(keyword)
url = 'https://search.daum.net/search?w=news&nil_search=btn&DA=NTB&enc=utf8&cluster=y&cluster_page=1&q=' + keyword
response = urlopen(url)

soup = BeautifulSoup(response, # response.content
                     "html.parser")
items_find_list = [] # 검색한 결과를 담을 dict list
items_el = soup.select('div.item-title > strong.tit-g.clamp-g > a')
len(items_el)
for idx,item in enumerate(items_el):
    items_find_list.append({'no':idx,
                            'title':item.text,
                            'link':item.attrs['href']})
import pandas as pd
pd.DataFrame(items_find_list)
# Out:
# %EB%B9%84%ED%8A%B8%EC%BD%94%EC%9D%B8
# Empty DataFrame
# Columns: []
# Index: []

# %%
import requests
from bs4 import BeautifulSoup
keyword = '비트코인'
url = 'https://search.daum.net/search?w=news&nil_search=btn&DA=NTB&enc=utf8&cluster=y&q=' + keyword
response = requests.get(url)
soup = BeautifulSoup(response.text, # response.content
                     "html.parser")
items_find_list = [] # 검색한 결과를 담을 2차원 리스트items_el = soup.select('div.item-title > strong.tit-g.clamp-g > a')
items_el = soup.select('div.item-title > strong.tit-g.clamp-g > a')
len(items_el)
for idx,item in enumerate(items_el):
    items_find_list.append([idx, item.text, item.attrs.get('href')])
items_find_list
import pandas as pd
pd.DataFrame(items_find_list, columns=['no', 'title', 'link'])
# Out:
#    no                                              title  \
# 0   0   [비트코인 2025] 백악관 크립토 차르 “美 정부 비트코인 추가 매입 검토…부채...
# 1   1            [비즈 나우] 비트코인 2025 컨퍼런스 개막…'전략자산' 선언 코앞
# 2   2                       美·日 국채 팔고 비트코인 샀다…'안전자산' 등극
# 3   3    “맥O날드보다 맛없어!” 혹평이 가득한 트럼프 만찬과 비트코인 피자데이[엠블록레터]
# 4   4         블랙록, 자사 비트코인 ETF 보유량 25% 확대…기관 투자 본격화 신호탄
# 5   5                 '비트코인 빚투' 스트레티지, 또 샀다…보유량 58만개 돌파
# 6   6                비트코인, 트럼프 미디어 비축 소식에도 주춤…1억5100만원대
# 7   7                        美 상원의원 "트럼프 대통령, 비트코인법 지지"
# 8   8                       숨 고르는 비트코인, 10만8000달러선 '주춤'
# 9   9   [비트코인 2025] 로빈후드 창업자 “토큰화 증권은 美 ‘자본 패권’ 키우는 수단”
#
#                                     link
# 0  http://v.daum.net/v/20250528103907230
# 1  http://v.daum.net/v/20250528075215864
# 2  http://v.daum.net/v/20250528154126316
# 3  http://v.daum.net/v/20250528143002735
# 4  http://v.daum.net/v/20250528151802080
# 5  http://v.daum.net/v/20250528042404292
# 6  http://v.daum.net/v/20250528095112897
# 7  http://v.daum.net/v/20250528090342853
# 8  http://v.daum.net/v/20250528095921258
# 9  http://v.daum.net/v/20250528110600761

# %%
# 다음 뉴스 검색(키워드, 원하는 페이지수)
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
def collect_list(keyword,page=1):
    'keyword로 다음 검색한 결과(해당 page)를 return'
    url = f'https://search.daum.net/search?w=news&nil_search=btn&DA=NTB&enc=utf8&cluster=y'
    params = {'q':keyword, 'p':page}
    response = requests.get(url, params=params)
    soup = BeautifulSoup(response.text, # response.content
                     'html.parser')
    items_find_list = [] # 검색한 결과를 담을 dict list
    items_el = soup.select('div.item-title > strong.tit-g.clamp-g > a')
    for idx,item in enumerate(items_el):
        items_find_list.append({'no': (page-1)*10 +idx,
                                'title':item.text,
                                'link':item.attrs['href']})
    return items_find_list
# keyword = '비트코인'
# page = 2
# # url = f'https://search.daum.net/search?w=news&nil_search=btn&DA=NTB&enc=utf8&cluster=y&q={keyword}&p={page}'
# # response = requests.get(url)
# url = f'https://search.daum.net/search?w=news&nil_search=btn&DA=NTB&enc=utf8&cluster=y'
# params = {'q':keyword, 'p':page}
# response = requests.get(url, params=params)
# soup = BeautifulSoup(response.text, # response.content
#                      'html.parser')
# items_find_list = [] # 검색한 결과를 담을 dict list
# items_el = soup.select('div.item-title > strong.tit-g.clamp-g > a')
# len(items_el)
# for idx,item in enumerate(items_el):
#     items_find_list.append({'no': (page-1)*10 +idx,
#                             'title':item.text,
#                             'link':item.attrs['href']})
#     print({'no':(page-1)*10 + idx,
#             'title':item.text,
#             'link':item.attrs['href']})

# %%
collect_list('대선',3)
# Out:
# [{'no': 20,
#   'title': ' [속보] 이재명 “대선 공약 이행 위해 5년간 210조원 필요 추정” ',
#   'link': 'http://v.daum.net/v/20250528154502477'},
#  {'no': 21,
#   'title': ' 양산 찾은 김문수 대선 후보 ',
#   'link': 'http://v.daum.net/v/20250528155708039'},
#  {'no': 22,
#   'title': ' 대선에 경찰 최대동원…서울 투표함 회송에 무장경찰 6400명 ',
#   'link': 'http://v.daum.net/v/20250528154201339'},
#  {'no': 23,
#   'title': ' 이재명, 이준석 겨냥 "혐오 언어로 대선 채워져 부끄럽다" ',
#   'link': 'http://v.daum.net/v/20250528142759650'},
#  {'no': 24,
#   'title': ' “여성 유권자에게 사과”…이준석 유세 중 날아든 지적 [21대 대선] ',
#   'link': 'http://v.daum.net/v/20250528142905688'},
#  {'no': 25,
#   'title': ' 대선토론 최악의 언어 성폭력…이준석 발언 ‘사후 제재’ 가능할까 ',
#   'link': 'http://v.daum.net/v/20250528144503420'},
#  {'no': 26,
#   'title': ' [게시판] 관악구, 대선 앞두고 투표소 점검 ',
#   'link': 'http://v.daum.net/v/20250528155731058'},
#  {'no': 27,
#   'title': ' 국힘 “단일화, 우리측 협상 국면 지나…이준석, 미래 생각해주길” [21대 대선] ',
#   'link': 'http://v.daum.net/v/20250528160604529'},
#  {'no': 28,
#   'title': ' [대선공약] 코리아 디스카운트 넘는다…李 "주주권익 보호" vs 金 "세제 혜택" ',
#   'link': 'http://v.daum.net/v/20250528153751194'},
#  {'no': 29,
#   'title': ' 21대 대선, 팩트체크 보도 만족하십니까 ',
#   'link': 'http://v.daum.net/v/20250528142254440'}]

# %%
# 원하는 keyword로 다음검색
result = []
keyword ="코로나"
pages = 4
for page in range(1, pages+1):
    result.extend(collect_list(keyword, page))
    time.sleep(1)
result_df = pd.DataFrame(result)
result_df.head()
# Out:
#    no                                       title  \
# 0   0     코로나에 매주 300명 죽는데…美 "임신부·아동 백신 권고 중단" 왜
# 1   1          대만 "코로나19 환자 내달 말 20만명으로 정점 이를 것"
# 2   2    "건강한 어린이·임산부, 코로나 백신 맞지 말라" 美 CDC 권고 중단
# 3   3               영천시, 코로나19 재유행 대비 예방접종 기간 연장
# 4   4   [기고] '국가 방역 최전선' 공항, 코로나19 재확산 막을 게이트 키퍼
#
#                                     link
# 0  http://v.daum.net/v/20250528150501463
# 1  http://v.daum.net/v/20250528112745057
# 2  http://v.daum.net/v/20250528155941153
# 3  http://v.daum.net/v/20250528160910676
# 4  http://v.daum.net/v/20250528152801669

# %%
keywords = ['청바지','면바지']
pages = 5
result0 = [] # 청바지 검색결과 50개
result1 = [] # 면바지 검색결과 50개
for i, keyword in enumerate(keyword):
    for page in range(1, pages+1):
        print(f'~ ~ ~ {i}번째 {keywords} {page} 검색 중입니다 ~ ~ ~')    
        if i==0:
            result0.extend(collect_list(keyword,page))
        else:
            result1.extend(collect_list(keyword,page))
        time.sleep(4)
# Out:
# ~ ~ ~ 0번째 ['청바지', '면바지'] 1 검색 중입니다 ~ ~ ~
# ~ ~ ~ 0번째 ['청바지', '면바지'] 2 검색 중입니다 ~ ~ ~
# ~ ~ ~ 0번째 ['청바지', '면바지'] 3 검색 중입니다 ~ ~ ~
# ~ ~ ~ 0번째 ['청바지', '면바지'] 4 검색 중입니다 ~ ~ ~
# ~ ~ ~ 0번째 ['청바지', '면바지'] 5 검색 중입니다 ~ ~ ~

# %%
result0_df = pd.DataFrame(result0)
result0_df.head()
# Out:
#    no                                              title  \
# 0   0                      '이병헌♥' 이민정, 매장 통째로 빌려 청바지 쇼핑
# 1   1            “추앙받을 만 하네”… 김지원, 셔츠에 청바지만 입어도 공항 ‘정지’
# 2   2                              흰 티셔츠에 청바지 정석대로 입는 법
# 3   3          이민정, 매장 빌려 폭풍 쇼핑 "10년 전 샀던 청바지는 응급실"(MJ)
# 4   4   ‘이병헌♥’ 이민정, 청바지 사는데 매장 통째로 빌렸다..남다른 쇼핑 클래스 “나...
#
#                                     link
# 0  http://v.daum.net/v/20250528050507783
# 1  http://v.daum.net/v/20250526182411395
# 2  http://v.daum.net/v/20250527185425864
# 3  http://v.daum.net/v/20250527191015309
# 4  http://v.daum.net/v/20250527192310643

# %%
result1_df = pd.DataFrame(result1)
result1_df.head()
# Out:
#    no                                              title  \
# 0   0                     사천에서 쾌청한 날씨 속 탁 트인 남해 풍경 즐겨요!
# 1   1            윤승아, ♥김무열 쏙 빼닮은 깜찍 子 하객룩 공개‥벌써 우월한 유전자
# 2   2                           이번 주 포천 여행,반팔 하나로 충분할까?
# 3   3                              이재명, 첫 대학 방문…이준석 겨냥?
# 4   4   "나는 젊어" 팔소매 접은 이준석의 '흰셔츠' 속에도 뼈가 담겼다[21대 대선 리...
#
#                                     link
# 0  http://v.daum.net/v/20250528104429529
# 1  http://v.daum.net/v/20250526145941690
# 2  http://v.daum.net/v/20250527171732518
# 3  http://v.daum.net/v/20250526191942751
# 4  http://v.daum.net/v/20250525070013619

# %%
result0_df.to_csv('data/ch14_'+keywords[0]+'.csv', index=False, encoding='cp949')
result1_df.to_csv('data/ch14_'+keywords[1]+'.csv', index=False)

# %% [markdown]
# ### 4) User-agent를 추가하여 크롤링
# - urlopen()함수를 사용하면 크롤링이 안 되는 사이트
# - User-agent를 추가하여 크롤링

# %%
# 방법2
from urllib.request import urlopen, Request
import urllib.parse
word = '비트코인'
word = urllib.parse.quote(word)
# print(word)
url = 'https://search.daum.net/search?w=news&nil_search=btn&DA=NTB&enc=utf8&cluster=y&cluster_page=1&q='+word
# User-Agent를 추가하여 브라우저처럼 보이게 포장
headers = {'user-agent':
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36'}
request = Request(url, headers=headers)
response = urlopen(request)
soup = BeautifulSoup(response, # response.content
                    "html.parser")

def collect_list(keyword,page=1):
    'keyword로 다음 검색한 결과(해당 page)를 return'
    url = f'https://search.daum.net/search?w=news&nil_search=btn&DA=NTB&enc=utf8&cluster=y'
    params = {'q':keyword, 'p':page}
    response = requests.get(url, params=params)
    soup = BeautifulSoup(response.text, # response.content
                     'html.parser')
    items_find_list = [] # 검색한 결과를 담을 dict list
    items_el = soup.select('div.item-title > strong.tit-g.clamp-g > a')
    for idx,item in enumerate(items_el):
        items_find_list.append({'no': (page-1)*10 +idx,
                                'title':item.text,
                                'link':item.attrs['href']})
    return items_find_list
collect_list("청바지", 1)
# Out:
# [{'no': 0,
#   'title': " '이병헌♥' 이민정, 매장 통째로 빌려 청바지 쇼핑 ",
#   'link': 'http://v.daum.net/v/20250528050507783'},
#  {'no': 1,
#   'title': ' “추앙받을 만 하네”… 김지원, 셔츠에 청바지만 입어도 공항 ‘정지’ ',
#   'link': 'http://v.daum.net/v/20250526182411395'},
#  {'no': 2,
#   'title': ' 흰 티셔츠에 청바지 정석대로 입는 법 ',
#   'link': 'http://v.daum.net/v/20250527185425864'},
#  {'no': 3,
#   'title': ' 이민정, 매장 빌려 폭풍 쇼핑 "10년 전 샀던 청바지는 응급실"(MJ) ',
#   'link': 'http://v.daum.net/v/20250527191015309'},
#  {'no': 4,
#   'title': ' ‘이병헌♥’ 이민정, 청바지 사는데 매장 통째로 빌렸다..남다른 쇼핑 클래스 “나는 즉흥적”(이민정 MJ) ',
#   'link': 'http://v.daum.net/v/20250527192310643'},
#  {'no': 5,
#   'title': ' 이시영처럼 다리 길어보이고 싶어서 청바지 분석함 [입스타그램] ',
#   'link': 'http://v.daum.net/v/20250519172231644'},
#  {'no': 6,
#   'title': ' \'의사 그만둔\' 고윤정, 흰 티+청바지..."정석 미녀" [★해시태그] ',
#   'link': 'http://v.daum.net/v/20250522182007490'},
#  {'no': 7,
#   'title': ' "청렴이 최고" … 창원특례시 성산구 문화위생과, \'청바지 데이\' 추진 ',
#   'link': 'http://v.daum.net/v/20250511091428626'},
#  {'no': 8,
#   'title': ' 패셔니스타 김지원, 청바지가 어울리는 여자랍니다! [포토] ',
#   'link': 'http://v.daum.net/v/20250518220139191'},
#  {'no': 9,
#   'title': ' 박병은 "류준하로 3개월 활동"…청바지 모델 시절 언급 ',
#   'link': 'http://v.daum.net/v/20250519190323957'}]

# %% [markdown]
# - 꼭 User-Agent를 사용하여야 하는 경우 : https://www.melon.com/chart/

# %%
# 방법1
import requests
from bs4 import BeautifulSoup
url = 'https://www.melon.com/chart/'
melonpage = requests.get(url)
melonpage.status_code
# Out:
# 406

# %%
# 방법2
from urllib.request import urlopen, Request
# melonpage = urlopen(url) # 에러남

# %%
# User-Agent 추가
headers = {'user-agent':
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36'
}
# 방법2
request = Request(url, headers=headers)
melonpage = urlopen(request)
# 방법1
melonpage = requests.get(url, headers=headers)
soup = BeautifulSoup(melonpage.text, # melonpage.content
                     "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>멜론차트&gt;TOP100&gt;멜론</title>
# <meta content="음악서비스, 멜론차트, 멜론TOP100, 최신음악, 인기가요, 뮤직비디오, 앨범, 플레이어, 스트리밍, 다운로드, 아티스트플러스, 아티스트채널" name="keywords"/>
# <meta content="No.1 뮤직플랫폼 멜론! 최신 트렌드부터 나를 아는 똑똑한 음악추천까지!" name="description"/>
# <meta content="ee85ff6db1fa8f2226bcb671ecb2bcdbcffb6f8b" name="naver-site-verification"/>
# <meta content="q4tbTQhmxa4La3OdNLsNOCxrJ_WV6lUlBFrFW4-HqQc" name="google-site-verification"/>
# <meta content="4022717807957185" property="fb:app_id"/>
# <meta content="Melon" property="og:title"/>
# <meta content="https://cdnimg.melon.co.kr/resource/image/web/common/logo_melon142x99.png" property="og:image"/>
# <meta content="음악이 필요한 순간, 멜론" property="og:description"/>
# <meta content="http://www.melon.com/chart/" property="og:url"/>
# <meta content="website" property="og:type"/>
# <meta content="멜론" property="og:site_name"/>
# <meta content="width=device-width" name="viewport"/>
# <link href="/favicon.ico?2" id="favicon" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://static.melon.co.kr/static/web/resource/style/w1/9d/x/e9gkymzs.css" rel="stylesheet" type="text/css"/>
# <link href="https://static.melon.co.kr/static/web/resource/style/w1/l8/i/bmqlrmeyi7uljr5.css" rel="stylesheet" type="text/css"/>
# <!-- 댓글 css 파일 네임 변경 -->
# <link href="https://static.melon.co.kr/static/web/resource/style/w1/dn/4/ynesuqe51i.css" rel="stylesheet" type="text/css"/>
# <link href="/resource/style/web/chart/melonweb_chart_4x.css" rel="stylesheet" type="text/css"/>
# <link href="https://static.melon.co.kr/static/web/resource/style/w1/qa/5/rlbqwv6hljdyw.css" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/css?family=Nunito:400" rel="stylesheet"/>
# <script src="/resource/script/cds/common/web/member_api.js" type="text/javascript"></script>
# <script src="/resource/script/cds/common/web/commerce_api.js" type="text/javascript"></script>
# <script src="/resource/script/web/common/jquery-1.9.1.min.js" type="text/javascript"></script>
# <script src="https://member.melon.com/resource/script/web/member/melonweb_member_external.js?tm=20250528" type="text/javascript"></script>
# <script src="https://static.melon.co.kr/static/web/resource/script/w1/c1/d/7j9pwitvgh7.js" type="text/javascript"></script>
# <script type="text/javascript">
# 	(function() {
# 		WEBPOCIMG = {
# 			defaultImg : function(obj, width){
# 				if(width == null || width == '') width = $(obj).width();
# 				if(width == 0) width = 500;
# 				var thumbType = "_500";
# 				//가장 큰사이즈로 리사이즈함
# 				var thumbType = "_500";
# 				var defaultImg = "//cdnimg.melon.co.kr/resource/image/web/default/noAlbum" + thumbType + "_160727.jpg/melon/resize/" + width;
# 				if(obj.src != defaultImg){
# 					obj.src = defaultImg;
# 				}
# 			},
#
# 			defaultAlbumImg : function(obj, width){
# 				if(width == null || width == '') width = $(obj).width();
# 				if(width == 0) width = 500;
# 				//가장 큰사이즈로 리사이즈함
# 				var thumbType = "_500";
# 				var defaultImg = "//cdnimg.melon.co.kr/resource/image/web/default/noAlbum" + thumbType + "_160727.jpg/melon/resize/" + width;
# 				if(obj.src != defaultImg){
# 					obj.src = defaultImg;
# 				}
# 			},
#
# 			defaultArtistImg : function(obj, width){
# 				if(width == null || width == '') width = $(obj).width();
# 				if(width == 0) width = 300;
# 				//가장 큰사이즈로 리사이즈함
# 				var thumbType = "_300";
# 				var defaultImg = "//cdnimg.melon.co.kr/resource/image/web/default/noArtist" + thumbType + "_160727.jpg/melon/resize/" + width;
# 				if(obj.src != defaultImg){
# 					obj.src = defaultImg;
# 				}
# 			},
# 			defaultDjImg : function(obj){
# 			},
# 			defaultMvImg : function(obj, width, height){
# 				if(width == null || width == '') width = $(obj).width();
# 				if(height == null || height == '') height = $(obj).height();
#
# 				var ratio43 = Math.floor((4/3)*10)/10;
# 				var ratio169 = Math.floor((16/9)*10)/10;
# 				var ratioObj = Math.floor((width/height)*10)/10;
#
# 				var ratio = "4x3";
# 				if(ratioObj == ratio43){
# 					ratio = "4x3"; //contentsType = "mv43";
# 				} else if(ratioObj == ratio169){
# 					ratio = "16x9"; //contentsType = "mv169";
# 				} else {
# 					if(ratioObj > 1.5) ratio = "16x9";
# 					else ratio = "4x3";
# 				}
#
# 				if(width == 0) width = 640;
# 				if(height == 0) ratio = "16x9";
#
# 				//가장 큰사이즈로 리사이즈함
# 				var thumbType = "_" + ratio + "_640";
# 				var defaultImg = "//cdnimg.melon.co.kr/resource/image/web/default/noMovie" + thumbType + "_160727.jpg/melon/resize/" + width;
# 				if(obj.src != defaultImg){
# 					obj.src = defaultImg;
# 				}
# 			},
# 			defaultPlaylistImg : function(obj, width){
# 				if(width == null || width == '') width = $(obj).width();
# 				if(width == 0) width = 500;
# 				//가장 큰사이즈로 리사이즈함
# 				var thumbType = "_500";
# 				var defaultImg = "//cdnimg.melon.co.kr/resource/image/web/default/noAlbum" + thumbType + "_160727.jpg/melon/resize/" + width;
# 				if(obj.src != defaultImg){
# 					obj.src = defaultImg;
# 				}
# 			},
# 			defaultMemberImg : function(obj, width){
# 				if(width == null || width == '') width = $(obj).width();
# 				if(width == 0) width = 300;
# 				//가장 큰사이즈로 리사이즈함
# 				var thumbType = "_300";
# 				var defaultImg = "//cdnimg.melon.co.kr/resource/image/web/default/noArtist" + thumbType + "_160727.jpg/melon/resize/" + width;
# 				if(obj.src != defaultImg){
# 					obj.src = defaultImg;
# 				}
# 			},
# 			defaultPhotoImg : function(obj, width){
# 				if(width == null || width == '') width = $(obj).width();
# 				if(width == 0) width = 500;
# 				//가장 큰사이즈로 리사이즈함
# 				var thumbType = "_500";
# 				var defaultImg = "//cdnimg.melon.co.kr/resource/image/web/default/noAlbum" + thumbType + "_160727.jpg/melon/resize/" + width;
# 				if(obj.src != defaultImg){
# 					obj.src = defaultImg;
# 				}
# 			},
# 			defaultShopImg : function(obj, width){
# 				if(width == null || width == '') width = $(obj).width();
# 				if(width == 0) width = 256;
# 				//가장 큰사이즈로 리사이즈함
# 				var thumbType = "_256";
# 				var defaultImg = "//cdnimg.melon.co.kr/resource/image/web/default/noProduct" + thumbType + "_160727.jpg/melon/resize/" + width;
# 				if(obj.src != defaultImg){
# 					obj.src = defaultImg;
# 				}
# 			},
# 			defaultShowwingImg : function(obj, width){
# 				if(width == null || width == '') width = $(obj).width();
#
# 				var thumbType = "_256";
# 				if(width > 0 && width <= 300){
# 					thumbType = "_256";
# 				} else {
# 					thumbType = "_313";//추후 조절값
# 				}
# 				var altSrc = "//cdnimg.melon.co.kr/resource/image/web/default/noShowing" + thumbType + ".jpg";
# 				if(obj.src != altSrc){
# 					obj.src = altSrc;
# 				}
# 			},
# 			defaultTicketImg : function(obj, width){
# 				if(width == null || width == '') width = $(obj).width();
#
# 				var thumbType = "_256";
# 				if(width > 0 && width <= 300){
# 					thumbType = "_256";
# 				} else {
# 					thumbType = "_313";//추후 조절값
# 				}
# 				var altSrc = "//cdnimg.melon.co.kr/resource/image/web/default/noTicket" + thumbType + ".png";
# 				if(obj.src != altSrc){
# 					obj.src = altSrc;
# 				}
# 			},
# 			defaultSmartRadioImg : function(obj, width){
# 				if(width == null || width == '') width = $(obj).width();
# 				var defaultImg = "//cdnimg.melon.co.kr/resource/image/web/default/noSmartradio_59_160727.jpg/melon/resize/" + width;
# 				if(obj.src != defaultImg){
# 					obj.src = defaultImg;
# 				}
# 			},
# 			defaultConcertImg : function(obj, width){
# 				if(width == null || width == '') width = $(obj).width();
# 				var defaultImg = "//cdnimg.melon.co.kr/resource/image/web/default/noAlbum_114_160727.jpg/melon/resize/" + width;
# 				if(obj.src != defaultImg){
# 					obj.src = defaultImg;
# 				}
# 			}
# 		}
# 		,WEBELLIPSIS = {
# 			ellipsis : function(ellipsisName,moreClassName,eWidth){
# 		        //아티스트 더보기
# 		        var arObj = $('.' + ellipsisName);
# 		        for(var i = 0; i < arObj.length; i++){
# 		            if (arObj.eq(i).width() > eWidth ){
# 		                arObj.eq(i).parent().parent().parent().find('.' + moreClassName).show();
# 		            }
# 		        }
# 			}
# 		}
# 	})();
# 	</script>
# </head>
# <body>
# <div id="wrap">
# <div id="skip_nav">skip navigation
# 		<ul>
# <li><a href="#gnb_menu">메뉴</a></li>
# <li><a href="#conts_section">본문</a></li>
# <li><a href="#footer">하단 정보</a></li>
# </ul>
# </div>
# <!--  header -->
# <div class="gnb2_expn" id="header">
# <div class="my_fold" id="header_wrap"> <!-- 1024이상 마이영역 접었을때 클래스 my_fold 추가 -->
# <div class="clfix" id="gnb">
# <!-- 상단 빠른 메뉴 -->
# <div id="util_menu">
# <p class="none">상단 빠른 메뉴</p>
# <div class="top_left">
# <ul class="clfix">
# <li class="first_child d_melon_ticket"><a class="menu01 mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=V08&amp;ACTION_AF_CLICK=V1" href="//ticket.melon.com/main/index.htm" title="멜론 티켓"><span>멜론 티켓</span></a></li>
# </ul>
# </div>
# <!-- 140603_수정 -->
# <div class="top_right">
# <ul class="clfix">
# <li class="first_child"><a class="menu01 mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=B01&amp;ACTION_AF_CLICK=V1" href="/commerce/pamphlet/web/sale_listMainView.htm" title="이용권구매"><span>이용권구매</span></a></li>
# <li><a class="menu02 mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=V06&amp;ACTION_AF_CLICK=V1" href="/event/vip/index.htm" title="멜론라운지"><span>멜론라운지</span></a></li>
# <li><a class="menu03 mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=B03&amp;ACTION_AF_CLICK=V1" href="/event/list.htm" title="이벤트"><span>이벤트</span></a></li>
# <li class="last_child"><a class="menu04 mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=V02&amp;ACTION_AF_CLICK=V1" href="//www.melon.com/customer/announce/index.htm" title="공지사항"><span>공지사항</span></a></li>
# </ul>
# <script type="text/javascript">
# 							var html = '';
# 							var logoutReturnUrl = window.location.href;
#
# 							if(logoutReturnUrl == ''){
# 								logoutReturnUrl = 'www.melon.com';
# 							}
#
# 							if(isMelonLogin()){
#
# 								var memberKey = getMemberKey()
# 								var memberInfo = svcMember.displayIdByMemberKey(memberKey);
# 								var memberType = svcMember.getMemberType().MEMBERTYPE;
# 								var gradeInfo = svcMember.gradeInfoByMemberKey(memberKey);
#
# 								var memId = '';
# 								if(memberType == undefined || memberType == null){
# 									memberType = '0';
# 								}
#
# 								if(memberInfo.DISPLAYID != undefined || memberInfo.DISPLAYID != null){
# 									memId = memberInfo.DISPLAYID;
# 								}
#
# 								if(memId.indexOf("@") != -1 && memberType != '1'){//카카오계정이 아닌경우에만 @도메인 영역 삭제처리
# 									memId = memId.split("@")[0];
# 								}
#
# 								var fromMPS = getCookie("MPS"); // 멜론 플레이어에서 왔는지 확인.
# 								var fromMPSYn = fromMPS == null || fromMPS.indexOf("MELONPLAYER") < 0;
#
# 								var gradeImg = "";
# 								var gradeName = gradeInfo.GRADE;
# 								var gradeImageUrl = gradeInfo.HTTPSIMAGEURL;
#
# 								if(gradeName == undefined || gradeName == null){
# 									gradeName = '일반';
# 								}
#
# 								try {
#
# 									gradeImageUrl = gradeImageUrl.replace('http:','');
#
# 									if(gradeName == '일반'){
# 										gradeImageUrl = "";
# 									}
#
# 									if(gradeImageUrl != ''){
# 										gradeImg = "<span class=\"icon_logon\"><img src=\""+gradeImageUrl+"\" width=\"18\" height=\"18\" alt=\""+gradeName+"\" /></span>";
# 									}
# 									//카카오연동확인
# 									if(memberType == '1'){
# 										gradeImg += '<span class="icon_logon"><img src="//cdnimg.melon.co.kr/resource/image/web/common/icon_kakao.png" width="18" height="18" alt="kakao"></span>';
# 									}
# 								} catch (e) {}
#
# 								var logoutButtonHtml = '<button type="button" title="로그아웃" class="btn_top_logout" onclick="javascript:MELON.WEBSVC.POC.logout(\'\');"><img src="//cdnimg.melon.co.kr/resource/image/web/common/btn_top_logout.png" width="44" height="12" alt="로그아웃"></button>';
#
# 								html = ['<div class="header_login">',
# 									' <span class="icon_grade">',
# 									'' + gradeImg + '',
# 									' </span>',
# 									' <span class="wrap_id"><a href="javascript:location.href=_getHttpsMemberDomain()+ \'/muid/web/help/myinfointro_inform.htm\';" class="user_id"><strong>' + memId + '</strong></a> 님</span>',
# 									fromMPSYn ? logoutButtonHtml : '', //멜론 플레이어에서 로그아웃 싱크 안맞는 이슈로 인해 로그아웃 멜론 플레이어에서 왔을 시 버튼 제거
# 									'</div>'
# 								].join('');
# 								document.write(html);
# 							}
# 						</script>
# </div>
# <!-- //140603_수정 -->
# </div>
# <!-- //상단 빠른 메뉴 -->
# <!-- 140603_수정 -->
# <h1><a class="mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=M01&amp;ACTION_AF_CLICK=V1" href="//www.melon.com/index.htm" title="MelOn 로고 - 홈으로 이동"><img alt="Melon" height="99" src="https://cdnimg.melon.co.kr/resource/image/web/common/logo_melon142x99.png" width="142"/></a></h1>
# <!-- //140603_수정 -->
# <!-- 통합검색 영역 -->
# <fieldset>
# <legend>통합검색영역</legend>
# <input id="top_search" name="" onkeypress="if(event.keyCode == 13){goSearch();}" placeholder="" style="width:249px" title="검색 입력 편집창" type="text"/><input id="keywordLink" name="keywordLink" type="hidden" value=""/>
# <button class="btn_icon btn_auto close" id="top_search_autocomplete_toggle" style="display: none;" title="자동검색 펼침" type="button"><span class="odd_span">자동검색 펼침</span></button> <!-- open/close 클래스 사용 -->
# <button class="btn_icon search_m" title="검색" type="button"><span class="odd_span">검색</span></button>
# <div class="auto_complete" id="top_search_autocomplete"><div class="auto_complete_cont" style="display:block;"><!-- 자동완성 레이어 --></div></div>
# <div class="auto_complete" id="top_search_autocomplete_template" style="display: none;"> <!-- 자동완성 레이어 템플릿 -->
# <!-- 텍스트 결과 -->
# <ul class="text_result">
# <li><a class="autocomplete-label" href="#"></a></li>
# </ul>
# <!-- 섬네일 결과 -->
# <ul class="thumb_result">
# <li class="cate"></li>
# <li class="class02">
# <a href="#">
# <span class="thumb_40">
# <span class="thumb_frame"></span>
# <img alt="" class="autocomplete-img" height="40" width="40"/>
# </span>
# <div class="info">
# <span class="autocomplete-label"></span><br/>
# <span><span class="f11 autocomplete-info"></span></span>
# </div>
# </a>
# </li>
# </ul>
# <!-- 검색어가 없을 때 -->
# <ul class="text_result">
# <li class="result_none">
# <span>해당글자로 시작하는 단어가 없습니다.</span>
# </li>
# </ul>
# </div>
# </fieldset>
# <form action="" id="searchFrm" method="get" style="display: none">
# <input name="q" type="hidden"/>
# <input name="section" type="hidden"/>
# </form>
# <!-- //통합검색 영역 -->
# <!-- 실시간 검색어 -->
# <div class="realtime_soar_keyword">
# <!-- 140519_수정 -->
# <a class="title" href="#none">급상승 키워드</a>
# <!-- //140519_수정 -->
# <div class="keyword_overlay">
# <ol style="overflow:hidden; height:20px;">
# </ol>
# <!-- 140423_추가 -->
# <!-- //140423_추가 -->
# </div>
# </div>
# <!-- //실시간 검색어 -->
# <!-- 배너 영역 -->
# <div class="cmn_banner"></div>
# </div>
# <!-- 140314_gnb마크업 수정 -->
# <div id="gnb_menu">
# <ul>
# <li class="nth1 on">
# <a class="cur_menu mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=R01&amp;ACTION_AF_CLICK=V1" href="//www.melon.com/chart/index.htm"><span class="cur_status none">현재 선택된 메뉴-</span><span class="menu_bg menu01">멜론차트</span></a>
# <div class="lay_menu">
# <ul>
# <li class="first_child on"><a href="//www.melon.com/chart/index.htm"><span class="menu_chart m1">TOP100</span></a></li>
# <li class=""><a href="//www.melon.com/chart/hot100/index.htm"><span class="menu_chart m6">HOT100</span></a></li><!-- // MELONUIT-2465 -->
# <li class=""><a href="//www.melon.com/chart/day/index.htm"><span class="menu_chart m2">일간</span></a></li>
# <li class=""><a href="//www.melon.com/chart/week/index.htm"><span class="menu_chart m3">주간</span></a></li>
# <li class=""><a href="//www.melon.com/chart/month/index.htm"><span class="menu_chart m4">월간</span></a></li>
# <li class=""><a href="//www.melon.com/chart/age/index.htm"><span class="menu_chart m5">시대</span></a></li>
# </ul>
# <div class="chart_finder">
# <button class="btn_chart_f" onclick="location.href='//www.melon.com/chart/search/index.htm'" type="button"><span class="odd_span">차트 파인더</span></button>
# </div>
# </div>
# </li>
# <li class="nth2">
# <a class="cur_menu mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=C01&amp;ACTION_AF_CLICK=V1" href="//www.melon.com/new/index.htm"><span class="cur_status none">현재 선택된 메뉴-</span><span class="menu_bg menu02">최신 음악</span></a>
# <div class="lay_menu">
# <ul>
# <li class="first_child"><a href="//www.melon.com/new/index.htm"><span class="menu_new m1">최신곡</span></a></li>
# <li class=""><a href="//www.melon.com/new/album/index.htm"><span class="menu_new m2">최신앨범</span></a></li>
# <li class=""><a href="//www.melon.com/new/mv/index.htm"><span class="menu_new m3">최신 뮤직비디오</span></a></li>
# </ul>
# </div>
# </li>
# <li class="nth3">
# <a class="cur_menu mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=C03&amp;ACTION_AF_CLICK=V1" href="//www.melon.com/genre/song_list.htm?gnrCode=GN0100"><span class="cur_status none">현재 선택된 메뉴-</span><span class="menu_bg menu03">장르 음악</span></a>
# <div class="lay_menu">
# <ul>
# <li class="first_child"><a href="//www.melon.com/genre/song_list.htm?gnrCode=GN0100"><span class="menu_gnr nm1">한국대중음악</span></a></li>
# <li class=""><a href="//www.melon.com/genre/song_list.htm?gnrCode=GN0900"><span class="menu_gnr nm2">해외POP음악</span></a></li>
# <li class=""><a href="//www.melon.com/genre/song_list.htm?gnrCode=GN1500"><span class="menu_gnr nm3">그외 인기장르</span></a></li>
# </ul>
# </div>
# </li>
# <li class="nth4">
# <a class="cur_menu mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=S04&amp;ACTION_AF_CLICK=V1" href="//www.melon.com/dj/today/djtoday_list.htm"><span class="cur_status none">현재 선택된 메뉴-</span><span class="menu_bg menu04">멜론DJ</span></a>
# <div class="lay_menu">
# <ul>
# <li class="first_child"><a href="//www.melon.com/dj/today/djtoday_list.htm"><span class="menu_dj m1">오늘은 뭘 듣지</span></a></li>
# <li class=""><a href="//www.melon.com/dj/essential/djessential_list.htm"><span class="menu_dj m2">전문가 선곡</span></a></li>
# <li class=""><a href="//www.melon.com/dj/themegenre/djthemegenre_list.htm"><span class="menu_dj m3">#테마장르</span></a></li>
# <li class=""><a href="//www.melon.com/dj/powerdj/djpowerdj_list.htm"><span class="menu_dj m4">파워DJ</span></a></li>
# <li class=""><a href="//www.melon.com/dj/chart/djchart_list.htm"><span class="menu_dj m5">인기</span></a></li>
# </ul>
# </div>
# </li>
# <li class="nth5">
# <a class="cur_menu mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=S05&amp;ACTION_AF_CLICK=V1" href="//www.melon.com/tv/index.htm"><span class="cur_status none">현재 선택된 메뉴-</span><span class="menu_bg menu05">멜론TV</span></a>
# <div class="lay_menu">
# <ul>
# <li class="first_child"><a href="//www.melon.com/tv/index.htm"><span class="menu_tv m1">오늘은 뭘 볼까</span></a></li>
# <li class=""><a href="//www.melon.com/tv/mv/index.htm"><span class="menu_tv m2">뮤직비디오</span></a></li>
# <li class=""><a href="//www.melon.com/tv/menu/index.htm?menuSeq=1"><span class="menu_tv m3">멜론 오리지널</span></a></li>
# <li class=""><a href="//www.melon.com/tv/menu/index.htm?menuSeq=4"><span class="menu_tv m4">아티스트 업데이트</span></a></li>
# <li class=""><a href="//www.melon.com/tv/menu/index.htm?menuSeq=3"><span class="menu_tv m5">방송</span></a></li>
# </ul>
# </div>
# </li>
# <li class="nth6">
# <a class="cur_menu mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=S07&amp;ACTION_AF_CLICK=V1" href="//www.melon.com/artistplus/todayupdate/index.htm"><span class="cur_status none">현재 선택된 메뉴-</span><span class="menu_bg menu06">스타포스트</span></a>
# <div class="lay_menu">
# <ul>
# <li class="first_child"><a href="//www.melon.com/artistplus/todayupdate/index.htm"><span class="menu_arti m1">NOW</span></a></li>
# <li class=""><a href="//www.melon.com/artistplus/artistchart/index.htm"><span class="menu_arti m3">아티스트 랭킹</span></a></li>
# <li class=""><a href="//www.melon.com/artistplus/myranking/index.htm"><span class="menu_arti m4">마이 랭킹</span></a></li>
# </ul>
# <div class="menu_artist_btn">
# <div class="artist_fan">
# <button class="btn_fan" onclick="MELON.WEBSVC.POC.menu.goMyMusicFanSignArtist();" type="button"><span class="odd_span">팬맺은 아티스트</span></button>
# </div>
# <div class="artist_finder">
# <button class="btn_artist_f" onclick="location.href='//www.melon.com/artistplus/finder/index.htm'" type="button"><span class="odd_span">아티스트 파인더</span></button>
# </div>
# </div>
# </div>
# </li>
# <!-- 160314 수정 -->
# <li class="nth7">
# <a class="cur_menu mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=S09&amp;ACTION_AF_CLICK=V1" href="//www.melon.com/musicstory/today/index.htm"><span class="cur_status none">현재 선택된 메뉴-</span><span class="menu_bg menu07">매거진</span></a>
# </li>
# <!-- // 160314 수정 -->
# <li class="nth8">
# <a class="cur_menu mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=S11&amp;ACTION_AF_CLICK=V1" href="//www.melon.com/melonaward/weekAward.htm"><span class="cur_status none">현재 선택된 메뉴-</span><span class="menu_bg menu08">뮤직어워드</span></a>
# </li>
# <li class="nth11 last_child">
# <a class="cur_menu" href="https://musicwave.melon.com"><span class="cur_status none">현재 선택된 메뉴-</span><span class="menu_bg menu11">뮤직웨이브</span></a>
# </li>
# </ul>
# <ul class="sub_gnb">
# <li class="">
# <a class="cur_menu mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=S01&amp;ACTION_AF_CLICK=V1" href="javascript:MELON.WEBSVC.POC.menu.goMyMusicMain();"><span class="cur_status none">현재 선택된 메뉴-</span><span class="menu_bg menu09">마이뮤직</span></a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <!-- //header -->
# <div class="clfix" id="cont_wrap">
# <div class="my_fold" id="conts_section">
# <!-- contents -->
# <!-- contents -->
# <div id="conts">
# <div class="page_header">
# <h2 class="title">TOP100</h2> <!-- MELONUIT-1980(24hit > top100) -->
# <div class="tooltip">
# <button class="button_icons etc tooltip" data-control="dropdown" type="button"><span class="none">툴팁보기</span></button>
# <div class="layer_popup" role="dialog">
# <p class="desc">최근 24시간 동안의 이용량과 최근 1시간의 이용량을 반영한 차트이며, 이용량은 스트리밍 40%+다운로드 60%를 기준으로 집계, 매 시간 업데이트 됩니다.<br/>
# 									차트 왜곡을 막기 위해 이용자가 적은 심야와 이른 오전 01시~07시에는 최근 24시간 이용량을 100% 반영한 차트를 발행합니다.<br/>
# 									반영 비율이 달라지는 01시·08시 차트에는 순위 변화를 제공하지 않습니다.
# 								<button class="button_icons etc close d_close" type="button"><span class="none">닫기</span></button>
# </p></div>
# </div>
# </div>
# <div class="multi_row">
# <!-- 시간선택 -->
# <div class="calendar_prid mt12">
# <span class="yyyymmdd">
# <span class="year">2025.05.28</span>
# </span>
# <span class="hhmm">
# <span class="hour">17:00</span>
# </span>
# <div class="time_layer">
# <button class="button_icons etc arrow_d" data-control="dropdown" title="시간선택" type="button">
# <span class="none">시간선택</span>
# </button>
# <div class="l_popup" style="display: none;">
# <div class="box_scroll">
# <ul class="time_list">
# <li><a class="timelist" data-time-value="2025052817" href="#"><span class="time">17:00</span></a></li>
# <li><a class="timelist" data-time-value="2025052816" href="#"><span class="time">16:00</span></a></li>
# <li><a class="timelist" data-time-value="2025052815" href="#"><span class="time">15:00</span></a></li>
# <li><a class="timelist" data-time-value="2025052814" href="#"><span class="time">14:00</span></a></li>
# <li><a class="timelist" data-time-value="2025052813" href="#"><span class="time">13:00</span></a></li>
# <li><a class="timelist" data-time-value="2025052812" href="#"><span class="time">12:00</span></a></li>
# <li><a class="timelist" data-time-value="2025052811" href="#"><span class="time">11:00</span></a></li>
# <li><a class="timelist" data-time-value="2025052810" href="#"><span class="time">10:00</span></a></li>
# <li><a class="timelist" data-time-value="2025052809" href="#"><span class="time">09:00</span></a></li>
# <li><a class="timelist" data-time-value="2025052808" href="#"><span class="time">08:00</span></a></li>
# <li><a class="timelist" data-time-value="2025052807" href="#"><span class="time">07:00</span></a></li>
# <li><a class="timelist" data-time-value="2025052806" href="#"><span class="time">06:00</span></a></li>
# <li><a class="timelist" data-time-value="2025052805" href="#"><span class="time">05:00</span></a></li>
# <li><a class="timelist" data-time-value="2025052804" href="#"><span class="time">04:00</span></a></li>
# <li><a class="timelist" data-time-value="2025052803" href="#"><span class="time">03:00</span></a></li>
# <li><a class="timelist" data-time-value="2025052802" href="#"><span class="time">02:00</span></a></li>
# <li><a class="timelist" data-time-value="2025052801" href="#"><span class="time">01:00</span></a></li>
# <li><a class="timelist" data-time-value="2025052800" href="#"><span class="time">00:00</span></a></li>
# </ul>
# </div>
# </div>
# <!-- <span class="rank_update">순위 업데이트!</span> 순위 업데이트 시 dp MELONUIT-1518 삭제 -->
# </div>
# </div>
# <div class="top3 button_group">
# <!-- <button type="button" id="d_tutorial_open"><span class="text">이용안내</span><span class="button_icons etc guide"></span></button> --><!-- // MELONUIT-1518 삭제 -->
# <button id="chart_Refresh" type="button"><span class="text">새로고침</span><span class="button_icons etc refresh"></span></button>
# </div>
# </div>
# <div id="tb_list">
# <form id="frm" name="frm">
# <div class="service_list_song type02 d_song_list">
# <h3 class="none"></h3>
# <!-- 곡리스트 테이블 -->
# <div class="wrap_btn_tb top">
# <button class="button_rbox" onclick="playShuffleChart();" title="셔플듣기" type="button"><span class="button_icons shuffle"></span><span class="cnt">셔플듣기</span></button>
# <button class="button_rbox" onclick="playChart();" title="전체듣기" type="button"><span class="button_icons type02 play"></span><span class="cnt">전체듣기</span></button>
# <button class="button_rbox" onclick="melon.play.playFormSong('1000002721','frm');" title="선택된 곡 듣기" type="button"><span class="button_icons type02 play"></span><span class="cnt">듣기</span></button>
# <button class="button_rbox" onclick="melon.play.addFormPlayList('frm');" title="선택된 곡 담기" type="button"><span class="button_icons type02 scrap"></span><span class="cnt">담기</span></button>
# <button class="button_rbox" onclick="melon.buy.goBuyProduct('frm','','3C0001','input_check','0','1000002721');" title="선택된 곡 다운로드" type="button"><span class="button_icons type02 download"></span><span class="cnt">다운</span></button>
# <button class="button_rbox" onclick="melon.buy.goBuyProduct('frm','','3C0001','input_check','110','1000002721');" title="선택된 곡 원음다운로드" type="button"><span class="button_icons type02 download"></span><span class="cnt"><span class="eng">FLAC</span></span></button>
# <button class="button_rbox" onclick="melon.buy.goPresent('song', 'frm', '1000002721');" title="선택된 곡 선물하기" type="button"><span class="button_icons type02 gift"></span><span class="cnt">선물</span></button>
# </div>
# <table border="1" style="width:100%">
# <caption>이 표는 곡 리스트로 체크박스, 순위, 곡정보, 좋아요, 뮤비, 다운, 폰전송 내용을 포함하고 있으며 표 상 하단에 제공하는 전체선택, 듣기, 다운로드, 담기, 선물하기 기능을 이용하실 수 있습니다.</caption>
# <colgroup>
# <col style="width: 15px"/><!-- checkbox -->
# <col style="width: 62px"/><!-- 순서 & 순위 -->
# <col style="width: 50px"/><!-- 순위등락 -->
# <col style="width: 60px"/><!-- 앨범이미지 -->
# <col style="width: 24px"/><!-- 곡 상세가기 -->
# <col/><!-- 곡정보 -->
# <col style="width: 190px"/><!-- 앨범 -->
# <col style="width: 111px"/><!-- 좋아요 -->
# <col style="width: 58px"/><!-- 듣기 -->
# <col style="width: 52px"/><!-- 담기 -->
# <col style="width: 52px"/><!-- 다운 -->
# <col style="width: 52px"/><!-- 뮤비 -->
# </colgroup>
# <thead>
# <tr>
# <th scope="col">
# <div class="wrap t_right"><input class="input_check d_checkall" title="곡 목록 전체 선택" type="checkbox"/></div>
# </th>
# <th scope="col">
# <div class="wrap t_center"><span class="rank">순위</span></div>
# </th>
# <th scope="col">
# <div class="wrap none">순위등락</div>
# </th>
# <th scope="col">
# <div class="wrap none">앨범이미지</div>
# </th>
# <th scope="col">
# <div class="wrap none">곡 상세가기</div>
# </th>
# <th scope="col">
# <div class="wrap pd_l_12">곡정보</div>
# </th>
# <th scope="col">
# <div class="wrap pd_l_12">앨범</div>
# </th>
# <th scope="col">
# <div class="wrap pd_l_30">좋아요</div>
# </th>
# <th scope="col">
# <div class="wrap t_center">듣기</div>
# </th>
# <th scope="col">
# <div class="wrap t_center">담기</div>
# </th>
# <th scope="col">
# <div class="wrap t_center">다운</div>
# </th>
# <th scope="col">
# <div class="wrap t_center">뮤비</div>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr class="lst50" data-song-no="38626852" id="lst50">
# <td><div class="wrap t_right"><input class="input_check" name="input_check" title="너에게 닿기를 곡 선택" type="checkbox" value="38626852"/></div></td>
# <td><div class="wrap t_center"><span class="rank">1</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11730411');" title="너에게 닿기를">
# <img alt="너에게 닿기를 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/117/30/411/11730411_20250306095101_500.jpg/melon/resize/120/quality/80/optimize" width="60">
# <span class="bg_album_frame"></span>
# </img></a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('38626852');" title="너에게 닿기를 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('1000002721',38626852);" title="너에게 닿기를 재생">너에게 닿기를</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('468244');" title="10CM - 페이지 이동">10CM</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('468244');" title="10CM - 페이지 이동">10CM</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11730411');" title="너에게 닿기를 - 페이지 이동">너에게 닿기를</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="1000002721" data-song-no="38626852" title="너에게 닿기를 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play" onclick="melon.play.playSong('1000002721',38626852);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap" onclick="melon.play.addPlayList('38626852');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '38626852', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '38626852','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# </tr>
# <tr class="lst50" data-song-no="39051429" id="lst50">
# <td><div class="wrap t_right"><input class="input_check" name="input_check" title="Never Ending Story 곡 선택" type="checkbox" value="39051429"/></div></td>
# <td><div class="wrap t_center"><span class="rank">2</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11831781');" title="꽃갈피 셋">
# <img alt="꽃갈피 셋 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/118/31/781/11831781_20250526162725_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('39051429');" title="Never Ending Story 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('1000002721',39051429);" title="Never Ending Story 재생">Never Ending Story</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('261143');" title="아이유 - 페이지 이동">아이유</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('261143');" title="아이유 - 페이지 이동">아이유</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11831781');" title="꽃갈피 셋 - 페이지 이동">꽃갈피 셋</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="1000002721" data-song-no="39051429" title="Never Ending Story 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play" onclick="melon.play.playSong('1000002721',39051429);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap" onclick="melon.play.addPlayList('39051429');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '39051429', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '39051429','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# </tr>
# <tr class="lst50" data-song-no="36397952" id="lst50">
# <td><div class="wrap t_right"><input class="input_check" name="input_check" title="Drowning 곡 선택" type="checkbox" value="36397952"/></div></td>
# <td><div class="wrap t_center"><span class="rank">3</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11183506');" title="OO-LI">
# <img alt="OO-LI - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/111/83/506/11183506_20230426141236_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('36397952');" title="Drowning 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('1000002721',36397952);" title="Drowning 재생">Drowning</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('2086047');" title="WOODZ - 페이지 이동">WOODZ</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('2086047');" title="WOODZ - 페이지 이동">WOODZ</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11183506');" title="OO-LI - 페이지 이동">OO-LI</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="1000002721" data-song-no="36397952" title="Drowning 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play" onclick="melon.play.playSong('1000002721',36397952);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap" onclick="melon.play.addPlayList('36397952');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '36397952', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video disabled" disabled="disabled" onclick="melon.link.goMvDetail('1000002721', '36397952','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# </tr>
# <tr class="lst50" data-song-no="38629386" id="lst50">
# <td><div class="wrap t_right"><input class="input_check" name="input_check" title="like JENNIE 곡 선택" type="checkbox" value="38629386"/></div></td>
# <td><div class="wrap t_center"><span class="rank">4</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11730946');" title="Ruby">
# <img alt="Ruby - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/117/30/946/11730946_20250307173452_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('38629386');" title="like JENNIE 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('1000002721',38629386);" title="like JENNIE 재생">like JENNIE</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('995173');" title="제니 (JENNIE) - 페이지 이동">제니 (JENNIE)</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('995173');" title="제니 (JENNIE) - 페이지 이동">제니 (JENNIE)</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11730946');" title="Ruby - 페이지 이동">Ruby</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="1000002721" data-song-no="38629386" title="like JENNIE 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play" onclick="melon.play.playSong('1000002721',38629386);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap" onclick="melon.play.addPlayList('38629386');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '38629386', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '38629386','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# </tr>
# <tr class="lst50" data-song-no="38429074" id="lst50">
# <td><div class="wrap t_right"><input class="input_check" name="input_check" title="모르시나요(PROD.로코베리) 곡 선택" type="checkbox" value="38429074"/></div></td>
# <td><div class="wrap t_center"><span class="rank">5</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11685729');" title="모르시나요">
# <img alt="모르시나요 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/116/85/729/11685729_20250106160640_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('38429074');" title="모르시나요(PROD.로코베리) 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('1000002721',38429074);" title="모르시나요(PROD.로코베리) 재생">모르시나요(PROD.로코베리)</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('3186091');" title="조째즈 - 페이지 이동">조째즈</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('3186091');" title="조째즈 - 페이지 이동">조째즈</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11685729');" title="모르시나요 - 페이지 이동">모르시나요</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="1000002721" data-song-no="38429074" title="모르시나요(PROD.로코베리) 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play" onclick="melon.play.playSong('1000002721',38429074);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap" onclick="melon.play.addPlayList('38429074');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '38429074', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '38429074','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# </tr>
# <tr class="lst50" data-song-no="39040959" id="lst50">
# <td><div class="wrap t_right"><input class="input_check" name="input_check" title="THUNDER 곡 선택" type="checkbox" value="39040959"/></div></td>
# <td><div class="wrap t_center"><span class="rank">6</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11829498');" title="SEVENTEEN 5th Album ‘HAPPY BURSTDAY’">
# <img alt="SEVENTEEN 5th Album ‘HAPPY BURSTDAY’ - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/118/29/498/11829498_20250526100446_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('39040959');" title="THUNDER 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('1000002721',39040959);" title="THUNDER 재생">THUNDER</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('861436');" title="세븐틴 (SEVENTEEN) - 페이지 이동">세븐틴 (SEVENTEEN)</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('861436');" title="세븐틴 (SEVENTEEN) - 페이지 이동">세븐틴 (SEVENTEEN)</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11829498');" title="SEVENTEEN 5th Album ‘HAPPY BURSTDAY’ - 페이지 이동">SEVENTEEN 5th Album ‘HAPPY BURSTDAY’</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="1000002721" data-song-no="39040959" title="THUNDER 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play" onclick="melon.play.playSong('1000002721',39040959);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap" onclick="melon.play.addPlayList('39040959');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '39040959', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '39040959','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# </tr>
# <tr class="lst50" data-song-no="38589554" id="lst50">
# <td><div class="wrap t_right"><input class="input_check" name="input_check" title="TOO BAD (feat. Anderson .Paak) 곡 선택" type="checkbox" value="38589554"/></div></td>
# <td><div class="wrap t_center"><span class="rank">7</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11722169');" title="Übermensch">
# <img alt="Übermensch - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/117/22/169/11722169_20250224160403_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('38589554');" title="TOO BAD (feat. Anderson .Paak) 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('1000002721',38589554);" title="TOO BAD (feat. Anderson .Paak) 재생">TOO BAD (feat. Anderson .Paak)</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('6984');" title="G-DRAGON - 페이지 이동">G-DRAGON</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('6984');" title="G-DRAGON - 페이지 이동">G-DRAGON</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11722169');" title="Übermensch - 페이지 이동">Übermensch</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="1000002721" data-song-no="38589554" title="TOO BAD (feat. Anderson .Paak) 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# ...
# </div></td>
# </tr>
# </tbody>
# </table>
# </div>
# </form>
# <script type="text/javascript">
# 	$(function(){
#
# 		/* 좋아요 셋팅부 */
# 		var LIKE_SET = {
# 			likeCnt  : "<span class=\"odd_span\">{TXT}</span>\n<span class=\"cnt\">\n<span class=\"none\">총건수</span>\n{CNT}</span>",
# 			likeObj  : $('div.d_song_list button.like'),
# 			likeAttr : 'data-song-no',
# 			likeUrl  : '/commonlike/getSongLike.json'
# 		};
#
# 		/* 좋아요 공통부 */
# 		var contsIdList = LIKE_SET['likeObj'].map(function() { return $(this).attr(LIKE_SET['likeAttr']); }).get().join(',');
# 		var tmpl, title;
# 		if ( contsIdList === '' || contsIdList === null  ) { return; }
# 		$.get(LIKE_SET['likeUrl'], { contsIds : contsIdList }, function(data) {
# 			var robj;
# 			$.each(data.contsLike, function(i, v) {
# 				var SUMMCNT = MELON.WEBSVC.number.addComma(v.SUMMCNT);
# 				robj  = LIKE_SET['likeObj'].eq(i);
# 				tmpl  = LIKE_SET['likeCnt'];
# 				title = robj.attr('title').split(' 좋아요');
# 				robj[v.LIKEYN == 'Y' ? 'addClass' : 'removeClass']('on').attr('title', title[0] + (v.LIKEYN == 'Y' ? ' 좋아요 취소' : ' 좋아요'));
# 				robj.html(
# 					tmpl.replace(/\{TXT\}/g, (v.LIKEYN == 'Y' ? '좋아요 취소' : '좋아요')).replace(/\{CNT\}/g, SUMMCNT)
# 				);
# 			});
# 		}).done(function(){
# 			//아티스트 더보기 처리
# 			var listType = 'CHART';
# 			if(listType == 'CHART'){
# 				WEBELLIPSIS.ellipsis("checkEllipsis","wrap_atist",210);
# 			}else{
# 				WEBELLIPSIS.ellipsis("checkEllipsis","wrap_atist",240);
# 			}
#
# 		});
# 	});
# 	</script>
# <!-- 차트타입 페이징 -->
# <script type="text/javascript">
#
# 				$(function(){
# 					/* 멜론 차트 곡만 듣기 */
# 					playChart = function() {
# 						var songList = $('tr').map(function() { return $(this).attr('data-song-no'); }).get();
# 						melon.play.playSong('1000002721', songList);
# 					}
#
# 					playShuffleChart = function() {
# 						var songList = $('tr').map(function() { return $(this).attr('data-song-no'); }).get();
# 						var j, x, i;
# 						for (i = songList.length; i; i -= 1) {
# 							j = Math.floor(Math.random() * i);
# 							x = songList[i - 1];
# 							songList[i - 1] = songList[j];
# 							songList[j] = x;
# 						}
# 						melon.play.playSong('1000002721', songList);
# 					}
#
# 					/* 리스트 다중 선택 */
# 					$('.input_check').optShift();
# 					/* 페이징 노출*/
# 					$('.chart_page').css({'display':''});
#
# 				});
# 			</script>
# </div>
# </div>
# <!-- //contents -->
# <script type="text/javascript">
# 		var httpWww = "http://www.melon.com";
# 		var httpsWww = "https://www.melon.com";
# 		var POC_ID = "WP10";
# 		var deployPhase = "";
# 	</script>
# <script src="/resource/script/web/common/melonweb_openlib.js" type="text/javascript"></script>
# <script src="https://static.melon.co.kr/static/web/resource/script/w1/ys/4/xiezkqccd.js" type="text/javascript"></script>
# <script src="https://static.melon.co.kr/static/web/resource/script/w1/rh/j/g6rj8w20wysnmr.js" type="text/javascript"></script>
# <script src="/resource/script/web/common/MPAPI.js?tm=20171129" type="text/javascript"></script>
# <script src="https://static.melon.co.kr/static/web/resource/script/w1/no/h/7wnxwuwuny.js" type="text/javascript"></script>
# <script src="https://static.melon.co.kr/static/web/resource/script/w1/h2/6/3ytqbprzyy7cq.js" type="text/javascript"></script>
# <!-- commit  -->
# <script src="/resource/script/web/chart/json2.js" type="text/javascript"></script>
# <script src="/resource/script/web/common/melonweb_zam.js?tm=2016042816" type="text/javascript"></script>
# <script src="https://static.melon.co.kr/static/web/resource/script/w1/8k/8/1ed5h822hvv.js" type="text/javascript"></script>
# <script src="https://static.melon.co.kr/statistics/js/mlog.28ba021f940fcdaa81ff.js" type="text/javascript"></script>
# <script src="//t1.daumcdn.net/tiara/js/v1/tiara.min.js" type="text/javascript"></script>
# <script src="/resource/script/web/event/bluebird.min.js" type="text/javascript"></script>
# <script src="/resource/script/web/common/melonweb_newtiara.js?tm=1623820031532" type="text/javascript"></script>
# <script src="/resource/script/web/clean/melonweb_clean.js?tm=20210914" type="text/javascript"></script>
# <script type="text/javascript">
# 		var melon = MELON.WEBSVC.POC;
# 		var menuId = '1000002721';
# 		if(menuId != null && menuId != ''){
# 			tiara.sendLog(menuId);
# 		}
#
# 		document.domain="melon.com";
#
# 		//pocId 쿠키설정 실행
# 		try {
# 			melon.setPocId();
# 		} catch (e){}
# 	</script>
# <script src="/resource/script/web/common/socket.io.js" type="text/javascript"></script>
# <script src="https://static.melon.co.kr/static/web/resource/script/w1/pf/z/14im3r4ty1x.js" type="text/javascript"></script>
# <script type="text/javascript">
# 	$(function() {
# 		$('#chart_Refresh').click(function() {
# 			moveTime();
# 		});
# 		$('a.timelist').click(function() {
# 			moveTime($(this).attr("data-time-value"));
# 		});
# 		moveTime = function(t) {
# 			var pUrl = "?dayTime=" + t;
# 			if ( typeof t === 'undefined') { pUrl = ""; }
# 			document.location.href = "/chart/index.htm" + pUrl;
# 		}
# 	});
# </script>
# <!-- //contents -->
# </div>
# </div>
# <!-- footer -->
# <div class="my_fold" id="footer">
# <div class="btn_top_wrap">
# <a class="btn_top" href="#skip_nav" style="" title="맨 위로 가기"><span>맨 위로 가기</span></a>
# </div>
# <!-- MELONUIT-738 -->
# <div class="wrap_pop_notice MELONUIT-738" id="popNotice">
# </div>
# <!-- //MELONUIT-738 -->
# <div class="footer_cont">
# <div class="footer_menu">
# <!-- 				<ul class="fl_left"> -->
# <!-- 					<li class="menu01 d_melon_ticket"><a href="http://ticket.melon.com/main/index.htm"><span>MelOn Ticket</span></a></li> -->
# <!-- 					<li class="menu04"><a href="http://aztweb.melon.com/aztalk/guide/web/main.htm"><span>aztalk</span></a></li> -->
# <!-- 				</ul> -->
# <ul class="fl_right">
# <!-- MELONUIT-1799 -->
# <li class="menu05" id="d_melon6"><a href="//www.melon.com/m6/campaign.htm"><span>멜론6.0 둘러보기</span></a></li>
# <!-- //MELONUIT-1799 -->
# <li class="menu10" id="d_studio"><a href="//studio.melon.com/"><span>멜론 스튜디오</span></a></li>
# <li class="menu06"><a href="//www.melon.com/customer/serviceintro/index.htm"><span>Windows 플레이어</span></a></li><!-- 160824 수정 -->
# <li class="menu07"><a href="//www.melon.com/customer/serviceintro/multi_pc_web.htm"><span>Mac 플레이어</span></a></li>
# <li class="menu09"><a href="//www.melon.com/customer/serviceintro/ipad.htm"><span>iPad</span></a></li>
# <li class="menu08"><a href="//faqs2.melon.com/customer/index.htm"><span>고객센터</span></a></li>
# </ul>
# </div>
# <ul class="footer_policy clfix">
# <li class="first_child"><a href="//info.melon.com/terms/web/terms1_1.html" target="_blank" title="이용약관 ">이용약관</a></li>
# <li><a href="//info.melon.com/terms/web/terms1_3.html" target="_blank" title="위치기반서비스 이용약관 "><strong>위치기반서비스 이용약관</strong></a></li>
# <li><a href="//info.melon.com/terms/web/terms3.html" target="_blank" title="개인정보처리방침 "><strong>개인정보처리방침</strong></a></li>
# <li><a href="//info.melon.com/terms/web/terms5_1.html" target="_blank" title="청소년보호정책">청소년보호정책</a></li>
# <li><a href="//faqs2.melon.com/customer/faq/informFaq.htm?no=1&amp;faqId=QUES20140616000001&amp;SEARCH_KEY=&amp;SEARCH_PAR_CATEGORY=CATE20130909000006&amp;SEARCH_CATEGORY=CATE20130909000021" title="제휴/프로모션문의">제휴/프로모션문의</a></li>
# <li><a href="javascript:openEmailCollectionReject();" title="이메일주소무단수집거부 ">이메일주소무단수집거부</a></li>
# <li class="last_child"><a href="//partner.melon.com/partrct/login/web/login_loginProcess.htm?t=s" target="_blank" title="파트너센터">파트너센터</a></li>
# </ul>
# <!--160531 수정 lyr-->
# <p>
# <span class="first"><strong>(주)카카오엔터테인먼트</strong>  경기도 성남시 분당구 판교역로 235, 에이치스퀘어 N동 8, 9, 10층</span>
# <span>공동대표이사 : 권기수, 장윤중</span>
# <span>사업자등록번호 : 220-88-02594</span>
# <span>통신판매업신고번호 : 2018-성남분당B-0004 <a class="btn_arrow" href="https://www.ftc.go.kr/bizCommPop.do?wrkr_no=2208802594" target="_blank" title="사업자정보확인">사업자정보확인</a></span>
# <br>
# <span class="first">문의전화 : 1566-7727 (평일 09:00-18:00, 유료)</span>
# <span>이메일 : <a class="btn_footer_mail" href="mailto:melon_info@kakaoent.com">melon_info@kakaoent.com</a></span>
# <span>호스팅서비스사업자 : (주)카카오엔터테인먼트</span>
# <span><a class="btn_footer_mail" href="//kakaoent.com" target="_blank">© Kakao Entertainment Corp.</a></span>
# </br></p>
# <!--//160531 수정 lyr-->
# <!--모바일 웹 버전, 태블릿에서만 적용됨. display none, block 으로 적용-->
# <!--140602 추가 lyr-->
# <div class="mobile_btn_wrap" style="display:none;">
# <p>접속하신 단말/브라우저에서는 멜론 서비스의 사용이 일부 제한될 수 있습니다. 양해부탁드립니다.</p>
# <a class="btn" href="#" title="모바일 웹 버전">
# <span class="odd_span">
# <span class="even_span">모바일 웹 버전</span>
# </span>
# </a>
# </div>
# <!--//140602 추가 lyr-->
# </div>
# <a class="btn_top" href="#" style="display: none;" title="맨 위로 가기">맨 위로 가기</a>
# <!-- MELONUIT-1148 20200121 ISMS 인증서 팝업 -->
# <div class="wrap_pop_notice wrap_pop_isms" id="pop_isms">
# <div class="pop_isms_inner">
# <h1 class="title">정보보호 및 개인정보보호 관리체계 인증</h1>
# <div class="cntt">
# <p class="txt01">정보보호 및 개인정보보호를 위한 일련의 조치와 활동이<br>인증기준에 적합함을 인터넷진흥원 또는 인증기간이 증명하는 제도</br></p>
# <ul class="list_isms">
# <li>[인증범위]  인터넷 서비스 운영 (카카오, 다음, 멜론)</li>
# <li>[유효기간]  2019.12.26 ~ 2022.12.25</li>
# </ul>
# </div>
# </div>
# <button class="btn_close d_close" title="닫기" type="button"><span>닫기</span></button>
# <span class="shadow"></span>
# </div>
# <!-- //MELONUIT-1148 20200121 ISMS 인증서 팝업 -->
# <script type="text/javascript">
# 			$(function() {
# 				//favicon 분기 처리
# 				var pocId = MELON.WEBSVC.POC.getPocId();
# 				if('AS20' == pocId || 'HT10' == pocId){
# 					$('link#favicon').attr('href','//cdnimg.melon.co.kr/resource/mobile40/cds/common/image/favicon.ico');
# 					$('title').text('Melon');
# 				}else if('IS20' == pocId || 'IT10' == pocId){
# 					$('link#favicon').attr('type','');
# 					$('link#favicon').attr('rel','apple-touch-icon-precomposed');
# 					$('link#favicon').attr('href','//cdnimg.melon.co.kr/resource/mobile40/cds/common/image/mobile_apple_120x120.png');
# 					$('link#favicon').after('<link rel="apple-touch-icon-precomposed" sizes="180x180" href="//cdnimg.melon.co.kr/resource/mobile40/cds/common/image/mobile_apple_180x180.png" />');
# 					$('title').text('Melon');
# 				}
#
# 				// 엣지 브라우저이고 해당 팝업이 뜬 적이 없는 경우 체크하여 팝업을 띄운다.
# 				var isEdge = (navigator.userAgent.indexOf("Edge") > 0);
# 				var edgeCheckYN = getCookie("EDGE_CHECK") != 'Y';
#
#
# 				// 타블렛이고 해당 팝업이 뜬 적이 없는 경우 체크하여 팝업을 띄운다.
# 				var tabletCheckYN = getCookie("TABLET_CHECK") != 'Y';
#
# 				if(melon.isTablet() && tabletCheckYN){
# 					window.open('//www.melon.com/error_page/error_tabletTypeA.html','tabletPopTypeA','scrollbars=no, resizable=no, location=no, width=560, height=483');
# 				}
#
# 				// 해당 쿠키가 존재하면 쿠키 삭제
# 				if(getCookie("CHECK_POP") != ''){
# 					// 체크 후 해당 쿠키는 제거
# 					var expireDate = new Date();
# 					expireDate.setDate(expireDate.getDate()-1);
# 					document.cookie = "CHECK_POP=;path=/;expires="+expireDate.toGMTString()+";domain=.melon.com";
# 				}
#
# 				if(isMelonLogin()){
# 					var djYn = false;
# 					var memberKey = getMemberKey();
#
#
# 					if(memberKey != null || memberKey != ''){
# 						var url = '/dj/members/'+memberKey+'/isdj.json';
# 						var promotionPopup = window.localStorage.getItem('promotionpopup'+getMemberKey());
#
# 						try {
# 							$.ajax({
# 								url: url,
# 								type : 'GET',
# 								dataType: 'json'
# 							}).done(function(data) {
# 								if (data != null && data.ISDJ != null && data.ISDJ.length > 0) {
# 									djYn = data.ISDJ;
# 								}
# 							}).fail(function() {
# 								djYn = false;
# 							});
#
#
# 							if(promotionPopup == null && isLoginWithin20Seconds()){
# 								var fromMPS = getCookie("MPS"); // 멜론 플레이어에서 왔는지 확인.
#
# 								// PCP이면 찌르지 않음
# 								if(POC_ID != 'VP40' && fromMPS.indexOf("MELONPLAYER") < 0) {
# 									$.ajax({
# 										url: '/commapi/v1/loginPromotion.json',
# 										type : 'GET',
# 										dataType: 'json',
# 										data : {memberKey : memberKey,
# 											pocId : getCookie("POC")}
# 									}).done(function(data) {
# 										if (data != undefined && data != null && data.PROMOTIONINFO != null && data.PROMOTIONINFO.PROMOTARGETMAP != null) {
# 											if(data.PROMOTIONINFO.PROMOTARGETMAP.promoLinkUrl != null){
# 												var promotionLinkUrl = data.PROMOTIONINFO.PROMOTARGETMAP.promoLinkUrl;
#
# 												try {
# 													var urlObj = new URL(promotionLinkUrl);
# 													var params = new URLSearchParams(urlObj.search);
# 												} catch (e) {
# 													var params = new URLSearchParams();
# 												}
#
# 												var width = params.get("width")  != null ? params.get("width") : '560';
# 												var height = params.get("height") != null ? params.get("height") : '780';
# 												var inflowCode = params.get("inflowCode") != null ? params.get("inflowCode") : '';
# 												var loginPromoId = params.get("loginPromoId") != null ? params.get("loginPromoId") : '';
#
# 												//inflowCode값이 IC0017가 아니거나, 해당 쿠키값이 존재하지 않을 떄 팝업 호출
# 												if (inflowCode != "IC0017" || getCookie('block_'+getMemberKey()+'_'+loginPromoId) == '') {
# 													window.open(promotionLinkUrl, '', 'width='+width+', height='+height+', left=50, top=100');
# 												}
#
# 												window.localStorage.setItem('promotionpopup'+getMemberKey(), '1');
# 											}
# 										}
# 									}).fail(function() {
# 										console.log('promotionPopup AJAX Failed!!!');
# 										window.localStorage.removeItem('promotionpopup'+getMemberKey());
# 									});
# 								}
# 							}
#
# 						} catch(e){}
# 					}
# 				}
#
# 				// 홈탭의 경우 쇼핑/티켓을 새창띄우기로 변경한다.
# 				var fromMPS = getCookie("MPS"); // 멜론 플레이어에서 왔는지 확인.
# 				var fromHomeTab = !(fromMPS == null || fromMPS.indexOf("MELONPLAYER") < 0);
#
# 				if(fromHomeTab){
# 					$("li.d_melon_shopping a").removeClass("mlog");
# 					$("li.d_melon_shopping a").addClass("mlog_without_page_change");
# 					$("li.d_melon_shopping a").attr("target", "_blank");
#
# 					$("li.d_melon_ticket a").removeClass("mlog");
# 					$("li.d_melon_ticket a").addClass("mlog_without_page_change");
# 					$("li.d_melon_ticket a").attr("target", "_blank");
# 				}
#
# 				//멜론 플레이어면 멜론 6.0 둘러보기 버튼 제거
# 				if(fromHomeTab){
# 					$('#d_studio').hide()
# 					$('#d_melon6').hide();
# 				}else{
# 					$('#d_studio').show()
# 					$('#d_melon6').show();
# 				}
#
# 				$(document).on('limitpopup', function( e, cookieId ) {
# 					$('#'+cookieId).modal();
# 				});
#
#
# 				//레이어 공지 제어
# 				//메인만 적용
# 				//pcp 홈탭 미적용
# 				if('10010101' == '1000002721' && !fromHomeTab){
# 					$.ajax({
# 						type : 'GET'
# 						,url : '/main/getTicketPositionProperty.json'
# 					}).done(function(response) {
#
# 						var layerPopNotiYn = response.layerPopNotiYn;
# 						var layerPopDateText = response.layerPopDateText;
# 						if(layerPopNotiYn == 'Y'){
# 							$('#d_layerPopDateText').text(layerPopDateText);
# 							setTimeout(function() {
# 								$("#popNotice").timeLimitSet({ cookieId:'popNotice',selectors:{closebtn:'#todayChk', checkbox:''} });
# 							},1);
# 							MELON.PBPGN.TimeLimitPopup.init({ cookieId:"popNotice", serverTime: new Date(), limitType:"day" });
# 							$("#popNotice .d_close").click(function() {  $("#popNotice").modal('hide'); });
# 						}
# 					});
# 				}
# 			});
#
# 			function goMelonTPage(){
# 				//t.com 종료 삭제처리
# 			}
#
# 			function isLoginWithin20Seconds() {
# 				const now = new Date();
# 				const loginTime = parseLoginTime(getLoginTime());
# 				const timeDifference = Math.abs(now - loginTime) / 1000;
# 				return timeDifference <= 20;
# 			}
#
# 			function parseLoginTime(loginTimeStr) {
# 				const year = parseInt(loginTimeStr.substring(0, 4), 10);
# 				const month = parseInt(loginTimeStr.substring(4, 6), 10) - 1;
# 				const day = parseInt(loginTimeStr.substring(6, 8), 10);
# 				const hours = parseInt(loginTimeStr.substring(8, 10), 10);
# 				const minutes = parseInt(loginTimeStr.substring(10, 12), 10);
# 				const seconds = parseInt(loginTimeStr.substring(12, 14), 10);
#
# 				return new Date(year, month, day, hours, minutes, seconds);
# 			}
#
# 			function openEmailCollectionReject(){
# 				window.open('//www.melon.com/emailCollectionReject.html','emailCollect', 'scrollbars=no, resizable=no, location=no, width=384, height=331');
# 			}
#
# 			//MELONUIT-1148 20200121 ISMS 인증서 팝업 //
# 			var popISMS = {
# 				open : function() {
# 					$('#pop_isms').modal('show');
# 				}
# 			};
#
# 			$(document).on('click', '.popISMS',function(){
# 				popISMS.open();
# 			});
# 			//MELONUIT-1148 20200121 ISMS 인증서 팝업 //
# 		</script>
# <!--//140602 추가 lyr-->
# </div>
# <!-- //footer -->
# </div>
# </body>
# </html>

# %%
# 멜론 순위, 노래제목, 가수, 좋아요갯수
# 1위 | 너에게 닿기를 | 10cm | ♥85,000

# %%
# User-Agent 추가
headers = {'user-agent':
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36'
}
# 방법1
melonpage = requests.get(url, headers=headers)
soup = BeautifulSoup(melonpage.text, # melonpage.content
                     "html.parser")

soup

# %%
title_els = soup.select('div.ellipsis.rank01 > span')
singer_els = soup.select('div.ellipsis.rank02 > span.checkEllipsis')
len([title.text.strip() for title in title_els])
len([singer.text for singer in singer_els])
for idx, (title,singer) in enumerate(zip(title_els, singer_els)):
    print('{}위 | {} - {}'.format(idx+1,
                                 title.text.strip(),
                                 singer.text))
# Out:
# 1위 | 너에게 닿기를 - 10CM
# 2위 | Never Ending Story - 아이유
# 3위 | Drowning - WOODZ
# 4위 | like JENNIE - 제니 (JENNIE)
# 5위 | 모르시나요(PROD.로코베리) - 조째즈
# 6위 | THUNDER - 세븐틴 (SEVENTEEN)
# 7위 | TOO BAD (feat. Anderson .Paak) - G-DRAGON
# 8위 | 네모의 꿈 - 아이유
# 9위 | Whiplash - aespa
# 10위 | HOME SWEET HOME (feat. 태양, 대성) - G-DRAGON
# 11위 | 나는 반딧불 - 황가람
# 12위 | 어제보다 슬픈 오늘 - 우디 (Woody)
# 13위 | 오늘만 I LOVE YOU - BOYNEXTDOOR
# 14위 | REBEL HEART - IVE (아이브)
# 15위 | HAPPY - DAY6 (데이식스)
# 16위 | 빨간 운동화 - 아이유
# 17위 | Flower - 오반(OVAN)
# 18위 | APT. - 로제 (ROSÉ), Bruno Mars
# 19위 | 청춘만화 - 이무진
# 20위 | HOT - LE SSERAFIM (르세라핌)
# 21위 | 10월 4일 - 아이유
# 22위 | 한 페이지가 될 수 있게 - DAY6 (데이식스)
# 23위 | Last Scene (Feat. 원슈타인) - 아이유
# 24위 | HBD - 세븐틴 (SEVENTEEN)
# 25위 | MY LOVE(2025) - 이예은, 아샤트리, 전건호
# 26위 | 그날이 오면 - 투모로우바이투게더
# 27위 | 내게 사랑이 뭐냐고 물어본다면 - 로이킴
# 28위 | Fly Up - RIIZE
# 29위 | Welcome to the Show - DAY6 (데이식스)
# 30위 | 소나기 - 이클립스 (ECLIPSE)
# 31위 | 천상연 - 이창섭
# 32위 | Die With A Smile - Lady Gaga, Bruno Mars
# 33위 | toxic till the end - 로제 (ROSÉ)
# 34위 | HANDS UP - MEOVV (미야오)
# 35위 | Supernova - aespa
# 36위 | 예뻤어 - DAY6 (데이식스)
# 37위 | Skyfall (THE 8 Solo) - 세븐틴 (SEVENTEEN)
# 38위 | ATTITUDE - IVE (아이브)
# 39위 | I DO ME - KiiiKiii (키키)
# 40위 | 미치게 그리워서 - 황가람
# 41위 | 미인 (Feat. Balming Tiger) - 아이유
# 42위 | 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지 - AKMU (악뮤)
# 43위 | DRIP - BABYMONSTER
# 44위 | Love wins all - 아이유
# 45위 | PO￦ER - G-DRAGON
# 46위 | 청혼하지 않을 이유를 못 찾았어 - 이무진
# 47위 | 그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection)) - 너드커넥션 (Nerd Connection)
# 48위 | 사랑은 늘 도망가 - 임영웅
# 49위 | Bad Influence (Prod. by Pharrell Williams) - 세븐틴 (SEVENTEEN)
# 50위 | 내 이름 맑음 - QWER
# 51위 | 99.9% (WONWOO Solo) - 세븐틴 (SEVENTEEN)
# 52위 | 슬픈 초대장 - 순순희(지환)
# 53위 | 첫 만남은 계획대로 되지 않아 - TWS (투어스)
# 54위 | Fortunate Change (JOSHUA Solo) - 세븐틴 (SEVENTEEN)
# 55위 | Raindrops (SEUNGKWAN Solo) - 세븐틴 (SEVENTEEN)
# 56위 | UP (KARINA Solo) - aespa
# 57위 | 고민중독 - QWER
# 58위 | 나는 아픈 건 딱 질색이니까 - i-dle (아이들)
# 59위 | 주저하는 연인들을 위해 - 잔나비
# 60위 | TAKE ME - G-DRAGON
# 61위 | 너의 모든 순간 - 성시경
# 62위 | 운명 (WOOZI Solo) - 세븐틴 (SEVENTEEN)
# 63위 | Damage (HOSHI Solo) (feat. Timbaland) - 세븐틴 (SEVENTEEN)
# 64위 | Happy Virus (DK Solo) - 세븐틴 (SEVENTEEN)
# 65위 | Magnetic - 아일릿(ILLIT)
# 66위 | How Sweet - NewJeans
# 67위 | 사랑인가 봐 - 멜로망스
# 68위 | I Feel Good - BOYNEXTDOOR
# 69위 | 에피소드 - 이무진
# 70위 | 비의 랩소디 - 임재현
# 71위 | Shake It Off (MINGYU Solo) - 세븐틴 (SEVENTEEN)
# 72위 | 우연 (JEONGHAN Solo) - 세븐틴 (SEVENTEEN)
# 73위 | Bag Bad Back - RIIZE
# 74위 | 123-78 - BOYNEXTDOOR
# 75위 | 모든 날, 모든 순간 (Every day, Every Moment) - 폴킴
# 76위 | The Chase - Hearts2Hearts (하츠투하츠)
# 77위 | 시작의 아이 - 마크툽 (MAKTUB)
# 78위 | Supersonic - 프로미스나인
# 79위 | Jungle (S.COUPS Solo) - 세븐틴 (SEVENTEEN)
# 80위 | 쌍둥이자리 (Gemini) (JUN Solo) - 세븐틴 (SEVENTEEN)
# 81위 | I AM - IVE (아이브)
# 82위 | Shining Star (Vernon Solo) - 세븐틴 (SEVENTEEN)
# 83위 | Hype Boy - NewJeans
# 84위 | 다정히 내 이름을 부르면 - 경서예지, 전건호
# 85위 | Seven (feat. Latto) - Clean Ver. - 정국
# 86위 | 헤어지자 말해요 - 박재정
# 87위 | Trigger (DINO Solo) - 세븐틴 (SEVENTEEN)
# 88위 | 영원해 - 도경수(D.O.)
# 89위 | 이렇게 좋아해 본 적이 없어요 - BOYNEXTDOOR
# 90위 | 우리들의 블루스 - 임영웅
# 91위 | 봄날 - 방탄소년단
# 92위 | 무제(無題) (Untitled, 2014) - G-DRAGON
# 93위 | 천국보다 아름다운 - 임영웅
# 94위 | 인사 - 범진
# 95위 | 굿데이 2025 (텔레파시 + 달빛 창가에서) - G-DRAGON, 황정민, 데프콘, 홍진경, 정형돈, 조세호, 기안84, 안성재, 태양, 정해인, 황광희, 임시완, 이수혁, 대성, 코드 쿤스트 (CODE KUNST), CL, 김고은, DAY6 (데이식스), 부석순 (SEVENTEEN), aespa
# 96위 | Sticky - KISS OF LIFE
# 97위 | Small girl (feat. 도경수(D.O.)) - 이영지
# 98위 | Dash - PLAVE
# 99위 | 사막에서 꽃을 피우듯 - 우디 (Woody)
# 100위 | 다시 만날 수 있을까 - 임영웅

# %% [markdown]
# ### 5) 네이버지식인으로 검색(open API 사용 X)
# - 특정 keyword를 특정페이지 수(3)만큼 검색한 결과 데이터프레임으로 출력

# %%
# 방법 1
from requests import get
from bs4 import BeautifulSoup
keyword = '챗지피티'
url = 'https://kin.naver.com/search/list.naver?query={}'.format(keyword)
# print(url)
response = get(url)
# response.status_code
soup = BeautifulSoup(response.text,
                     'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta contents="always" name="referrer"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="챗지피티의 지식iN Q&amp;A 검색결과입니다. 궁금증을 해결하지 못했다면 지식iN '질문하기'를 해보세요." name="description">
# <meta content="width=1024" name="viewport"/>
# <meta content="none" name="msapplication-config">
# <link href="https://ssl.pstatic.net/static.kin/static/pc/20250528165456/css/min/common.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.kin/static/pc/20250528165456/css/min/components.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.kin/static/pc/20250528165456/css/min/other.css" rel="stylesheet" type="text/css"/>
# <script>
#
# 	var pcDomain = "kin.naver.com";
# 	var pcDomainWithProtocol = "https://kin.naver.com";
# 	var pcKinServiceProtocol = "https";
#
# 	var mobileDomain = "m.kin.naver.com";
# 	var mobileDomainWithProtocol = "https://m.kin.naver.com";
# 	var mobileKinServiceProtocol = "https";
#
# 	var uploadDomain = "upload.kin.naver.com";
# 	var uploadDomainWithProtocol = "https://upload.kin.naver.com";
# 	var uploadKinServiceProtocol = "https";
# </script>
# <script src="https://ssl.pstatic.net/static.kin/static/pc/20250528165456/js/min/kin.js" type="text/javascript"></script>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="noindex,nofollow" name="robots">
# <meta content="챗지피티 검색결과 : 네이버 지식iN" property="og:title">
# <meta content="https://kin.naver.com/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static/kin/common/kin_thumbnail_new_w1000.png" property="og:image"/>
# <meta content="챗지피티의 지식iN Q&amp;A 검색결과입니다. 궁금증을 해결하지 못했다면 지식iN '질문하기'를 해보세요." property="og:description"/>
# <meta content="네이버 지식iN" property="og:article:author"/>
# <meta content="https://kin.naver.com" property="og:article:author:url"/>
# <link href="/favicon.ico?v=2.4" rel="shortcut icon" type="image/x-icon"/>
# <title>
# 	챗지피티 검색결과 : 지식iN
# </title>
# <script type="text/javascript">
#
# if ( typeof window.nhn  == "undefined" ) window.nhn = {};
# if ( typeof window.naver  == "undefined" ) window.naver = {};
# nhn.isLogin = false;
# nhn.isJunior = ("N"=="Y");
# nhn.isKinUser = false;
# nhn.isPortableDevice = false;
# nhn.jsDir = 'https://ssl.pstatic.net/static.kin/static/pc/20250528165456/js/min';
#
# var g_ssc = ("kin.search" == "") ? "kin.temp" : "kin.search";
# var ccsrv="cc.naver.com";
#
#
# var kinRos = {
# 	bIsNoticeDisplay : ("false" == "" || "false" == "false") ? false : true,
# 	bIsActionNoticeDisplay : ("false" == "" || "false" == "false") ? false : true
#
# };
#
#
#
#
#
# var standardReportPopupUrl = "https://srp2.naver.com/report";
#
#
# var baUserKey = "__UNKNOWN__";
# var baLogEndpoint = "https://scv-kin.io.naver.com/jackpotlog/v1/logs";
# var baAbTestResult = null;
# </script>
# </meta></meta></meta></meta></head>
# <body>
# <div id="loadingIndicator" style="display:none;width:100%;height:100%;position:fixed;top:0px;left:0px;background-color:transparent;z-index:10000;">
# <img alt="데이터 요청 응답 대기중" height="21" src="https://ssl.pstatic.net/static/kin/m/ico_lod2.gif" style="position:absolute;top:49%;left:49%;" width="21"/>
# </div>
# <div class="wrap wrap_search" id="wrap">
# <div class="skip_nav header_gnb_inner">
# <a class="skip" href="#gnb" onclick="nhn.Kin.Utility.skipNavigation('au_lnb_home');return false;">메인 메뉴 바로가기</a>
# <a class="skip" href="#s_content" onclick="nhn.Kin.Utility.skipNavigation('s_content');return false;">본문 바로가기</a>
# </div>
# <div class="header_wrap">
# <div aria-labelledby="ieUpdateBannerTitle" class="popup popup--header_notice" id="ieUpdateBanner" role="dialog" style="display: none;">
# <h1 class="blind" id="ieUpdateBannerTitle" tabindex="0">권장 브라우저 업데이트 안내</h1>
# <div class="popup__content">
# <div class="popup__title">
# <p class="popup__title_text"><span class="ico_alert sp_common"></span>권장 브라우저 안내</p>
# </div>
# <div class="popup__maintext">
# <p class="popup__text">혹시 아직 인터넷 익스플로러 9.0 미만 버전을 사용하고 계신가요?</p>
# <p class="popup__subtext">새롭게 바뀐 지식iN Q&amp;A 페이지는 IE 9.0 이상의 브라우저에 최적화되어 있습니다. 원활한 이용을 위해 꼭 업데이트 해주세요! <a class="popup__link" href="https://support.microsoft.com/ko-kr/help/17621/internet-explorer-downloads" target="_blank">업데이트하기 <span class="sp_common ico_arr_lnk"></span></a></p>
# </div>
# </div>
# </div>
# <script type="text/javascript">
# 	// IE8 이하이면 브라우저 버전을 올려달라는 배너를 노출한다.
# 	$Fn(function() {
# 		var oAgent = jindo.$Agent().navigator();
# 		if (oAgent.ie && (oAgent.version >= 6 && oAgent.version < 9)) {
# 			if (typeof naver.kin.SimpleBanner !== "undefined") {
# 				var oIeUpdateBanner = new naver.kin.SimpleBanner({
# 					sBannerId: "ieUpdateBannerArea"
# 				});
# 			}
# 		}
# 	}, this).attach(document, 'domready');
# </script>
# <div class="header_gnb">
# <div class="header_gnb_inner">
# <div class="header_gnb__cell">
# <h1 class="header_logo">
# <a class="logo_naver" href="http://www.naver.com" onclick="nhn.Kin.Utility.nClicks('STA.naverlogo', '', '', event);" title="나의 경쟁력, 네이버"><span class="blind">NAVER</span></a>
# </h1>
# <div class="header_search">
# <h2 class="logo_wrap">
# <a class="icon_logo_kin" href="/" onclick="nhn.Kin.Utility.nClicks('STA.kin', '', '', event);"><span class="blind">지식iN</span></a>
# </h2>
# <h3 class="blind">검색영역</h3>
# <form action="/search/list.naver" id="topSearch" method="get" name="topSearch" onsubmit="return checkQuery();">
# <fieldset>
# <legend>지식인 검색</legend>
# <div class="search_area">
# <input accesskey="s" aria-autocomplete="list" aria-controls="atcmpList" aria-expanded="false" aria-haspopup="listbox" autocomplete="off" class="search_input" id="nx_query" maxlength="255" name="query" onclick="nhn.Kin.Utility.nClicks('STA.search', '', '', event);return false;" role="combobox" title="검색어 입력" type="text" value="챗지피티"/>
# <a class="search_auto" href="#">
# <span class="sp_gnb icon_arrow" id="triangleBtn">자동완성 열기</span>
# </a>
# <div>
# <iframe class="auto_complete_box" frameborder="0" height="193px" id="autoFrame" marginheight="0" marginwidth="0" scrolling="no" title="검색어 자동완성" width="290"></iframe>
# </div>
# <a class="search_btn" href="#" onclick="return checkQuery();"><span class="sp_gnb icon_search">지식iN 검색</span></a>
# </div>
# </fieldset>
# </form>
# </div>
# </div>
# <div class="header_gnb__cell">
# <div class="gnb_wrap">
# <div class="gnb_eXpertLogo">
# <a aria-controls="bannerExpert" aria-expanded="true" aria-haspopup="true" class="link" href="https://expert.naver.com" id="bannerLink" target="_blank">
# <span class="logo"><span class="blind">eXpert</span></span>
# </a>
# </div>
# <div class="gnb_common_area">
# <div id="gnb">
# <script type="text/javascript">
#
# 								var gnb_service = "kin";
#
# 								var gnb_logout = encodeURIComponent("https://nid.naver.com/nidlogin.logout");
#
# 								var gnb_login = encodeURIComponent(location.href || 'https://kin.naver.com');
#
# 								var gnb_template = "gnb_utf8";
#
# 								var gnb_item_hide_option = 0;
#
#
#
#
# 							</script>
# <script charset="utf-8" src="https://ssl.pstatic.net/static.gn/templates/gnb_utf8.nhn?2025052910" type="text/javascript"></script>
# </div>
# </div>
# </div>
# <div class="header__rolling rolling-notice">
# <i class="icon_speaker"><span class="blind">실시간 공지사항</span></i>
# <ul class="rolling-notice__list _rolling_banner" id="listNotice">
# <li class="rolling-notice__item _rollingItem" data-start-time="2023-07-03 00:00:00" style="display:none;">
# <a class="rolling-notice__link" href="https://m.expert.naver.com/mobile/expert/account/join/hub" onclick="nhn.Kin.Utility.nClicks('STA.event', '', '', event);">
# <i class="icon_new_red _newMark" style="display:none;"><span class="blind">새소식</span></i>
# <span class="text-color--secondary">지식iN은 누구나 엑스퍼트</span><br/>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <!-- nav -->
# <div class="nav" role="navigation">
# <div class="nav_inner">
# <h3 class="blind">메인 메뉴</h3>
# <ul class="nav_list" id="au_lnb" role="menubar">
# <li class="menu" role="presentation">
# <a class="item" href="/index.naver" id="au_lnb_home" onclick="nhn.Kin.Utility.nClicks('LNB.home', '', '', event);" role="menuitem" tabindex="0"><em>홈</em></a>
# </li>
# <li class="menu" role="presentation">
# <a aria-expanded="false" aria-haspopup="true" class="item" href="/qna/list.naver" onclick="nhn.Kin.Utility.nClicks('LNB.qna', '', '', event);" role="menuitem" tabindex="-1"><em>Q&amp;A</em></a>
# <ul class="nav_sub_list _lnbSubMenu" role="menu">
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=11" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '11', '1', event);" role="menuitem" tabindex="-1">교육, 학문</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=1" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '1', '2', event);" role="menuitem" tabindex="-1">IT/테크</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=2" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '2', '3', event);" role="menuitem" tabindex="-1">게임</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=3" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '3', '4', event);" role="menuitem" tabindex="-1">엔터테인먼트, 예술</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=8" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '8', '5', event);" role="menuitem" tabindex="-1">생활</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=7" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '7', '6', event);" role="menuitem" tabindex="-1">건강</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=6" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '6', '7', event);" role="menuitem" tabindex="-1">사회, 정치</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=4" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '4', '8', event);" role="menuitem" tabindex="-1">경제</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=9" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '9', '9', event);" role="menuitem" tabindex="-1">여행</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=10" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '10', '10', event);" role="menuitem" tabindex="-1">스포츠, 레저</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=5" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '5', '11', event);" role="menuitem" tabindex="-1">쇼핑</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=13" onclick="nhn.Kin.Utility.nClicks('LNB.jun', '', '', event);" role="menuitem" tabindex="-1">쥬니버Q&amp;A</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=12" onclick="nhn.Kin.Utility.nClicks('LNB.loc', '', '', event);" role="menuitem" tabindex="-1">지역&amp;플레이스</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=20" onclick="nhn.Kin.Utility.nClicks('LNB.talk', '', '', event);" role="menuitem" tabindex="-1">고민Q&amp;A</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/opendic/index.naver" onclick="nhn.Kin.Utility.nClicks('LNB.open', '', '', event);" role="menuitem" tabindex="-1">오픈사전</a></li>
# </ul>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/qna/questionList.naver" onclick="nhn.Kin.Utility.nClicks('LNB.answer', '', '', event);" role="menuitem" tabindex="-1"><em>답변하기</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/volunteer/index.naver" onclick="nhn.Kin.Utility.nClicks('LNB.donation', '', '', event);" role="menuitem" tabindex="-1"><em>지식기부</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/people/elite/index.naver?from=lnb" id="peopleLnbBtn" onclick="nhn.Kin.Utility.nClicks('LNB.people', '', '', event);" role="menuitem" tabindex="-1"><em>사람들</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/best/listaha.naver" onclick="nhn.Kin.Utility.nClicks('LNB.best', '', '', event);" role="menuitem" tabindex="-1"><em>베스트</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/hall/index.naver" onclick="nhn.Kin.Utility.nClicks('LNB.honor', '', '', event);" role="menuitem" tabindex="-1"><em>명예의전당</em></a>
# </li>
# <li class="menu" role="presentation">
# <span class="lnb_bar">|</span>
# <a class="item" href="/myinfo/index.naver" onclick="nhn.Kin.Utility.nClicks('LNB.profile', '', '', event);" role="menuitem" tabindex="-1"><em>프로필</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/partnercenter/index.naver" onclick="nhn.Kin.Utility.nClicks('LNB.partner', '', '', event);" role="menuitem" tabindex="-1"><em>파트너센터</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/roulette/home.naver" onclick="nhn.Kin.Utility.nClicks('LNB.roulette', '', '', event);" role="menuitem" tabindex="-1"><em>룰렛</em></a>
# </li>
# </ul>
# <a class="nav__button_question _clickcode:LNB.q" href="#" onclick="nhn.Kin.checkRosAndGoUrl(event, '/qna/question.naver', '');sendBaLog(BaPcEventType.KIN_HOME_5048)" role="button"><span class="btn_inner"><i class="sp_gnb icon_pencil"></i>질문하기</span></a>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#
# 	$Fn(function() {
# 		new naver.kin.LNB({
# 			'questionType' : ''
# 		});
# 	}).attach(window, 'load');
#
# 	var GNB_BRIGHTNESS_VALUE = {
# 		DARK_ICON : 0,
# 		DARK_ICON_AND_TRANSPARENCY : 1,
# 		BRIGHT_ICON_AND_TRANSPARENCY : 2,
# 		BRIGHT_ICON : 3
# 	};
#
# 	var GNB_ITEM_HIDE_OPTION_BIT_VALUE = {
# 		DEFAULT : 0,
# 		HIDE_LOGIN_BTN : 1,
# 		HIDE_USER_LAYER : 2,
# 		HIDE_NAVER_ME_AREA : 4,
# 		HIDE_MAIL_ALARM_AREA : 8,
# 		HIDE_PROFILE_IMAGE : 16,
# 		SHOW_BENEFIT_FOR_STAFF_MEMBER : 32
# 	};
#
#
# 	var smartSearch = "";
#
# 	var gnb_service = "kin";
#
# 	var gnb_logout = encodeURIComponent("https://nid.naver.com/nidlogin.logout");
#
# 	var gnb_login = encodeURIComponent(location.href || 'https://kin.naver.com');
#
# 	var gnb_template = "gnb_utf8";
#
# 	var gnb_item_hide_option = GNB_ITEM_HIDE_OPTION_BIT_VALUE.DEFAULT;
#
#
#
#
#
# 	$Fn(function() {
#
# 		getGNB();
#
# 		var bIsGnbClicked = false;
#
#
# 		$Fn(function (we) {
# 			if (!bIsGnbClicked) {
# 				gnbAllLayerClose();
# 			}
#
# 			bIsGnbClicked = false;
# 		}, this).attach(document.body, 'click');
#
# 		$Fn(function(we) {
# 			bIsGnbClicked = true;
# 		}, this).attach($('gnb'), 'click');
#
#
# 		try {
# 			$('autoFrame').src = '/static/reatcmp.html?v=4.1';
# 		} catch(e) {
# 		}
#
# 		smartSearch = new nhn.AjaxSuggestUS('nx_query', 'autoFrame', {
# 			url : 'https://ac.search.naver.com/nx/ac',
# 			cookieName : 'NaverSuggestUse',
# 			listbox : '_resultBox',
# 			sFromName : 'topSearch',
# 			triangleBtn : 'triangleBtn',
# 			sListMaxLength : 55,
# 			listMaxCount : 15,
# 			request_type : 'jsonp',
# 			request_data : {
# 				q : '{query}',
# 				st : '100',
# 				r_format : 'json',
# 				t_koreng : '1',
# 				q_enc : 'UTF-8',
# 				r_enc : 'UTF-8',
# 				r_unicode : '0',
# 				r_escape : '1',
# 				frm : 'kin'
# 			},
# 			sTriangleUpOn : 'https://ssl.pstatic.net/static/common/snb/090513/bu_arrow_up.gif',
# 			sTriangleUpOff : 'https://ssl.pstatic.net/sstatic/search/mypocket/v3/btn_atcmp_off_op2.gif',
# 			sTriangleDownOn : 'https://ssl.pstatic.net/static/common/snb/090513/bu_arrow_down.gif',
# 			sTriangleDownOff : 'https://ssl.pstatic.net/static/common/snb/090513/bu_arrow_down3.gif'
# 		}).attach({
# 			actSubmit : function() {
# 				try {
# 					top.selectAction(this._elForm);
# 				} catch(e) {
# 					try {
# 						selectAction(this._elForm);
# 					} catch(e) {
# 					}
# 				}
#
# 				this._elForm.submit();
# 			}
# 		});
#
# 		var expertEntryBanner = $$.getSingle("div.gnb_eXpertLogo div.banner");
# 		if (!!expertEntryBanner) {
# 			var cookie = new $Cookie();
#
# 			$Fn(function () {
# 				$Element(expertEntryBanner).hide();
#
# 				var newDisabledUntil = new Date().getTime() + (3 * 1000 * 24 * 60 * 60);
# 				cookie.set("kin_expert_entry_banner_disabled_until", newDisabledUntil, 5);
# 			}).attach($$.getSingle("div.gnb_eXpertLogo div.banner button.buttonCancel"), 'click');
#
# 			var disabledUntilTimestamp = new Number(cookie.get("kin_expert_entry_banner_disabled_until"));
# 			if (!isNaN(disabledUntilTimestamp)) {
# 				if (new Date().getTime() > disabledUntilTimestamp) {
# 					cookie.remove("kin_expert_entry_banner_disabled_until");
# 					$Element(expertEntryBanner).show();
# 				}
# 			} else {
# 				$Element(expertEntryBanner).show();
# 			}
# 		}
#
#
# 		if (typeof nhn.Kin.ChatMenu !== "undefined") {
# 			window.oChatMenu = new nhn.Kin.ChatMenu();
# 		}
# 	}).attach(window, 'load');
# </script>
# <div class="container-fluid" id="container">
# <div class="container-fluid-content">
# <div class="container-fluid-content-inner">
# <div id="search_result">
# <strong>'챗지피티'</strong> 에 대한 검색결과입니다.
#
#
#
# </div>
# <script type="text/javascript">
# function checkAdultAuth() {
# 	var url = "https://" + top.location.hostname + "/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0&cs=utf8&section=kin&excludeAdultDoc=false";
# 	var surl = "https://" + top.location.hostname + "/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0&cs=utf8&section=kin";
#
# 	try{
#
#
# 			top.location.href = "https://nid.naver.com/nidlogin.login?svctype=128&a_version=2&viewtype=2&url=" + encodeURIComponent(url + "&from=search") + "&surl=" + encodeURIComponent(surl);
#
# 	} catch (e){
# 		history.back();
# 	}
# }
# </script>
# <div class="container-fluid-content__left" id="content">
# <script src="https://ssl.pstatic.net/static.kin/static/pc/20250528165456/js/min/nhn.Kin.Search.Terms.js" type="text/javascript"></script>
# <div id="s_content">
# <div id="scl">
# <ul>
# <li class="tx_depth1"><strong><a class="_nclicks:tab.kin" href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0§ion=kin" title="전체"><span>전체</span></a></strong></li>
# <li class="tx_depth2"><a class="_nclicks:tab.qna" href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0§ion=qna" title="Q&amp;A"><span>Q&amp;A</span></a></li>
# <li class="tx_depth3"><a class="_nclicks:tab.ency" href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0§ion=ency" title="오픈백과"><span>오픈백과</span></a></li>
# <li>
# </li></ul>
# </div>
# <div class="banner_suicide_stop" id="suicidalPreventionBanner" style="display:none;">
# <div class="content_suicide_stop">
# <h3 class="tit_suicide_stop">
# <span class="blind">생명은 소중합니다.! 지금,희망을 클릭하세요.</span>
# </h3>
# <ul class="info_suicide_stop">
# <li class="counsel_list v1">
# <strong class="tit_counsel_list">전화상담</strong>
# <ul class="counsel_info_list">
# <li>자살예방상담전화 <em>109</em></li>
# <li>정신건강상담전화 <em>1577-0199</em></li>
# <li><a href="https://www.cyber1388.kr:447" target="_blank">청소년 HelpCall</a> <em>1388</em></li>
# <li><a href="https://www.lifeline.or.kr" target="_blank">한국생명의전화</a> <em>1588-9191</em></li>
# <li>한마음한몸자살예방센터 <em>1577-0199</em></li>
# </ul>
# </li>
# <li class="counsel_list v2">
# <strong class="tit_counsel_list">온라인상담</strong>
# <ul class="counsel_info_list">
# <li><a href="https://www.lifeline.or.kr" id="btn_suicide_stop" target="_blank">한국생명의전화</a></li>
# <li><a href="https://www.cyber1388.kr:447" target="_blank">청소년사이버상담센터</a></li>
# </ul>
# </li>
# <li class="counsel_list v3">
# <strong class="tit_counsel_list">지식iN도 여러분을 돕습니다.</strong>
# <ul class="counsel_info_list">
# <li><a href="/qna/question.naver?expertType=doctor&amp;dirId=70109" target="_blank">의사에게질문하기</a></li>
# <li><a href="/profile/index.naver?u=6oCfeacJKVQGwsBB7OHEIS4miiPixwQ%2FoueervNeYrg%3D" target="_blank">여성가족부. 한국청소년상담복지개발원</a></li>
# <li><a href="/profile/index.naver?u=9xhBJX%2Fe3worDHM4Tp9d%2F4jUxoIMOWjkBn9VK4u3x8M%3D" target="_blank">경기도청소년상담복지센터</a></li>
# <li class="list_aside"><a href="/profile/index.naver?u=m61fd7AyyTNGzdSXnfIARZMD2YrqU0TvSai8n3aIfHk%3D" target="_blank">마음상담</a></li>
# <li><span class="counsel_vt">|</span><a href="/profile/index.naver?u=9AFcqSNT5xcmX%2BDwjqumdFA11U6ypJgxKXiNTqx%2FenU%3D" target="_blank">허그맘</a></li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <script type="text/javascript">
# 	jindo.$Fn(function() {
#
#
# 		if(nhn.Kin.Utility.containSuicideKeywords('\uCC57\uC9C0\uD53C\uD2F0')) {
#
# 			jindo.$Element('suicidalPreventionBanner').show();
# 		}
# 	},this).attach(window,"load");
# 	</script>
# <div class="section">
# <h2>
# <img alt="전체 지식iN" height="15" src="https://ssl.pstatic.net/static/kin/09renewal/h_search_kin_all.gif" width="67"/>
# <span class="number">(<em>1-10/20,931</em>)</span>
# </h2>
# <div class="option_search">
# <ul class="option_sort">
# <li class="sp_sort1"><strong><a aria-current="true" class="_nclicks:kin.relavant" href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0§ion=kin&amp;sort=none" title="정확도"><span>정확도</span></a></strong></li>
# <li class="sp_sort2"><a class="_nclicks:kin.recent" href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0§ion=kin&amp;sort=date" title="최신순"><span>최신순</span></a></li>
# <li class="sp_sort3"><a class="_nclicks:kin.vcount" href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0§ion=kin&amp;sort=vcount" title="추천순"><span>추천순</span></a></li>
# </ul>
# <form name="date_search">
# <input name="sort" type="hidden" value="none">
# <input name="section" type="hidden" value="kin"/>
# <input name="query" type="hidden" value="챗지피티"/>
# <input id="au_period" name="period" type="hidden" value=""/>
# </input></form>
# <ul class="option_term">
# <li>
# <div class="selectbox-noscript" id="au_date_select">
# <select class="selectbox-source" id="au_date_result" name="date" title="기간 전체">
# <option class="_nclicks:kin.dateall" selected="" value="0">기간 전체</option>
# <option class="_nclicks:kin.date1w" value="1">최근 1주</option>
# <option class="_nclicks:kin.date1m" value="2">최근 1달</option>
# <option class="selectbox-notclose _nclicks:kin.dateinput" value="2002.01.01.2025.05.29.">기간 입력</option>
# </select>
# <div class="selectbox-box">
# <div class="selectbox-label"></div>
# </div>
# <div class="selectbox-layer">
# <div class="selectbox-list"></div>
# </div>
# </div>
# </li>
# </ul>
# <script src="https://ssl.pstatic.net/static.kin/static/pc/20250528165456/js/min/nhn.Kin.Search.DateSelectBox.js" type="text/javascript"></script>
# <script type="text/javascript">
# 			$Fn(function() {
# 				nhn.Kin.Search.DateSelectBox.initialize('PC');
# 			},this).attach(window,"load");
#
# 			</script>
# </div>
# <!-- Search List -->
# <strong class="blind">검색결과</strong>
# <ul class="basic1">
# <li>
# <dl>
# <dt>
# <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=3&amp;dirId=31501&amp;docId=484827506&amp;qb=7LGX7KeA7ZS87Yuw&amp;enc=utf8" target="_blank"><b>챗지피티</b> 사주</a>
# </dt>
# <dd class="txt_inline">2025.05.03.</dd>
# <dd>책지피티 사주 다 정확하지는 않죠?ㅠ 좋아하던 사람한테 연락올 가능성 있다는데ㅠ... <b>챗지피티</b>는 이용하지 않는게 좋습니다 <b>챗지피티</b> 제작 초기 최초 적용, 입력한 이론... </dd>
# <dd class="tag_area">
# </dd>
# <dd class="txt_block">
# <a class="txt_g1 _nclicks:kin.cat1" href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0§ion=qna">Q&amp;A</a>
#
# 									 &gt; <a class="txt_g1 _nclicks:kin.cat2" href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0§ion=qna&amp;dirId=31501">사주, 궁합</a>
# <span class="bar">|</span>
# <span class="hit">답변수 10</span> UP 25
#
#
# 							</dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>
# <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=3&amp;dirId=31503&amp;docId=484836001&amp;qb=7LGX7KeA7ZS87Yuw&amp;enc=utf8" target="_blank"><b>챗지피티</b> 타로</a>
# </dt>
# <dd class="txt_inline">2025.05.03.</dd>
# <dd><b>챗지피티</b> 타로 믿을만한가요?ㅜㅜ <b>챗지피티</b> 타로, 그러니까 인공지능이 타로카드 해석을... 요즘엔 온라인에서 너무나 손쉽게 타로를 볼 수 있고, 특히 <b>챗지피티</b>처럼 최신... </dd>
# <dd class="tag_area">
# </dd>
# <dd class="txt_block">
# <a class="txt_g1 _nclicks:kin.cat1" href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0§ion=qna">Q&amp;A</a>
#
# 									 &gt; <a class="txt_g1 _nclicks:kin.cat2" href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0§ion=qna&amp;dirId=31503">타로카드운세</a>
# <span class="bar">|</span>
# <span class="hit">답변수 2</span> UP 1
#
#
# 								<span class="bar">|</span>
#
#
# 									답변
#
#
#
# 									오버럴드(hoit****)
#
#
#
# 							</dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>
# <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=3&amp;dirId=31503&amp;docId=485464963&amp;qb=7LGX7KeA7ZS87Yuw&amp;enc=utf8" target="_blank"><b>챗지피티</b> 타로</a>
# </dt>
# <dd class="txt_inline">2025.05.23.</dd>
# <dd>제가 <b>챗지피티</b>로 사주랑 타로를 많이 보는데요 사주는 가끔 가다가 말이 너무... <b>챗지피티</b>가 해석해주는데 것도 말이 달라요 그래서 제가 똑바로 해석하라고 해서 다시... </dd>
# <dd class="tag_area">
# </dd>
# <dd class="txt_block">
# <a class="txt_g1 _nclicks:kin.cat1" href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0§ion=qna">Q&amp;A</a>
#
# 									 &gt; <a class="txt_g1 _nclicks:kin.cat2" href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0§ion=qna&amp;dirId=31503">타로카드운세</a>
# <span class="bar">|</span>
# <span class="hit">답변수 6</span> UP 6
#
#
# 								<span class="bar">|</span>
#
#
# 									답변
#
#
#
#
#
#
#
#
# 										<img alt="TOP 5" class="ico_top5" height="11" src="https://ssl.pstatic.net/static/kin/09renewal/ico_badge_top5.gif" width="25">
#
#
#
# 									프라임(rlxa****)
#
#
#
# 							</img></dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>
# <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=1&amp;dirId=113&amp;docId=485266256&amp;qb=7LGX7KeA7ZS87Yuw&amp;enc=utf8" target="_blank"><b>챗지피티</b> 갸륵체 어떻게 생각하시나요?</a>
# </dt>
# <dd class="txt_inline">2025.05.17.</dd>
# <dd>요즘 <b>챗지피티</b> 갸륵체가 정말 핫하더라고요. 갸륵체... 혹시 여러분은 자신만의 <b>챗지피티</b> 답변 문체가 있나요?... 요즘 <b>챗지피티</b> ‘갸륵체’처럼 독특한 문체가 인기를 끌고... </dd>
# <dd class="tag_area">
# <a class="_nclicks:kin.tag" href="/tag/tagDetail.naver?tag=zalpha%EB%B3%B4%EC%9E%90&amp;listType=answer">#zalpha보자</a>
# <a class="_nclicks:kin.tag" href="/tag/tagDetail.naver?tag=20%EB%8C%80%ED%95%AB%ED%95%B4%EC%9A%94&amp;listType=answer">#20대핫해요</a>
# <a class="_nclicks:kin.tag" href="/tag/tagDetail.naver?tag=%EC%B1%97gpt&amp;listType=answer">#챗gpt</a>
# <a class="_nclicks:kin.tag" href="/tag/tagDetail.naver?tag=%EA%B0%B8%EB%A5%B5%EC%B2%B4&amp;listType=answer">#갸륵체</a>
# <a class="em _nclicks:kin.tag" href="/tag/tagDetail.naver?tag=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0&amp;listType=answer">#챗지피티</a>
# <a class="_nclicks:kin.tag" href="/tag/tagDetail.naver?tag=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0%EB%AC%B8%EC%B2%B4&amp;listType=answer">#챗지피티문체</a>
# </dd>
# <dd class="txt_block">
# <a class="txt_g1 _nclicks:kin.cat1" href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0§ion=qna">Q&amp;A</a>
#
# 									 &gt; <a class="txt_g1 _nclicks:kin.cat2" href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0§ion=qna&amp;dirId=113">오픈API</a>
# <span class="bar">|</span>
# <span class="hit">답변수 2</span> UP 1
#
#
# 								<span class="bar">|</span>
#
#
# 									답변
#
#
#
# 									디지털 노마드(luna****)
#
#
#
# 							</dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>
# <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=4&amp;dirId=408&amp;docId=485386619&amp;qb=7LGX7KeA7ZS87Yuw&amp;enc=utf8" target="_blank"><b>챗지피티</b> 사용하려면 어떻게 해야 하나요?</a>
# </dt>
# <dd class="txt_inline">2025.05.20.</dd>
# <dd><b>챗지피티</b> 사용하려면 어떻게 해야 하나요? 회원가입을 해야 하나요? 순서도 모르겠고... <b>챗지피티</b> 쓰려면 openai.com 가서 회원가입 먼저 하셔야 해요 이메일 인증하고... </dd>
# <dd class="tag_area">
# </dd>
# <dd class="txt_block">
# <a class="txt_g1 _nclicks:kin.cat1" href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0§ion=qna">Q&amp;A</a>
#
# 									 &gt; <a class="txt_g1 _nclicks:kin.cat2" href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0§ion=qna&amp;dirId=408">경제 정책, 제도</a>
# <span class="bar">|</span>
# <span class="hit">답변수 2</span> UP 0
#
#
# 								<span class="bar">|</span>
#
#
# 									답변
#
#
#
# 									아정당인테리어(dang****)
#
#
#
# 							</dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>
# <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=4&amp;dirId=40608&amp;docId=484141621&amp;qb=7LGX7KeA7ZS87Yuw&amp;enc=utf8" target="_blank"><b>챗지피티</b> 잡아내는거..</a>
# </dt>
# <dd class="txt_inline">2025.04.12.</dd>
# <dd>... 지피티 같은 AI 많이 쓰잖아요 이걸 그대로 베껴오지않고 조금 수정해도 걸린다는데 도대체 뭐 써서 <b>챗지피티</b>... (질문) 요즘 과제나 수행평가에 <b>챗지피티</b> 같은 AI 많이... </dd>
# <dd class="tag_area">
# </dd>
# <dd class="txt_block">
# <a class="txt_g1 _nclicks:kin.cat1" href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0§ion=qna">Q&amp;A</a>
#
# 									 &gt; <a class="txt_g1 _nclicks:kin.cat2" href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0§ion=qna&amp;dirId=40608">컴퓨터, 프로그래밍</a>
# <span class="bar">|</span>
# <span class="hit">답변수 2</span> UP 4
#
#
# 							</dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>
# <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=1&amp;dirId=11003&amp;docId=485467804&amp;qb=7LGX7KeA7ZS87Yuw&amp;enc=utf8" target="_blank"><b>챗지피티</b> 개인정보</a>
# </dt>
# <dd class="txt_inline">2025.05.23.</dd>
# <dd><b>챗지피티</b>에서 지금까지 운영자가 보는거 제외하고 타인에게 개인정보가 유출된 사례가... 메일주소나 ip주소 등등 <b>챗지피티</b>의 개인정보 유출 사례가 있습니다. <b>챗지피티</b>... </dd>
# <dd class="tag_area">
# </dd>
# <dd class="txt_block">
# <a class="txt_g1 _nclicks:kin.cat1" href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0§ion=qna">Q&amp;A</a>
#
# 									 &gt; <a class="txt_g1 _nclicks:kin.cat2" href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0§ion=qna&amp;dirId=11003">개인정보보호</a>
# <span class="bar">|</span>
# <span class="hit">답변수 1</span> UP 1
#
#
# 							</dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>
# <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=6&amp;dirId=60101&amp;docId=480556548&amp;qb=7LGX7KeA7ZS87Yuw&amp;enc=utf8" target="_blank"><b>챗지피티</b> 돈 내면서 쓰는거 좋나요?</a>
# </dt>
# <dd class="txt_inline">2025.03.21.</dd>
# <dd>... <b>챗 지피티</b> 싸게 이용하는 방법 안내해드릴께요! 겜스고라는 사이트가시면 다른분들이랑 같이 구독해서 저렴하게 이용할수 있는데 프로모션 코드에 MLWYX입력하시면... </dd>
# <dd class="tag_area">
# <a class="_nclicks:kin.tag" href="/tag/tagDetail.naver?tag=%EA%B2%9C%EC%8A%A4%EA%B3%A0%ED%95%A0%EC%9D%B8%EC%BD%94%EB%93%9C&amp;listType=answer">#겜스고할인코드</a>
# </dd>
# <dd class="txt_block">
# <a class="txt_g1 _nclicks:kin.cat1" href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0§ion=qna">Q&amp;A</a>
#
# 									 &gt; <a class="txt_g1 _nclicks:kin.cat2" href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0§ion=qna&amp;dirId=60101">가족, 개인 민원</a>
# <span class="bar">|</span>
# <span class="hit">답변수 8</span> UP 19
#
#
# 								<span class="bar">|</span>
#
#
# 									답변
#
#
#
#
# 									kies****
#
#
# 							</dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>
# <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=11&amp;dirId=110501&amp;docId=484520422&amp;qb=7LGX7KeA7ZS87Yuw&amp;enc=utf8" target="_blank">카피킬러 표절 및 <b>챗지피티</b> 검사 83%</a>
# </dt>
# <dd class="txt_inline">2025.04.30.</dd>
# <dd>카피킬러 사용해서 표절률이랑 <b>챗지피티</b>? 검사 했는데 83%나오는데 왜 이런가요?? <b>챗지피티</b> 유료라 사용도 안해봤는데… 맞아요. 카피킬러에서 AI(<b>챗지피티</b>) 판별은 원래 높게... </dd>
# <dd class="tag_area">
# </dd>
# <dd class="txt_block">
# <a class="txt_g1 _nclicks:kin.cat1" href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0§ion=qna">Q&amp;A</a>
#
# 									 &gt; <a class="txt_g1 _nclicks:kin.cat2" href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0§ion=qna&amp;dirId=110501">대학공부</a>
# <span class="bar">|</span>
# <span class="hit">답변수 3</span> UP 0
#
#
# 								<span class="bar">|</span>
#
#
# 									답변
#
#
#
# 									코코(ouo3****)
#
#
#
# 							</dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>
# <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=1&amp;dirId=1040206&amp;docId=479912844&amp;qb=7LGX7KeA7ZS87Yuw&amp;enc=utf8" target="_blank"><b>챗지피티</b> 무료 렉 거림</a>
# </dt>
# <dd class="txt_inline">2025.03.25.</dd>
# <dd>뭐 도움 받을게 있어서 오랜만에 <b>챗지피티</b>를 사용했는데... 급하게 <b>챗지피티</b> 써야하는데 왜이러는지 알려주세요... 재시작을 하거나 <b>챗지피티</b> 로그아웃, 혹은 새로운 아이디로... </dd>
# <dd class="tag_area">
# </dd>
# <dd class="txt_block">
# <a class="txt_g1 _nclicks:kin.cat1" href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0§ion=qna">Q&amp;A</a>
#
# 									 &gt; <a class="txt_g1 _nclicks:kin.cat2" href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0§ion=qna&amp;dirId=1040206">XML</a>
# <span class="bar">|</span>
# <span class="hit">답변수 8</span> UP 17
#
#
# 							</dd>
# </dl>
# </li>
# </ul>
# <div class="s_paging">
# <strong>1</strong>
# <a href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0&amp;page=2" onclick="nhn.Kin.Utility.nClicks('kin.page','','2',event);">2</a>
# <a href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0&amp;page=3" onclick="nhn.Kin.Utility.nClicks('kin.page','','3',event);">3</a>
# <a href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0&amp;page=4" onclick="nhn.Kin.Utility.nClicks('kin.page','','4',event);">4</a>
# <a href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0&amp;page=5" onclick="nhn.Kin.Utility.nClicks('kin.page','','5',event);">5</a>
# <a href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0&amp;page=6" onclick="nhn.Kin.Utility.nClicks('kin.page','','6',event);">6</a>
# <a href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0&amp;page=7" onclick="nhn.Kin.Utility.nClicks('kin.page','','7',event);">7</a>
# <a href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0&amp;page=8" onclick="nhn.Kin.Utility.nClicks('kin.page','','8',event);">8</a>
# <a href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0&amp;page=9" onclick="nhn.Kin.Utility.nClicks('kin.page','','9',event);">9</a>
# <a href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0&amp;page=10" onclick="nhn.Kin.Utility.nClicks('kin.page','','10',event);">10</a>
# <a class="next _nclicks:kin.next" href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0&amp;page=11">다음페이지</a>
# </div><!--kin:navigation maxPage="50" /-->
# <script type="text/javascript">
# 				var kinSearchTerms = new nhn.Kin.Search.Terms();
# 				if (kinSearchTerms) {
#
# 					kinSearchTerms.addTerm('\uCC57');
#
# 					kinSearchTerms.addTerm('\uC9C0\uD53C\uD2F0');
#
# 					kinSearchTerms.addQueryToTerm('\uCC57\uC9C0\uD53C\uD2F0');
# 					var kin_terms = kinSearchTerms.makeTermArray();
# 				}
# 			</script>
# <div class="this_questions" id="bottomQuestionButton">
# <p>
# <b class="keyword">'챗지피티'</b> 에 대한 궁금증을 해결하지 못하셨다면 직접 질문해보세요!<br/>
# 				내 궁금증에 맞는 더 정확한 답변을 받을 수 있습니다.
# 			</p>
# <a class="btn_go_question _nclicks:ask.question" href="/qna/question.naver" target="_blank" title="질문하러 가기"><img alt="질문하러 가기" height="33" src="https://ssl.pstatic.net/static/kin/09renewal/btn_go_question.gif" width="121"/></a>
# </div>
# <script type="text/javascript">
#
# 		$Fn(function() {
# 			if(nhn.Kin.Utility.containSuicideKeywords('\uCC57\uC9C0\uD53C\uD2F0')) {
# 				$Element('bottomQuestionButton').hide();
# 			}
# 		},this).attach(window,"load");
# 		</script>
# </div>
# </div>
# </div>
# <div class="container-fluid-content__right">
# <div id="aside">
# <script src="https://ssl.pstatic.net/static.kin/static/pc/20250528165456/js/min/nhn.Kin.Search.RelatedKeyword.js" type="text/javascript"></script>
# <div class="aside relate aside_type1" id="au_related_keyword">
# <h4 class="h_side_title">
# <strong class="tit">연관검색어</strong>
# </h4>
# <div class="aside_list aside_word">
# <ul>
# <li><a href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0%EB%AC%B4%EB%A3%8C">챗지피티무료</a></li>
# <li><a href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0%20%EC%82%AC%EC%A3%BC">챗지피티 사주</a></li>
# <li><a href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0%20%EC%9C%A0%EB%A3%8C">챗지피티 유료</a></li>
# <li><a href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0%20%EA%B2%80%EC%82%AC%EA%B8%B0">챗지피티 검사기</a></li>
# <li><a href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0%20%EC%A7%80%EB%B8%8C%EB%A6%AC">챗지피티 지브리</a></li>
# <li><a href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0%20%EC%82%AC%EC%A3%BC%20%ED%94%84%EB%A1%AC%ED%94%84%ED%8A%B8">챗지피티 사주 프롬프트</a></li>
# <li><a href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0%20%EC%9D%8C%EC%84%B1%EB%8C%80%ED%99%94">챗지피티 음성대화</a></li>
# <li><a href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0%20%EC%9C%A0%EB%A3%8C%20%EA%B0%80%EA%B2%A9">챗지피티 유료 가격</a></li>
# <li><a href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0%20%EA%B0%80%EA%B2%A9">챗지피티 가격</a></li>
# <li><a href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0%20%EA%B7%B8%EB%A6%BC">챗지피티 그림</a></li>
# <li class="_related_keyword" style="display:none;"><a href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0%20%EC%98%A4%EB%A5%98">챗지피티 오류</a></li>
# <li class="_related_keyword" style="display:none;"><a href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0%20%ED%94%8C%EB%9F%AC%EC%8A%A4">챗지피티 플러스</a></li>
# <li class="_related_keyword" style="display:none;"><a href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0%20%ED%95%9C%EA%B5%AD%EC%96%B4">챗지피티 한국어</a></li>
# <li class="_related_keyword" style="display:none;"><a href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0%204.0">챗지피티 4.0</a></li>
# <li class="_related_keyword" style="display:none;"><a href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0%20%ED%83%80%EB%A1%9C">챗지피티 타로</a></li>
# <li class="_related_keyword" style="display:none;"><a href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0%20%EC%82%AC%EC%A7%84">챗지피티 사진</a></li>
# <li class="_related_keyword" style="display:none;"><a href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0%20%ED%94%84%EB%A1%AC%ED%94%84%ED%8A%B8">챗지피티 프롬프트</a></li>
# <li class="_related_keyword" style="display:none;"><a href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0%20%EC%A7%80%EB%B8%8C%EB%A6%AC%20%EB%AC%B4%EB%A3%8C">챗지피티 지브리 무료</a></li>
# <li class="_related_keyword" style="display:none;"><a href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0%20%EB%8C%80%ED%99%94">챗지피티 대화</a></li>
# <li class="_related_keyword" style="display:none;"><a href="/search/list.naver?query=%EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0%20%ED%94%8C%EB%9F%AC%EC%8A%A4%20%EA%B0%80%EA%B2%A9">챗지피티 플러스 가격</a></li>
# </ul>
# </div>
# <div class="aside_help"><a class="cs" href="https://help.naver.com/service/5627/contents/4956" target="_blank"><span class="blind">연관검색어 </span>도움말</a><a class="cs2 _cs2" href="#"><span class="blind">연관검색어</span> <span>더보기 열기</span></a></div>
# </div>
# <script type="text/javascript">
# 	nhn.Kin.Search.RelatedKeyword.initialize();
# </script>
# <div class="aside aside_type1 noline">
# <h4 class="h_side_title type_default">
# <strong class="tit">아하!그렇구나</strong>
# </h4>
# <div class="aside_list">
# <ul>
# <li><a href="/qna/detail.naver?d1id=6&amp;dirId=6130102&amp;docId=483628061" target="_blank">임시공휴일과 대체휴일이...</a></li>
# <li><a href="/qna/detail.naver?d1id=11&amp;dirId=11080103&amp;docId=484458245" target="_blank">된소리되기가 왜 형태론적...</a></li>
# <li><a href="/qna/detail.naver?d1id=5&amp;dirId=50502&amp;docId=470270402" target="_blank">집중호우기준이뭔죠</a></li>
# <li><a href="/qna/detail.naver?d1id=11&amp;dirId=11080103&amp;docId=484628394" target="_blank">된소리되기 율법..왜 되나...</a></li>
# <li><a href="/qna/detail.naver?d1id=3&amp;dirId=30205&amp;docId=474166290" target="_blank">인디음악 뜻</a></li>
# </ul>
# </div>
# <span class="more"><a href="/best/listaha.naver">더보기</a></span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script>
# 	var query = '\uCC57\uC9C0\uD53C\uD2F0';
# 	if (query) {
# 		sendBaLog(BaPcEventType.KIN_SEARCH_5064, {keyword: query});
# 	}
# </script>
# </div>
# <footer class="footerArea">
# <div class="footerList">
# <a class="footerItem _nclicks:fot.agreement" href="http://www.naver.com/rules/service.html" target="_blank">이용약관</a>
# <a class="footerItem _nclicks:fot.policy" href="/common/guide.naver?query=p1" target="_blank">지식iN 서비스 운영정책</a>
# <a class="footerItem _nclicks:fot.privacy" href="http://www.naver.com/rules/privacy.html" target="_blank"><strong>개인정보처리방침</strong></a>
# <a class="footerItem _nclicks:fot.claim" href="https://right.naver.com" target="_blank">권리보호센터</a>
# <a class="footerItem _nclicks:fot.help" href="https://help.naver.com/alias/kin/kinmain.naver" target="_faqhelp">지식iN 고객센터</a>
# <address class="copyright"><a class="highlight _nclicks:fot.nhncorp" href="https://www.navercorp.com" target="_openNHNWindow">© NAVER Corp.</a></address>
# </div>
# </footer>
# <!-- Naver Tag Manager -->
# <script type="text/javascript">
#   !function(t,n){n=n||"ntm";window["ntm_"+t]=n,window[n]=window[n]||[],window[n].push({"ntm.start":+new Date});t=document.getElementsByTagName("script")[0],n=document.createElement("script");n.async=!0,n.src="https://ntm.pstatic.net/scripts/ntm_4ce883ef1dad.js",t.parentNode.insertBefore(n,t)}("4ce883ef1dad","ntm");
# </script>
# <!-- End Naver Tag Manager -->
# </body>
# </html>

# %%
# 방법 2
from urllib.request import urlopen
from urllib.parse import quote
# 챗지피티 -> %EC%B1%97%EC%A7%80%ED%94%BC%ED%8B%B0
keyword = quote(keyword) # (url 인코딩된 문자열)
url = 'https://kin.naver.com/search/list.naver?query={}'.format(keyword)
# print(url)
response = urlopen(url)
soup = BeautifulSoup(response, # response.read
                     'html.parser')

# %%
# 페이징 포함 (keyword를 page수 만큼 검색한 결과를 데이터프레임에)
import requests
from bs4 import BeautifulSoup
import pandas as pd
keyword = '챗지피티'
pages = 3
items_list = [] # 크롤링한 데이터를 담을 list(2차원 리스트)
for page in range(1, pages+1):
    url = f'https://kin.naver.com/search/list.naver?query={keyword}&page={page}'
    # print(url)
    # 해당 url의 soup객체 -> 글제목, link를 가져와서 items_list에 append
    response = requests.get(url)
    # print(response.status_code) 정상 접근 가능한지 여부
    soup = BeautifulSoup(response.text, 'html.parser')
    items = soup.select('dt > a')
    # print([item.attrs['href'] for item in items])
    for item in items:
        items_list.append([item.text, item.attrs.get('href')])
        # items_list.append({
        #     'title':item.text,
        #     'link':item.attrs.get('href')
        # })
# print(len(items_list), '개 데이터')
# print(items_list[:2])
df = pd.DataFrame(items_list, columns=['title','link'])
df
# Out:
#                         title  \
# 0                     챗지피티 사주
# 1                     챗지피티 타로
# 2                     챗지피티 타로
# 3        챗지피티 갸륵체 어떻게 생각하시나요?
# 4      챗지피티 사용하려면 어떻게 해야 하나요?
# 5                챗지피티 잡아내는거..
# 6                   챗지피티 개인정보
# 7         챗지피티 돈 내면서 쓰는거 좋나요?
# 8       카피킬러 표절 및 챗지피티 검사 83%
# 9                챗지피티 무료 렉 거림
# 10  아 ㅆ 지식인 챗지피티 돌리는 것들 잘...
# 11            챗지피티 동시 접속 되나요?
# 12         챗지피티 plus 파일 생성 오류
# 13           무료 챗지피티 써보려고 하는데
# 14                     하 챗지피티
# 15                  챗지피티 연애상담
# 16                    챗지피티 코딩
# 17              퍼플렉시티 챗지피티 질문
# 18                    챗지피티 음성
# 19          조선왕조실록 챗지피티 사실 검증
# 20                   겜스고 챗지피티
# 21                   챗지피티 검사기
# 22                   챗지피티 메모리
# 23                 챗지피티 유료 차이
# 24                   모바일 챗지피티
# 25                 지식인<<<챗지피티
# 26                챗지피티 결제 플러스
# 27          챗지피티 4o 이용해야 하나…?
# 28                    챗지피티 오류
# 29              챗지피티 주 사용 연령층
#
#                                                  link
# 0   https://kin.naver.com/qna/detail.naver?d1id=3&...
# 1   https://kin.naver.com/qna/detail.naver?d1id=3&...
# 2   https://kin.naver.com/qna/detail.naver?d1id=3&...
# 3   https://kin.naver.com/qna/detail.naver?d1id=1&...
# 4   https://kin.naver.com/qna/detail.naver?d1id=4&...
# 5   https://kin.naver.com/qna/detail.naver?d1id=4&...
# 6   https://kin.naver.com/qna/detail.naver?d1id=1&...
# 7   https://kin.naver.com/qna/detail.naver?d1id=6&...
# 8   https://kin.naver.com/qna/detail.naver?d1id=11...
# 9   https://kin.naver.com/qna/detail.naver?d1id=1&...
# 10  https://kin.naver.com/qna/detail.naver?d1id=8&...
# 11  https://kin.naver.com/qna/detail.naver?d1id=1&...
# 12  https://kin.naver.com/qna/detail.naver?d1id=1&...
# 13  https://kin.naver.com/qna/detail.naver?d1id=1&...
# 14  https://kin.naver.com/qna/detail.naver?d1id=11...
# 15  https://kin.naver.com/qna/detail.naver?d1id=7&...
# 16  https://kin.naver.com/qna/detail.naver?d1id=1&...
# 17  https://kin.naver.com/qna/detail.naver?d1id=1&...
# 18  https://kin.naver.com/qna/detail.naver?d1id=4&...
# 19  https://kin.naver.com/qna/detail.naver?d1id=11...
# 20  https://kin.naver.com/qna/detail.naver?d1id=1&...
# 21  https://kin.naver.com/qna/detail.naver?d1id=3&...
# 22  https://kin.naver.com/qna/detail.naver?d1id=5&...
# 23  https://kin.naver.com/qna/detail.naver?d1id=1&...
# 24  https://kin.naver.com/qna/detail.naver?d1id=2&...
# 25  https://kin.naver.com/qna/detail.naver?d1id=7&...
# 26  https://kin.naver.com/qna/detail.naver?d1id=1&...
# 27  https://kin.naver.com/qna/detail.naver?d1id=1&...
# 28  https://kin.naver.com/qna/detail.naver?d1id=1&...
# 29  https://kin.naver.com/qna/detail.naver?d1id=1&...

# %%
# 페이징 포함 (keyword를 page수 만큼 검색한 결과를 데이터프레임에)
import requests
from bs4 import BeautifulSoup
import pandas as pd
keyword = '챗지피티'
pages = 3
items_list = [] # 크롤링한 데이터를 담을 list(2차원 리스트)
for page in range(1, pages+1):
    url = f'https://kin.naver.com/search/list.naver?query={keyword}&page={page}'
    # print(url)
    # 해당 url의 soup객체 -> 글제목, link를 가져와서 items_list에 append
    response = requests.get(url)
    # print(response.status_code) 정상 접근 가능한지 여부
    soup = BeautifulSoup(response.text, 'html.parser')
    dts = soup.find_all('dt')
    # print([item.attrs['href'] for item in items])
    for dt in dts:
        item = dt.find('a')
        items_list.append([item.text, item.attrs.get('href')])

df = pd.DataFrame(items_list, columns=['title','link'])
df
# Out:
#                         title  \
# 0                     챗지피티 사주
# 1                     챗지피티 타로
# 2                     챗지피티 타로
# 3        챗지피티 갸륵체 어떻게 생각하시나요?
# 4      챗지피티 사용하려면 어떻게 해야 하나요?
# 5                챗지피티 잡아내는거..
# 6                   챗지피티 개인정보
# 7         챗지피티 돈 내면서 쓰는거 좋나요?
# 8       카피킬러 표절 및 챗지피티 검사 83%
# 9                챗지피티 무료 렉 거림
# 10  아 ㅆ 지식인 챗지피티 돌리는 것들 잘...
# 11            챗지피티 동시 접속 되나요?
# 12         챗지피티 plus 파일 생성 오류
# 13           무료 챗지피티 써보려고 하는데
# 14                     하 챗지피티
# 15                  챗지피티 연애상담
# 16                    챗지피티 코딩
# 17              퍼플렉시티 챗지피티 질문
# 18                    챗지피티 음성
# 19          조선왕조실록 챗지피티 사실 검증
# 20                   겜스고 챗지피티
# 21                   챗지피티 검사기
# 22                   챗지피티 메모리
# 23                 챗지피티 유료 차이
# 24                   모바일 챗지피티
# 25                 지식인<<<챗지피티
# 26                챗지피티 결제 플러스
# 27          챗지피티 4o 이용해야 하나…?
# 28                    챗지피티 오류
# 29              챗지피티 주 사용 연령층
#
#                                                  link
# 0   https://kin.naver.com/qna/detail.naver?d1id=3&...
# 1   https://kin.naver.com/qna/detail.naver?d1id=3&...
# 2   https://kin.naver.com/qna/detail.naver?d1id=3&...
# 3   https://kin.naver.com/qna/detail.naver?d1id=1&...
# 4   https://kin.naver.com/qna/detail.naver?d1id=4&...
# 5   https://kin.naver.com/qna/detail.naver?d1id=4&...
# 6   https://kin.naver.com/qna/detail.naver?d1id=1&...
# 7   https://kin.naver.com/qna/detail.naver?d1id=6&...
# 8   https://kin.naver.com/qna/detail.naver?d1id=11...
# 9   https://kin.naver.com/qna/detail.naver?d1id=1&...
# 10  https://kin.naver.com/qna/detail.naver?d1id=8&...
# 11  https://kin.naver.com/qna/detail.naver?d1id=1&...
# 12  https://kin.naver.com/qna/detail.naver?d1id=1&...
# 13  https://kin.naver.com/qna/detail.naver?d1id=1&...
# 14  https://kin.naver.com/qna/detail.naver?d1id=11...
# 15  https://kin.naver.com/qna/detail.naver?d1id=7&...
# 16  https://kin.naver.com/qna/detail.naver?d1id=1&...
# 17  https://kin.naver.com/qna/detail.naver?d1id=1&...
# 18  https://kin.naver.com/qna/detail.naver?d1id=4&...
# 19  https://kin.naver.com/qna/detail.naver?d1id=11...
# 20  https://kin.naver.com/qna/detail.naver?d1id=1&...
# 21  https://kin.naver.com/qna/detail.naver?d1id=3&...
# 22  https://kin.naver.com/qna/detail.naver?d1id=5&...
# 23  https://kin.naver.com/qna/detail.naver?d1id=1&...
# 24  https://kin.naver.com/qna/detail.naver?d1id=2&...
# 25  https://kin.naver.com/qna/detail.naver?d1id=7&...
# 26  https://kin.naver.com/qna/detail.naver?d1id=1&...
# 27  https://kin.naver.com/qna/detail.naver?d1id=1&...
# 28  https://kin.naver.com/qna/detail.naver?d1id=1&...
# 29  https://kin.naver.com/qna/detail.naver?d1id=1&...

# %%
# 페이징 포함 (keyword를 page수 만큼 검색한 결과를 데이터프레임에)
def get_items_data(keyword, pages):
    import requests
    from bs4 import BeautifulSoup
    import pandas as pd

    items_list = [] # 크롤링한 데이터를 담을 list(2차원 리스트)
    for page in range(1, pages+1):
        url = f'https://kin.naver.com/search/list.naver?query={keyword}&page={page}'
        # 해당 url의 soup객체 -> 글제목, link를 가져와서 items_list에 append
        response = requests.get(url)
        soup = BeautifulSoup(response.text, 'html.parser')
        dts = soup.find_all('dt')
        for dt in dts:
            item = dt.find('a')
            items_list.append([item.text, item.attrs.get('href')])

    return pd.DataFrame(items_list, columns=['title','link'])

# %%
get_items_data('체인링크',3)
# Out:
#                           title  \
# 0               체인링크 안정성을 고려한다면
# 1            공업용 체인링크는 어디서 파나요?
# 2            팬텀코인 기반 체인링크 현금화방법
# 3         체인링크 코인 전망에 대해 알려주세요.
# 4                    체인링크 체결 방법
# 5                     체인링크vs폴카닷
# 6   자전거 12단 체인에 11단 체인링크 써도...
# 7      자전거 체인에 체인링크있는 거랑 없는...
# 8        체인링크 코인의 시세와 전망이 궁금합니다
# 9                    자전거체인 체인링크
# 10                 픽시 체인 링크가 없음
# 11           체인링크 없는 체인 커팅 후 결합
# 12          자전거 체인링크 어떤걸 사야하나요?
# 13     체인링크 코인 전망 다시 전고점 갈수...
# 14      체인링크(LINK)코인 투자해도 좋을까요?
# 15                        체인 링크
# 16    장투용으로 체인링크, 라이트코인, 트론...
# 17                스램 체인링크 관련 질문
# 18     MTB 27단 체인교체 및 체인링크에...
# 19              자전거 체인링크없을때 빼는법
# 20                 엔진11크릿디 체인링크
# 21        체인링크 시세 때문에 똥줄 타는...
# 22            체인링크 시세와 전망이 궁금해요
# 23       자전거 체인링크 사이즈 구매 알려주세요.
# 24            로드자전거 체인링크 내공 100
# 25       (급해요ㅠㅠ)픽시 체인링크 없을때...
# 26        체인링크 시세가 우울 그자체인데...
# 27           이즈미 젯블랙 골드 체인링크 호환
# 28                   자전거 체인링크분리
# 29                      픽시 체인링크
#
#                                                  link
# 0   https://kin.naver.com/qna/detail.naver?d1id=3&...
# 1   https://kin.naver.com/qna/detail.naver?d1id=2&...
# 2   https://kin.naver.com/qna/detail.naver?d1id=4&...
# 3   https://kin.naver.com/qna/detail.naver?d1id=4&...
# 4   https://kin.naver.com/qna/detail.naver?d1id=5&...
# 5   https://kin.naver.com/qna/detail.naver?d1id=4&...
# 6   https://kin.naver.com/qna/detail.naver?d1id=10...
# 7   https://kin.naver.com/qna/detail.naver?d1id=10...
# 8   https://kin.naver.com/qna/detail.naver?d1id=4&...
# 9   https://kin.naver.com/qna/detail.naver?d1id=10...
# 10  https://kin.naver.com/qna/detail.naver?d1id=10...
# 11  https://kin.naver.com/qna/detail.naver?d1id=10...
# 12  https://kin.naver.com/qna/detail.naver?d1id=10...
# 13  https://kin.naver.com/qna/detail.naver?d1id=8&...
# 14  https://kin.naver.com/qna/detail.naver?d1id=2&...
# 15  https://kin.naver.com/qna/detail.naver?d1id=10...
# 16  https://kin.naver.com/qna/detail.naver?d1id=4&...
# 17  https://kin.naver.com/qna/detail.naver?d1id=10...
# 18  https://kin.naver.com/qna/detail.naver?d1id=10...
# 19  https://kin.naver.com/qna/detail.naver?d1id=10...
# 20  https://kin.naver.com/qna/detail.naver?d1id=5&...
# 21  https://kin.naver.com/qna/detail.naver?d1id=4&...
# 22  https://kin.naver.com/qna/detail.naver?d1id=4&...
# 23  https://kin.naver.com/qna/detail.naver?d1id=10...
# 24  https://kin.naver.com/qna/detail.naver?d1id=10...
# 25  https://kin.naver.com/qna/detail.naver?d1id=10...
# 26  https://kin.naver.com/qna/detail.naver?d1id=2&...
# 27  https://kin.naver.com/qna/detail.naver?d1id=13...
# 28  https://kin.naver.com/qna/detail.naver?d1id=10...
# 29  https://kin.naver.com/qna/detail.naver?d1id=10...

# %% [markdown]
# ### 6) 네이버지식인으로 검색(open API 사용 O)
# - 특정 keyword를 특정데이터 수(30)만큼 검색한 결과 데이터프레임으로 출력
#     - .env에 발급받은 키 저장 -> load (pip install python-dotenv)

# %%
# 환경변수를 가져오기
from dotenv import load_dotenv
import os
load_dotenv() # dotenv_path='.env' 기본값
# print(os.getenv('Client_ID'))
# print(os.getenv('Client_Secret'))
# Out:
# True

# %%
# 네이버 검색 API 예제 - 지식인 검색
import os
import sys
import urllib.request
client_id = os.getenv('Client_ID')
client_secret = os.getenv('Client_Secret')
encText = urllib.parse.quote("이더리움")
url = "https://openapi.naver.com/v1/search/kin.json?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/kin.xml?query=" + encText # XML 결과

headers = {'X-Naver-Client-Id':client_id,
           'X-Naver-Client-Secret':client_secret}
request = urllib.request.Request(url, headers=headers)

# request = urllib.request.Request(url)
# request.add_header("X-Naver-Client-Id",client_id)
# request.add_header("X-Naver-Client-Secret",client_secret)

response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(type(response_body.decode('utf-8')))
    import json
    data = json.loads(response_body.decode('utf-8')) # json형태의 str을 딕셔너리로
    print(type(data))
    print(data['items'])
else:
    print("Error Code:" + rescode)
# Out:
# <class 'str'>
# <class 'dict'>
# [{'title': '<b>이더리움</b> etf', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=814&docId=481152606&qb=7J20642U66as7JuA&enc=utf8', 'description': '<b>이더리움</b> 비트코인 etf가 상승하면 <b>이더리움</b>도 상승하나요? 비트코인 ETF가 상승하면 <b>이더리움</b>도 덩달아 오를까? 음... 그럼 <b>이더리움</b> 같은 다른 알트코인들도 심리적으로 영향을 받아 같이 오를 가능성은 있어요. 하지만! 이건... '}, {'title': '<b>이더리움</b>은 대체 불가인가요?', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40108&docId=484040430&qb=7J20642U66as7JuA&enc=utf8', 'description': "... 세력들이 <b>이더리움</b>을 꾸준히 모으는 이유가 뭔지... 결론부터 말씀드리면, <b>이더리움</b>이 기술적인 속도 면에서... 이것이 고래들이 <b>이더리움</b>을 모으는 이유입니다. 속도... <b>이더리움</b> 레이어1 자체보다 빠른 것은 사실입니다. '안정성... "}, {'title': 'ETHU, <b>이더리움</b> ETF 투자 방법은?', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40603&docId=484716632&qb=7J20642U66as7JuA&enc=utf8', 'description': 'ETHU라는 <b>이더리움</b> ETF가 있다고 들었는데, <b>이더리움</b> ETF에 투자하는... ETHU는 최근 주목받고 있는 <b>이더리움</b> 현물 ETF(Ethereum Spot ETF) 관련 종목 중... 상장된 <b>이더리움</b> 현물 기반 ETF입니다. 아래에 <b>이더리움</b> ETF에 투자하는... '}, {'title': '<b>이더리움</b> 스테이킹, 어디서 시작해야 할까요?', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=3&dirId=31503&docId=484682042&qb=7J20642U66as7JuA&enc=utf8', 'description': '... <b>이더리움</b>(ETH)을 스테이킹하고 싶은데, 어떤 플랫폼에서 시작하는 것이... <b>이더리움</b>(ETH) 스테이킹을 시작하려면 몇 가지 옵션을 고려할 수... 추천 <b>이더리움</b> 스테이킹 플랫폼 리도 (Lido) 유동성 스테이킹을 지원하여 stETH를... '}, {'title': '<b>이더리움</b> 스테이킹, 어디서 시작해야 할까요?', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40603&docId=484761509&qb=7J20642U66as7JuA&enc=utf8', 'description': '... <b>이더리움</b>(ETH)을 스테이킹하고 싶은데, 어떤 플랫폼에서... <b>이더리움</b> 어디서 시작해야 할까요? 안녕하세요. <b>이더리움</b>(ETH)을 하고 싶은데, 어떤 플랫폼에서 시작하는 것이... &gt; <b>이더리움</b> 어디서 해야할지 궁금하셨나봅니다 <b>이더리움</b>... '}, {'title': '<b>이더리움</b> 상장폐지', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40108&docId=483122224&qb=7J20642U66as7JuA&enc=utf8', 'description': '<b>이더리움</b> 상장폐지 되면 <b>이더리움</b> 기반 밈코인들은 어떻게 되는건가요? 특히 도지코인. 같이 상폐ㄱㄱ?인가요?... <b>이더리움</b>이 상장폐지되면, <b>이더리움</b> 기반 밈코인들은 큰 영향을 받을 수 있습니다. 도지코인 같은 경우 <b>이더리움</b>과는 다른... '}, {'title': '룸네트워크 메타마스크 <b>이더리움</b> 출금', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=1060106&docId=485643169&qb=7J20642U66as7JuA&enc=utf8', 'description': '... 메타마스크 주소 복붙하여 업비트에서 <b>이더리움</b>으로 출금해서 출금완료가... 혹시 룸네트워크의 <b>이더리움</b>이 아니라, 룸네트워크 자체 토큰을 <b>이더리움</b>으... 만약 업비트에서 <b>이더리움</b> 출금이 정상적으로 처리되었다면... '}, {'title': '요즘 <b>이더리움</b> 전망이 어떻게 되나요?', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40102&docId=427872282&qb=7J20642U66as7JuA&enc=utf8', 'description': '이제 막 돈벌면서 투자를 좀 하려고 하는데 <b>이더리움</b> 전망이 어떻게 되나요? 처음해보는거라 전망이 어떤지, 해도 괜찮을지 고민입니다 <b>이더리움</b> 전망이 어떻게 되는지 알려주세요 <b>이더리움</b> 호재 전망 정리되어있는 글 공유드려요... '}, {'title': '<b>이더리움</b> 자녀 전송 후 증여신고 안함', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40303&docId=478733897&qb=7J20642U66as7JuA&enc=utf8', 'description': '작년에 빗썸에서 보유중인 <b>이더리움</b>을 아들 2명에게 본인 소유의 빗썸 지갑으로 각각 0.5개씩 전송했습니다. 그때 당시에 1개의 <b>이더리움</b>이 530만원 정도였으니까 0.5개씩이면 300만원도 안되고 금액이 소액이라 신고 안해도 되겠지라고... '}, {'title': '<b>이더리움</b> 타인에게 전송할 때', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40108&docId=485544709&qb=7J20642U66as7JuA&enc=utf8', 'description': '타인의 지갑에서 제 지갑으로 <b>이더리움</b> 전송할 때 그 지갑이 만들어진 앱이나 사이트가 꼭 같아야만 전송되나요? 아님... 있는 지갑끼리도 주소만 있으면 전송되나요? 타인의 지갑과 앱이 달라도 주소만 있으면 <b>이더리움</b> 전송 가능합니다.'}]

# %%
# keyword를 display수만큼 지식in 검색 결과를 데이터프레임에 (방법1 크롤링)
import requests
import pandas as pd
import json
import os
load_dotenv()
client_id = os.getenv('Client_ID')
client_secret = os.getenv('Client_Secret')
keyword = "챗지피티"
cnt = 30
url = f'https://openapi.naver.com/v1/search/kin.json?query={keyword}&display={cnt}'
headers = {'X-Naver-Client-Id':client_id,
           'X-Naver-Client-Secret':client_secret}
response = requests.get(url, headers=headers)
# items = json.loads(response.text)['items'] : json.loads() - 방법1과 방법2
items = response.json()['items'] # 방법1에서만 가능한 함수
items_list=[]
for item in items:
    items_list.append([item.get('title').replace('<b>','').replace('</b>','') , #item['title']
                       item.get('link'),
                       item.get('description')])
df = pd.DataFrame(items_list, columns=['title','link','description'])
print(df.loc[0, 'link'])
# Out:
# https://kin.naver.com/qna/detail.naver?d1id=3&dirId=31501&docId=484827506&qb=7LGX7KeA7ZS87Yuw&enc=utf8

# %%
# 함수 작성
def get_naver_kin(keyword, cnt):
    import requests
    import pandas as pd
    import json
    from dotenv import load_dotenv
    import os
    load_dotenv() 
    client_id = os.getenv('Client_ID')
    client_secret = os.getenv('Client_Secret')

    url = f'https://openapi.naver.com/v1/search/kin.json?query={keyword}&display={cnt}'
    headers = {'X-Naver-Client-Id': client_id,
               'X-Naver-Client-Secret':client_secret}
    response = requests.get(url, headers=headers)

    # items = json.loads(response.text)['items'] : json.loads() -방법1과 방법2
    items = response.json()['items'] # 방법1에서만 가능한 함수
    items_list = []
    for item in items:
        items_list.append([
            item.get('title').replace('<b>','').replace('</b>',''), # item['title']
            item.get('link'),
            item.get('description').replace('<b>','').replace('</b>','')
        ])
    return pd.DataFrame(items_list, columns=['title','link','description'])

# %%
get_naver_kin("청바지",20)
# Out:
#                              title  \
# 0                 영어로 청바지를 뭐라고하나요?
# 1   전 남자인데, 누워서 청바지를 입으면 고환이 아플 수?
# 2                청바지 없는데 면접취소 할까요?
# 3                   고관절 지방이식 후 청바지
# 4                   임영웅 청바지 입은 사진?
# 5                           청바지 세탁
# 6   미국에서 청바지 가격이 306불입니다 관부가세 얼마나오
# 7             청바지? 면바지도 트레이닝바지인가요?
# 8                        핀턱 청바지 수선
# 9                           청바지 이염
# 10      골프 연습장 에서 부츠컷 청바지 입어도 되나요?
# 11                    강아지 청바지 뜯어먹음
# 12                          청바지 수선
# 13              청바지는 오랫동안 쓸 수 있나요?
# 14       여자들중에 원피스보다 청바지가 예쁜 이유는요?
# 15          체육대회때 흰티에 청바지 입어도 되나요?
# 16                   8월 초 이탈리아 청바지
# 17              청바지는 오랫동안 쓸 수 있나요?
# 18                      청바지에서 파란 물
# 19               40대 남자도 청바지를 입나요?
#
#                                                  link  \
# 0   https://kin.naver.com/qna/detail.naver?d1id=11...
# 1   https://kin.naver.com/qna/detail.naver?d1id=7&...
# 2   https://kin.naver.com/qna/detail.naver?d1id=6&...
# 3   https://kin.naver.com/qna/detail.naver?d1id=7&...
# 4   https://kin.naver.com/qna/detail.naver?d1id=3&...
# 5   https://kin.naver.com/qna/detail.naver?d1id=8&...
# 6   https://kin.naver.com/qna/detail.naver?d1id=4&...
# 7   https://kin.naver.com/qna/detail.naver?d1id=13...
# 8   https://kin.naver.com/qna/detail.naver?d1id=8&...
# 9   https://kin.naver.com/qna/detail.naver?d1id=5&...
# 10  https://kin.naver.com/qna/detail.naver?d1id=10...
# 11  https://kin.naver.com/qna/detail.naver?d1id=8&...
# 12  https://kin.naver.com/qna/detail.naver?d1id=5&...
# 13  https://kin.naver.com/qna/detail.naver?d1id=8&...
# 14  https://kin.naver.com/qna/detail.naver?d1id=8&...
# 15  https://kin.naver.com/qna/detail.naver?d1id=5&...
# 16  https://kin.naver.com/qna/detail.naver?d1id=9&...
# 17  https://kin.naver.com/qna/detail.naver?d1id=5&...
# 18  https://kin.naver.com/qna/detail.naver?d1id=8&...
# 19  https://kin.naver.com/qna/detail.naver?d1id=8&...
#
#                                           description
# 0   영어로 청바지를 뭐라고하나요? 안녕하세요~ 선생님도 매월 시험보는 목동영어학원 길벗...
# 1   전 남자인데, 누워서 청바지를 입으면 고환이 아플 수? 안녕하세요. 하이닥-네이버 ...
# 2   낼 알바 면접인데 츄리닝만 있고 청바지가 없어요 취소할까요? 아님 청바지는 아니어도...
# 3   현재 고관절(골반) 지방이식 한 지 두달 가까이 되어가는데,꽉 끼는 청바지나 레깅스...
# 4   임영웅 사진첩 만들고 있는데요! 청바지 입은 사진 갖고 계신분 공유부탁드려요! 임영...
# 5   ... 청바지 구매하고 처음 한번은 드라이크리닝으로 했는데요. 한번 드라이크리닝 했...
# 6   청바지 디스쿼드 샌스에서 309불에 사려고 합니다 배대지 이용합니다... 청바지 수...
# 7   제가 내일 체육대회인데여 트레이닝바지가 된다는데 제가 가지고있는바지중에서 카키색에 ...
# 8   핀턱있는 청바지 허리 줄일 수 있나용 네! 핀턱 청바지도 허리 수선이 가능합니다. ...
# 9   ... 아니면 진한 청바지는 다 이염이 된다고 봐야하나요ㅠ 진한 청바지 모두에서 이...
# 10  ... 바지가 부츠컷 청바지만 았는데 좀 달라 붙는 거라서.. 가능한가요? 너무 이...
# 11  8살된 강아지가 제 청바지를 좀 뜯어먹었어요.. 손가락 지문만큼 먹었는데 괜찮을까요...
# 12  제가 내일 입고 나가려고 바지를 시켰는데요 혹시 데님 청바지도 허벅지부터 종아리 부...
# 13  청바지는 오랫동안 쓸 수 있나요? 청바지, 하나 잘 사면 진짜 몇 년이고 입게 되잖...
# 14  ... 보다 청바지를 입고 있는게 예쁜 이유는요? 여자들 사이에서 청바지가 원피스보...
# 15  체육대회때 흰티에 청바지 입어도 되나요? 체육대회에 흰티와 청바지 착용 가능합니다....
# 16  ... 가는데 청바지 입으면 더울까요ㅠ 더위를 많이 타는 편이라면 더울 수도 있지만...
# 17  청바지는 오랫동안 쓸 수 있나요? 청바지는 품질에 따라 다르지만, 일반적으로 잘 관...
# 18  파란물이 원래 나오나요?청바지입고 크록스 신고 돌아댕겻는데 크록스 발꿈치?부분이 파...
# 19  40대 남자도 청바지를 입나요? 보통 20대에 청바지 많이 입던 분들이 나이 먹으면...

# %% [markdown]
# ### quiz) 네이버 open API를 이용해서 청바지 이미지 100건 데이터를 csv파일로 저장
#     데이터 : 제목, 이미지링크, 썸네일링크, 높이, 폭

# %%
word = '청바지'
url = f'https://openapi.naver.com/v1/search/image?query={word}&display=100'
headers = {'X-Naver-Client-Id':client_id,
           'X-Naver-Client-Secret':client_secret}
response = requests.get(url, headers=headers)
items = response.json()['items']
items_list=[]
for item in items:
    items_list.append([item.get('title').replace('<b>','').replace('</b>','') , #item['title']
                       item.get('link'),
                       item.get('thumbnail')])
df = pd.DataFrame(items_list, columns=['title','link','thumbnail'])

df.to_csv(f"data/{word}_images.csv", index=False, encoding='utf-8')
df.head()
# Out:
#                                               title  \
# 0      BINIWU 심플 빈티지 워싱 청바지 남자 봄가을 루즈핏 통바지 28 빈티지블루
# 1                   중년 청바지 아이스 팬츠 남성 얇은 슬랙스 바지남 긴바지
# 2         게스 게스 여성 청바지 플레어 붓컷 미디엄블루 데님팬츠 M YM3D0117
# 3    가우리 봄 가을 프리미엄 중년 남성 청바지 CRO 스판 청 팬츠 - 청바지 | 쿠팡
# 4  청바지 남자 여름 얇은 레져 텐셀 아메리칸 빈티지 청바지 남자 카우형 남자 스타일 팬츠
#
#                                                 link  \
# 0  http://shopping.phinf.naver.net/main_5172227/5...
# 1  http://shopping.phinf.naver.net/main_5314890/5...
# 2  http://shopping.phinf.naver.net/main_5182791/5...
# 3  https://thumbnail8.coupangcdn.com/thumbnails/r...
# 4  http://shopping.phinf.naver.net/main_5188539/5...
#
#                                            thumbnail
# 0  https://search.pstatic.net/common/?type=b150&s...
# 1  https://search.pstatic.net/common/?type=b150&s...
# 2  https://search.pstatic.net/common/?type=b150&s...
# 3  https://search.pstatic.net/sunny/?type=b150&sr...
# 4  https://search.pstatic.net/common/?type=b150&s...

# %%
import requests
import pandas as pd
from dotenv import load_dotenv
import os
load_dotenv() 
client_id = os.getenv('Client_ID')
client_secret = os.getenv('Client_Secret')
word = "청바지"
url = f'https://openapi.naver.com/v1/search/image?query={word}&display=100'
headers = {'X-Naver-Client-Id': client_id,
           'X-Naver-Client-Secret':client_secret}
response = requests.get(url, headers=headers)
# print(response.text)
items = response.json()['items'] # 방법1에서만 가능한 함수
items_list = []
for idx, item in enumerate(items):
    title = item.get('title')
    link = item.get('link')
    thumbnail = item.get('thumbnail')
    sizeheight = item.get('sizeheight')
    sizewidth = item.get('sizewidth')
    items_list.append({
        'no': idx+1,
        'title': title,
        'link' : link,
        'thumbnail' : thumbnail,
        'sizeheight':sizeheight,
        'sizewidth' :sizewidth
    })
    # link와 thumbnail을 저장
df = pd.DataFrame(items_list)
df.head()
# Out:
#    no                                             title  \
# 0   1      BINIWU 심플 빈티지 워싱 청바지 남자 봄가을 루즈핏 통바지 28 빈티지블루
# 1   2                   중년 청바지 아이스 팬츠 남성 얇은 슬랙스 바지남 긴바지
# 2   3         게스 게스 여성 청바지 플레어 붓컷 미디엄블루 데님팬츠 M YM3D0117
# 3   4    가우리 봄 가을 프리미엄 중년 남성 청바지 CRO 스판 청 팬츠 - 청바지 | 쿠팡
# 4   5  청바지 남자 여름 얇은 레져 텐셀 아메리칸 빈티지 청바지 남자 카우형 남자 스타일 팬츠
#
#                                                 link  \
# 0  http://shopping.phinf.naver.net/main_5172227/5...
# 1  http://shopping.phinf.naver.net/main_5314890/5...
# 2  http://shopping.phinf.naver.net/main_5182791/5...
# 3  https://thumbnail8.coupangcdn.com/thumbnails/r...
# 4  http://shopping.phinf.naver.net/main_5188539/5...
#
#                                            thumbnail sizeheight sizewidth
# 0  https://search.pstatic.net/common/?type=b150&s...        800       800
# 1  https://search.pstatic.net/common/?type=b150&s...       1000      1000
# 2  https://search.pstatic.net/common/?type=b150&s...        700       700
# 3  https://search.pstatic.net/sunny/?type=b150&sr...        492       492
# 4  https://search.pstatic.net/common/?type=b150&s...        600       600

# %%
df.loc[3, 'link']
# Out:
# 'https://thumbnail8.coupangcdn.com/thumbnails/remote/492x492ex/image/vendor_inventory/images/2017/09/07/17/1/837feb8c-041e-4921-bd39-174fec765a2a.jpg'

# %%
def save_img(attr, idx, query, url):
    '{attr}_{idx}_{query}.{확장자} 이미지 저장'
    file_extension = url.split('.')[-1]
    quote_index = file_extension.find('?')
    
    if quote_index != -1:
        file_extension = file_extension[:quote_index]
    # print(file_extension)
    img = requests.get(url).content
    open(f'ch14_image/{attr}_{idx}_{query}.{file_extension}', 'wb').write(img)

# %%
save_img('메인',2 , '청바지', df.loc[6,'link'])

# %%
# word image 100개 검색한 데이터는 csv파일로, 이미지는 ch14_image폴더에 저장되는 함수

def get_naver_save_image(word):
    import requests
    import pandas as pd
    from dotenv import load_dotenv
    import os
    load_dotenv() 
    client_id = os.getenv('Client_ID')
    client_secret = os.getenv('Client_Secret')
    url = f'https://openapi.naver.com/v1/search/image?query={word}&display=100'
    headers = {'X-Naver-Client-Id': client_id,
            'X-Naver-Client-Secret':client_secret}
    response = requests.get(url, headers=headers)
    items = response.json()['items'] # 방법1에서만 가능한 함수
    items_list = []
    for idx, item in enumerate(items):
        title = item.get('title')
        link = item.get('link')
        thumbnail = item.get('thumbnail')
        sizeheight = item.get('sizeheight')
        sizewidth = item.get('sizewidth')
        items_list.append({
            'no': idx+1,
            'title': title,
            'link' : link,
            'thumbnail' : thumbnail,
            'sizeheight':sizeheight,
            'sizewidth' :sizewidth
        })
        # link와 thumbnail을 저장
        save_img('메인', idx+1, word, link)
        save_img('썸네일', idx+1, word, thumbnail)
        # 20% 40% 60% 80% 지점에서 message 출력
        if idx/20 == round(idx/20):
            print(f'= = = {idx}% 진행 중입니다 = = =')
        
    df = pd.DataFrame(items_list)
    df.to_csv(f'ch14_image/{word}.csv', encoding='cp949', index=False)
    print('~ ~ ~ 이미지 및 csv 파일 저장 완료 ~ ~ ~')

# %%
get_naver_save_image('일본')
# Out:
# = = = 0% 진행 중입니다 = = =
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 get_naver_save_image('일본')
#
# Cell In[23], line 32, in get_naver_save_image(word)
#      23 items_list.append({
#      24     'no': idx+1,
#      25     'title': title,
#    (...)
#      29     'sizewidth' :sizewidth
#      30 })
#      31 # link와 thumbnail을 저장
# ---> 32 save_img('메인', idx+1, word, link)
#      33 save_img('썸네일', idx+1, word, thumbnail)
#      34 # 20% 40% 60% 80% 지점에서 message 출력
#
# Cell In[5], line 10, in save_img(attr, idx, query, url)
#       8 # print(file_extension)
#       9 img = requests.get(url).content
# ---> 10 open(f'ch14_image/{attr}_{idx}_{query}.{file_extension}', 'wb').write(img)
#
# File c:\Users\Admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ch14_image/메인_21_일본.com/t5/image/serverpage/image-id/9664047i26C1E36DF4272D6E/image-size/large'

# %% [markdown]
# ## 2.3 xml 파일
# - 기상예측 RSS 활용
# - https://www.kma.go.kr/repositary/xml/fct/mon/img/fct_mon1rss_108_20250529.xml

# %% [markdown]
# ### 1) 기상정보

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://www.kma.go.kr/repositary/xml/fct/mon/img/fct_mon1rss_108_20250529.xml'
response = urlopen(url)
# response.getcode()
soup = BeautifulSoup(response, "xml") #pip install lxml
locals = soup.find_all('local_ta')
# locals[1]
items_list = []
for local in locals:
    local_ta_name = local.select_one('local_ta_name').text
    week1_normalYear = local.select_one('week1_local_ta_normalYear').text # 평년기온
    week1_similarRange = local.select_one('week1_local_ta_similarRange').text # 기온범위
    week1_min = local.select_one('week1_local_ta_minVal').text
    week1_max = local.select_one('week1_local_ta_maxVal').text
    
    week2_normalYear = local.select_one('week2_local_ta_normalYear').text # 평년기온
    week2_similarRange = local.select_one('week2_local_ta_similarRange').text # 기온범위
    week2_min = local.select_one('week2_local_ta_minVal').text
    week2_max = local.select_one('week2_local_ta_maxVal').text
    items_list.append({
        '지역':local_ta_name,
        '1주평년기온':float(week1_normalYear),
        '1주범위':week1_similarRange,
        '1주최저':week1_min,
        '1주최고':week1_max,
        '2주평년기온':week2_normalYear,
        '2주범위':week2_similarRange,
        '2주최저':week2_min,
        '2주최고':week2_max,
    })
df = pd.DataFrame(items_list)
df.head()
# Out:
#                지역  1주평년기온       1주범위 1주최저 1주최고 2주평년기온       2주범위 2주최저 2주최고
# 0   전국(제주도,북한제외)     21.1  20.6~21.6   10   60   21.9  21.5~22.3   20   40
# 1      서울ㆍ인천ㆍ경기도     21.6  21.1~22.1   10   60   22.4  22.0~22.8   20   30
# 2         강원도 영서     20.3  19.7~20.9   10   60   21.3  20.7~21.9   20   30
# 3         강원도 영동     19.1  18.2~20.0   10   60   20.1  19.4~20.8   20   30
# 4     대전ㆍ세종ㆍ충청남도     21.5  21.0~22.0   10   60   22.3  21.9~22.7   20   40

# %%
locals[1]
# Out:
# <local_ta>
# <local_ta_name> 서울ㆍ인천ㆍ경기도 </local_ta_name>
# <week_local_ta>
# <week1_local_ta_normalYear>21.6</week1_local_ta_normalYear>
# <week1_local_ta_similarRange>21.1~22.1</week1_local_ta_similarRange>
# <week1_local_ta_minVal>10</week1_local_ta_minVal>
# <week1_local_ta_similarVal>30</week1_local_ta_similarVal>
# <week1_local_ta_maxVal>60</week1_local_ta_maxVal>
# </week_local_ta>
# <week_local_ta>
# <week2_local_ta_normalYear>22.4</week2_local_ta_normalYear>
# <week2_local_ta_similarRange>22.0~22.8</week2_local_ta_similarRange>
# <week2_local_ta_minVal>20</week2_local_ta_minVal>
# <week2_local_ta_similarVal>50</week2_local_ta_similarVal>
# <week2_local_ta_maxVal>30</week2_local_ta_maxVal>
# </week_local_ta>
# <week_local_ta>
# <week3_local_ta_normalYear>22.7</week3_local_ta_normalYear>
# <week3_local_ta_similarRange>22.2~23.2</week3_local_ta_similarRange>
# <week3_local_ta_minVal>20</week3_local_ta_minVal>
# <week3_local_ta_similarVal>40</week3_local_ta_similarVal>
# <week3_local_ta_maxVal>40</week3_local_ta_maxVal>
# </week_local_ta>
# <week_local_ta>
# <week4_local_ta_normalYear>23.5</week4_local_ta_normalYear>
# <week4_local_ta_similarRange>23.1~23.9</week4_local_ta_similarRange>
# <week4_local_ta_minVal>10</week4_local_ta_minVal>
# <week4_local_ta_similarVal>40</week4_local_ta_similarVal>
# <week4_local_ta_maxVal>50</week4_local_ta_maxVal>
# </week_local_ta>
# </local_ta>

# %% [markdown]
# ### 2) 버스위치정보 조회(OpenAPI활용)
# - data.go.kr 에서
#     * 서울특별시_노선정보조회 서비스(busRouteId, stationNm-정류소명, station-정류소id)
#     * 서울특별시_버스위치정보조회 서비스(busRouteId->버스들위치)

# %%
# step1 : 버스번호 -> busRouteId
# 노선정보조회 서비스 3번 getBusRouteList 서비스

# %%
from dotenv import load_dotenv
import os
load_dotenv() #dotenv_path='.env'
# print('key =', os.getenv('key'))
# print('skey =', os.getenv('skey'))
# Out:
# True

# %%
import requests
from bs4 import BeautifulSoup
from urllib.request import urlretrieve # url 경로 파일을 내 pc에 저장
from urllib.parse import quote
# busNum = quote('마포01')
busNum = '2222'
key = os.getenv('key') # 일반인증키(Encoding)



url1 = f'http://ws.bus.go.kr/api/rest/busRouteInfo/getBusRouteList?ServiceKey={key}&strSrch={quote(busNum)}'
# print(url1)
# response = requests.get(url)
# soup = BeautifulSoup(response.text, "xml")
savefilename = 'data/ch14_busInfo.xml'
urlretrieve(url1, savefilename) # url경로 파일을 savefilename으로 저장
xml = open(savefilename, 'r', encoding='utf-8').read()
soup = BeautifulSoup(xml, 'xml')

soup.select('itemList')

for item in soup.select('itemList'):
    busRouteNm = item.select_one('busRouteNm').text
    if busRouteNm == busNum:
        busRouteId = item.select_one('busRouteId').text
        break
print('busRouteId :', busRouteId)
# Out:
# busRouteId : 100100199

# %%
# step2 : busRouteId로 버스 정류장 목록(정류장이름과 정류장id)
# 노선정보조회 서비스 4번 getStaionsByRouteList

# %%
import pandas as pd
url2 = f'http://ws.bus.go.kr/api/rest/busRouteInfo/getStaionByRoute?ServiceKey={key}&busRouteId={busRouteId}'
print(url2)
response = requests.get(url2)
soup = BeautifulSoup(response.text, 'xml')
itemLists = soup.find_all('itemList')
print(busNum, '번 정류장 갯수 :', len(itemLists))
bus_station = []
for itemList in itemLists:
    # 정류장이름, 정류장id, 경도, 위도
    stationNm = itemList.find('stationNm').text
    station   = itemList.find('station').text
    gpsX      = itemList.find('gpsX').text
    gpsY      = itemList.find('gpsY').text
    bus_station.append([stationNm, station, gpsX, gpsY])
df = pd.DataFrame(bus_station, columns=['정류소명','id','경도','위도'])
df.head()
# Out:
# http://ws.bus.go.kr/api/rest/busRouteInfo/getStaionByRoute?ServiceKey=kWiLqR5an3qgHfkycjPmjxAie5mGGzW0LuPktrSNA3kqpsmWfsLSW9TxR9k0khrZgJLecVcO88n5LsStz845eg%3D%3D&busRouteId=100100199
# 2222 번 정류장 갯수 : 62
#             정류소명         id              경도             위도
# 0  자양미소약국.자양골목시장  104000097  127.0768712862  37.5327003382
# 1    자양동우체국.중앙농협  104000098  127.0807386521  37.5315308364
# 2    자양하늘채베르아파트앞  104000100  127.0846733447  37.5319732231
# 3       자양2동주민센터  104000311       127.08517      37.527949
# 4     구립행복마루어린이집  104000312      127.082213      37.527743

# %%
# step3 : busRouteId로 버스 위치 정보 조회

# %%
url3 = f'http://ws.bus.go.kr/api/rest/buspos/getBusPosByRtid?ServiceKey={key}&busRouteId={busRouteId}'
print(url3)
response = requests.get(url3)
soup = BeautifulSoup(response.text, "xml")
bus_position = []
itemLists = soup.select('itemList')
print('운행중인 버스 대수 :', len(itemLists))
for itemList in soup.select('itemList'):
    # 차량번호, 혼잡도, 경도, 위도, 최종정류장id, 다음정류장id, 도착소요시간
    plainNo = itemList.select_one('plainNo').text
    # print(plainNo)
    congetion = itemList.select_one('congetion').text
    congetion = '여유' if congetion == '3' \
                else "보통" if congetion=='4' \
                else '혼잡' if congetion=='5' \
                else '매우 혼잡'
    # print(congetion)
    gpsX = itemList.select_one('gpsX').text
    gpsY = itemList.select_one('gpsY').text
    lastStnId = itemList.select_one('lastStnId').text
    nextStId = itemList.select_one('nextStId').text
    nextStTm = itemList.select_one('nextStTm').text
    
    bus_position.append({
        '차량번호':plainNo,
        '혼잡도':congetion,
        '경도': gpsX,
        '위도':gpsY,
        '최종정류소id':lastStnId,
        '다음정류장id':nextStId,
        '도착소요시간':nextStTm
    })
df_pos = pd.DataFrame(bus_position)
df_pos
# Out:
# http://ws.bus.go.kr/api/rest/buspos/getBusPosByRtid?ServiceKey=kWiLqR5an3qgHfkycjPmjxAie5mGGzW0LuPktrSNA3kqpsmWfsLSW9TxR9k0khrZgJLecVcO88n5LsStz845eg%3D%3D&busRouteId=100100199
# 운행중인 버스 대수 : 10
#         차량번호    혼잡도          경도         위도    최종정류소id    다음정류장id 도착소요시간
# 0  서울74사4459  매우 혼잡  127.075817  37.533105  104000097  104000120     50
# 1  서울74사6259     여유   127.07529  37.531483  104000096  104000111    385
# 2  서울74사4472     여유  127.067452  37.548372  104000293  103000035    708
# 3  서울74사4455     여유  127.047465  37.551707  103000153  103000035    362
# 4  서울74사4453     여유  127.038338  37.576589  105000079  103000034   1589
# 5  서울70사9509     여유   127.03596  37.589311  105000089  103000034   1063
# 6  서울70사9619     여유  127.038331  37.578959  105000083  103000034    711
# 7  서울70사9508     여유  127.036411  37.565779  103000023  103000034    229
# 8  서울70사9618     여유  127.067907  37.548237  103000189  104000120    862
# 9  서울74사7003     여유  127.071537  37.534452  104000120  104000120     57

# %%
# id 가 104000097 인 정류소명
df.loc[df['id'] == '104000097', '정류소명'].iloc[0]
# Out:
# '자양미소약국.자양골목시장'

# %%
def station_name(row):
    row['최종정류소명'] = df.loc[df['id'] == row['최종정류소id'], '정류소명'].iloc[0]
    return row

# %%
station_name(df_pos.loc[0])
# Out:
# 차량번호           서울74사4459
# 혼잡도                매우 혼잡
# 경도            127.075817
# 위도             37.533105
# 최종정류소id        104000097
# 다음정류장id        104000120
# 도착소요시간                50
# 최종정류소명     자양미소약국.자양골목시장
# Name: 0, dtype: object

# %%
df_pos = df_pos.apply(station_name, axis=1)

# %%
df_pos
# Out:
#         차량번호    혼잡도          경도         위도    최종정류소id    다음정류장id 도착소요시간  \
# 0  서울74사4459  매우 혼잡  127.075817  37.533105  104000097  104000120     50
# 1  서울74사6259     여유   127.07529  37.531483  104000096  104000111    385
# 2  서울74사4472     여유  127.067452  37.548372  104000293  103000035    708
# 3  서울74사4455     여유  127.047465  37.551707  103000153  103000035    362
# 4  서울74사4453     여유  127.038338  37.576589  105000079  103000034   1589
# 5  서울70사9509     여유   127.03596  37.589311  105000089  103000034   1063
# 6  서울70사9619     여유  127.038331  37.578959  105000083  103000034    711
# 7  서울70사9508     여유  127.036411  37.565779  103000023  103000034    229
# 8  서울70사9618     여유  127.067907  37.548237  103000189  104000120    862
# 9  서울74사7003     여유  127.071537  37.534452  104000120  104000120     57
#
#           최종정류소명
# 0  자양미소약국.자양골목시장
# 1        신자초등학교앞
# 2          화양사거리
# 3          리버하우스
# 4  동대문구청.용신동주민센터
# 5         고려대학교앞
# 6           경동시장
# 7          도선사거리
# 8      우리은행화양동지점
# 9          자양고교앞

# %%
# 컬럼명에 id가 포함된 컬럼 제거
drop_true = df_pos.columns.str.contains('id')
drop_column_name = df_pos.columns[drop_true]
df_pos.drop(drop_column_name, axis=1)
# Out:
#         차량번호    혼잡도          경도         위도 도착소요시간         최종정류소명
# 0  서울74사4459  매우 혼잡  127.075817  37.533105     50  자양미소약국.자양골목시장
# 1  서울74사6259     여유   127.07529  37.531483    385        신자초등학교앞
# 2  서울74사4472     여유  127.067452  37.548372    708          화양사거리
# 3  서울74사4455     여유  127.047465  37.551707    362          리버하우스
# 4  서울74사4453     여유  127.038338  37.576589   1589  동대문구청.용신동주민센터
# 5  서울70사9509     여유   127.03596  37.589311   1063         고려대학교앞
# 6  서울70사9619     여유  127.038331  37.578959    711           경동시장
# 7  서울70사9508     여유  127.036411  37.565779    229          도선사거리
# 8  서울70사9618     여유  127.067907  37.548237    862      우리은행화양동지점
# 9  서울74사7003     여유  127.071537  37.534452     57          자양고교앞

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

pages = 2
for page in range(1, pages+1):
    url = f'https://www.yes24.com/product/category/bestseller?pageNumber={page}'
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36'
    }

    response = requests.get(url, headers=headers)
    
    soup = BeautifulSoup(response.text, 'html.parser')

    items_list = []


    rank = soup.select('div.item_img > div.img_canvas > div > em')
    title = soup.select('div.item_info > div.info_row.info_name > a.gd_name')
    author = soup.select('div.item_info > div.info_row.info_pubGrp > span.authPub.info_auth > a')
    publisher = soup.select('div.item_info > div.info_row.info_pubGrp > span.authPub.info_pub > a')
    price = soup.select('div.item_info > div.info_row.info_price > strong > em')   

    items_list.append({
        '순위': rank,
        '제목': title,
        '저자': author,
        '출판사': publisher,
        '가격': price
    })

    if idx >= 48:  # 48위까지
        break

df = pd.DataFrame(items_list)
df.to_csv('yes24_bestseller.csv', index=False)

# %%
# 방법1
pages = 2
bestseller_list = []
for page in range(1, pages+1):
    url = f'https://www.yes24.com/product/category/bestseller?pageNumber={page}'
    response = requests.get(url)
    # print(url)
    # print(response.status_code)
    soup = BeautifulSoup(response.text, 'html.parser')
    ranks_els = soup.select('div.img_upper > em.ico.rank')
    ranks = [int(ranks_el.text) for ranks_el in ranks_els]
    titles_els=soup.select("div.item_info > div.info_row > a.gd_name")
    titles = [titles_el.text for titles_el in titles_els]
    writers_els = soup.select("span.authPub.info_auth")
    # writers_els = soup.find_all('span', class_='info_auth')
    writers = [writers_el.text.strip() for writers_el in writers_els]
    publishers_els = soup.select('div.info_row.info_pubGrp > span.authPub.info_pub')
    publishers = [publishers_el.text for publishers_el in publishers_els]
    prices_els = soup.select("div.info_row > strong.txt_num")
    prices = [prices_el.text for prices_el in prices_els]
    # print(len(ranks), len(titles), len(writers), len(publishers), len(prices))
    for rank, title, writer, publisher, price in zip(ranks, titles, writers, publishers, prices):
        # print("{},{},{},{},{}".format(rank, title, writer, publisher, price))
        bestseller_list.append([rank, title, writer, publisher, price])
df = pd.DataFrame(bestseller_list, 
                  columns=['rank', 'title', 'writer', 'publisher', 'price'])
df.to_csv('data/ch14_yes24.csv', index=False)
